# %% [markdown]
# # Project 08 - Analysis of U.S. Immigration (I-94) Data
# ### Udacity Data Engineer - Capstone Project
# > by Peter Wissel | 2021-04-03
#
# ## Project Overview
# This project works with a data set for immigration to the United States. The supplementary datasets will include data on
# airport codes, U.S. city demographics and temperature data.
#
# The following process is divided into five sub-steps to illustrate how to answer the questions set by the business
# analytics team.
#
# The project file follows the following steps:
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
#
# ##### 3.1.2. At what airports do foreign persons arrive for immigration to the U.S.? [(Data pipeline)](#question2_data_pipeline) <a name="question2_description">
# **Airport dimension**
# 1. Clean data and create staging table `st_immigration_airports` from file
#    [`I94_SAS_Labels_I94PORT.txt`](../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94PORT.txt)
#    with the columns `st_ia_airport_code` as referencing column, `st_ia_airport_name` and `st_ia_airport_state_code`.
#
#     Note that the I-94 airport code is **not** the same as the [IATA](https://en.wikipedia.org/wiki/International_Air_Transport_Association) code and
#     does not correspond to it. Therefore, `SFR` (I94: 'SFR' = 'SAN FRANCISCO, CA') is used for San
#     Francisco Airport in this scenario instead of `SFO`. `SFR` means normally San Fernando, CA, USA.
#
#     **Project decision:** Data from file [airport-codes.csv](../P8_capstone_resource_files/airport-codes_csv.csv) will **not** be linked to the
#     I-94 airport codes because incorrect assignments should not be made.
# 2. Add the column `st_i94_port_state_code` to staging table `st_i94_immigration` based on staging table `st_immigration_airports`. This
#    information is needed to connect the `us-cities-demographics.json` file later on.
#    `st_ia_airport_state_code --> st_i94_port_state_code`
# 3. Add column `st_i94_port_state_code --> f_i94_port_state_code` to fact table `f_i94_immigrations`
# 4. Creation of a dimension named `d_immigration_airports` based on staging table `st_immigration_airports`.
# 5. Mapping of dimension `d_immigration_airports` to  fact table `f_i94_immigration` based on columns
#    (`st_immigration_airports.st_ia_airport_code` --> `d_immigration_airports.d_ia_id`) ==
#    (`st_i94_immigration.st_i94_port` --> `f_i94_immigration.d_ia_id`).
# 6. Answer Project Question 2: At what airports do foreign persons arrive for immigration to the U.S.?

# %% [markdown]
# ##### 4.1.2. At what airports do foreign persons arrive for immigration to the U.S.? [(Description)](#question2_description) <a name="question2_data_pipeline">
# **Airport dimension**
# 1. Clean data and create staging table `st_immigration_airports` from file
#    [`I94_SAS_Labels_I94PORT.txt`](../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94PORT.txt)
#    with the columns `st_ia_airport_code` as referencing column, `st_ia_airport_name` and `st_ia_airport_state_code`.
#
#     Note that the I-94 airport code is **not** the same as the [IATA](https://en.wikipedia.org/wiki/International_Air_Transport_Association) code and
#     does not correspond to it. Therefore, `SFR` (I94: 'SFR' = 'SAN FRANCISCO, CA') is used for San
#     Francisco Airport in this scenario instead of `SFO`. `SFR` means normally San Fernando, CA, USA.
#
#     **Project decision:** Data from file [airport-codes.csv](../P8_capstone_resource_files/airport-codes_csv.csv) will **not** be linked to the
#     I-94 airport codes because incorrect assignments should not be made.

# %%
###### Imports and Installs section
import shutil
import pandas as pd
import pyspark.sql.functions as F
# import spark as spark
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, IntegerType, LongType, TimestampType, DateType
from datetime import datetime, timedelta
from pyspark.sql import SparkSession, DataFrameNaFunctions
from pyspark.sql.functions import when, count, col, to_date, datediff, date_format, month
import re
import json
from os import path

MAX_MEMORY = "5g"

spark = SparkSession\
    .builder\
    .appName("etl pipeline for project 8 - I94 data") \
    .config("spark.jars.packages","saurfang:spark-sas7bdat:3.0.0-s_2.12")\
    .config('spark.sql.repl.eagerEval.enabled', True) \
    .config("spark.executor.memory", MAX_MEMORY) \
    .config("spark.driver.memory", MAX_MEMORY) \
    .appName("Foo") \
    .enableHiveSupport()\
    .getOrCreate()

# setting the current LOG-Level
spark.sparkContext.setLogLevel('ERROR')

# %%
"""
Next Steps: Carefully clean list of airports
1. read all available information from file
2. filter all elements on different regex conditions and store them into a new data frame called `df_st_immigration_airports`
3. store cleaned data frame `df_st_immigration_airports` to disk
"""

# path of txt file
filepath_immigration_airports = "../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94PORT.txt"

# read txt file into data frame
df_txt_immigration_airports_raw = spark.read.text(filepath_immigration_airports)

# get regex_cleaned values --> less error prone --> 582 Entries
regex_cleaned = r"^\s+'([.\w{2,3} ]*)'\s+=\s+'([\w -.\/]*),\s* ([\w\/]+)"

df_st_immigration_airports_regex_cleaned = df_txt_immigration_airports_raw\
    .select( F.regexp_extract('value',regex_cleaned, 1).alias('st_ia_airport_code'),
             F.regexp_extract('value',regex_cleaned, 2).alias('st_ia_airport_name'),
             F.regexp_extract('value',regex_cleaned, 3).alias('st_ia_airport_state_code')) \
    .drop_duplicates() \
    .filter("st_ia_airport_code != ''")  \
    .sort("st_ia_airport_state_code", "st_ia_airport_code") \
    .select("st_ia_airport_code", "st_ia_airport_name", "st_ia_airport_state_code")

print(df_st_immigration_airports_regex_cleaned.count())
df_st_immigration_airports_regex_cleaned.show(10, False)
# Out:
# 582
# +------------------+------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name      |st_ia_airport_state_code|
# +------------------+------------------------+------------------------+
# |5KE               |KETCHIKAN               |AK                      |
# |ALC               |ALCAN                   |AK                      |
# |ANC               |ANCHORAGE               |AK                      |
# |BAR               |BAKER AAF - BAKER ISLAND|AK                      |
# |DAC               |DALTONS CACHE           |AK                      |
# |DTH               |DUTCH HARBOR            |AK                      |
# |EGL               |EAGLE                   |AK                      |
# |FRB               |FAIRBANKS               |AK                      |
# |HOM               |HOMER                   |AK                      |
# |HYD               |HYDER                   |AK                      |
# +------------------+------------------------+------------------------+
# only showing top 10 rows

# %%
# get regex_all values --> with errors like `Collapsed (BUF)` --> 660 Entries
regex = r"^\s+'([.\w{2,3} ]*)'\s+=\s+'([\w -.\/]*)\s*,*\s* ([\w\/]+)"

df_st_immigration_airports = df_txt_immigration_airports_raw\
    .select( F.regexp_extract('value',regex, 1).alias('st_ia_airport_code'),
             F.regexp_extract('value',regex, 2).alias('st_ia_airport_name'),
             F.regexp_extract('value',regex, 3).alias('st_ia_airport_state_code')) \
    .drop_duplicates() \
    .filter("st_ia_airport_code != ''")  \
    .sort("st_ia_airport_state_code", "st_ia_airport_code")

print(df_st_immigration_airports.count())
df_st_immigration_airports.show(1000, False)
# Out:
# 660
# +------------------+------------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name            |st_ia_airport_state_code|
# +------------------+------------------------------+------------------------+
# |BUS               |Collapsed (BUF)               |06/15                   |
# |FRG               |Collapsed (FOK)               |06/15                   |
# |HRL               |Collapsed (HLG)               |06/15                   |
# |IAG               |Collapsed (NIA)               |06/15                   |
# |ISP               |Collapsed (FOK)               |06/15                   |
# |JSJ               |Collapsed (SAJ)               |06/15                   |
# |PHN               |Collapsed (PHU)               |06/15                   |
# |STN               |Collapsed (STR)               |06/15                   |
# |T01               |Collapsed (SEA)               |06/15                   |
# |VMB               |Collapsed (VNB)               |06/15                   |
# |DLV               |DERBY LINE, VT (RT.           |5                       |
# |DUR               |LOUIS BOTHA, SOUTH            |AFRICA                  |
# |5KE               |KETCHIKAN,                    |AK                      |
# |ALC               |ALCAN,                        |AK                      |
# |ANC               |ANCHORAGE,                    |AK                      |
# |BAR               |BAKER AAF - BAKER ISLAND,     |AK                      |
# |DAC               |DALTONS CACHE,                |AK                      |
# |DTH               |DUTCH HARBOR,                 |AK                      |
# |EGL               |EAGLE,                        |AK                      |
# |FRB               |FAIRBANKS,                    |AK                      |
# |HOM               |HOMER,                        |AK                      |
# |HYD               |HYDER,                        |AK                      |
# |JUN               |JUNEAU,                       |AK                      |
# |KET               |KETCHIKAN,                    |AK                      |
# |MOS               |MOSES POINT INTERMEDIATE,     |AK                      |
# |NIK               |NIKISKI,                      |AK                      |
# |NOM               |NOM,                          |AK                      |
# |ORI               |PORT LIONS SPB,               |AK                      |
# |PIZ               |DEW STATION PT LAY DEW,       |AK                      |
# |PKC               |POKER CREEK,                  |AK                      |
# |SKA               |SKAGWAY,                      |AK                      |
# |SNP               |ST. PAUL ISLAND,              |AK                      |
# |TKI               |TOKEEN,                       |AK                      |
# |WRA               |WRANGELL,                     |AK                      |
# |BHX               |BIRMINGHAM,                   |AL                      |
# |HSV               |MADISON COUNTY - HUNTSVILLE,  |AL                      |
# |MOB               |MOBILE,                       |AL                      |
# |ARB               |ARUBA, NETH                   |ANTILLES                |
# |AG0               |MAGNOLIA,                     |AR                      |
# |LIA               |LITTLE ROCK,                  |AR                      |
# |ROG               |ROGERS ARPT,                  |AR                      |
# |EZE               |BUENOS AIRES, MINISTRO PIST,  |ARGENTINA               |
# |DOU               |DOUGLAS,                      |AZ                      |
# |LUK               |LUKEVILLE,                    |AZ                      |
# |MAP               |MARIPOSA                      |AZ                      |
# |NAC               |NACO,                         |AZ                      |
# |NOG               |NOGALES,                      |AZ                      |
# |PHO               |PHOENIX,                      |AZ                      |
# |POR               |PORTAL,                       |AZ                      |
# |SAS               |SASABE,                       |AZ                      |
# |SLU               |SAN LUIS,                     |AZ                      |
# |TUC               |TUCSON,                       |AZ                      |
# |YUI               |YUMA,                         |AZ                      |
# |YUM               |YUMA,                         |AZ                      |
# |FBA               |FREEPORT,                     |BAHAMAS                 |
# |NAS               |NASSAU,                       |BAHAMAS                 |
# |BDA               |KINDLEY FIELD,                |BERMUDA                 |
# |HAM               |HAMILTON,                     |BERMUDA                 |
# |CRQ               |CARAVELAS, BA #ARPT,          |BRAZIL                  |
# |GRU               |GUARULHOS INTL, SAO PAULO,    |BRAZIL                  |
# |AND               |ANDRADE,                      |CA                      |
# |BFL               |MEADOWS FIELD - BAKERSFIELD,  |CA                      |
# |BLT               |PACIFIC, HWY. STATION,        |CA                      |
# |BUR               |BURBANK,                      |CA                      |
# |CAL               |CALEXICO,                     |CA                      |
# |CAO               |CAMPO,                        |CA                      |
# |FRE               |FRESNO,                       |CA                      |
# |ICP               |IMPERIAL COUNTY,              |CA                      |
# |LNB               |LONG BEACH,                   |CA                      |
# |LOS               |LOS ANGELES,                  |CA                      |
# |OAK               |OAKLAND,                      |CA                      |
# |ONT               |ONTARIO,                      |CA                      |
# |OTM               |OTAY MESA,                    |CA                      |
# |PSP               |PALM SPRINGS,                 |CA                      |
# |RIV               |RIVERSIDE,                    |CA                      |
# |SAA               |SANTA ANA,                    |CA                      |
# |SAC               |SACRAMENTO,                   |CA                      |
# |SDP               |SAN DIEGO,                    |CA                      |
# |SFR               |SAN FRANCISCO,                |CA                      |
# |SLI               |SAN LUIS OBISPO,              |CA                      |
# |SLO               |SAN LUIS OBISPO,              |CA                      |
# |SLS               |SALINAS,                      |CA                      |
# |SNJ               |SAN JOSE,                     |CA                      |
# |SPC               |SAN PEDRO,                    |CA                      |
# |STO               |STOCKTON,                     |CA                      |
# |SYS               |SAN YSIDRO,                   |CA                      |
# |TEC               |TECATE,                       |CA                      |
# |TRV               |TRAVIS-AFB,                   |CA                      |
# |VNY               |VAN NUYS,                     |CA                      |
# |NCA               |NORTH CAICOS, TURK &          |CAIMAN                  |
# |CLG               |CALGARY,                      |CANADA                  |
# |EDA               |EDMONTON,                     |CANADA                  |
# |MON               |MONTREAL,                     |CANADA                  |
# |OTT               |OTTAWA,                       |CANADA                  |
# |TOR               |TORONTO,                      |CANADA                  |
# |VCV               |VANCOUVER,                    |CANADA                  |
# |VIC               |VICTORIA,                     |CANADA                  |
# |WIN               |WINNIPEG,                     |CANADA                  |
# |YHC               |HAKAI PASS,                   |CANADA                  |
# |YXE               |SASKATOON,                    |CANADA                  |
# |APA               |ARAPAHOE COUNTY,              |CO                      |
# |ASE               |ASPEN,                        |CO                      |
# |COS               |COLORADO SPRINGS,             |CO                      |
# |DEN               |DENVER,                       |CO                      |
# |DRO               |LA PLATA - DURANGO,           |CO                      |
# |BOG               |BOGOTA, EL DORADO #ARPT,      |COLOMBIA                |
# |MDE               |MEDELLIN,                     |COLOMBIA                |
# |SRO               |SANTANA RAMOS #ARPT,          |COLOMBIA                |
# |BDL               |BRADLEY INTERNATIONAL,        |CT                      |
# |BGC               |BRIDGEPORT,                   |CT                      |
# |GRT               |GROTON,                       |CT                      |
# |HAR               |HARTFORD,                     |CT                      |
# |NWH               |NEW HAVEN,                    |CT                      |
# |NWL               |NEW LONDON,                   |CT                      |
# |TST               |NEWINGTON DATA CENTER TEST,   |CT                      |
# |HAL               |Halifax, NS,                  |Canada                  |
# |.GA               |No PORT                       |Code                    |
# |060               |No PORT                       |Code                    |
# |5T6               |No PORT                       |Code                    |
# |74S               |No PORT                       |Code                    |
# |A2A               |No PORT                       |Code                    |
# |ADU               |No PORT                       |Code                    |
# |AG                |No PORT                       |Code                    |
# |AKT               |No PORT                       |Code                    |
# |AMT               |No PORT                       |Code                    |
# |ASI               |No PORT                       |Code                    |
# |ATW               |No PORT                       |Code                    |
# |AUH               |No PORT                       |Code                    |
# |BCM               |No PORT                       |Code                    |
# |BKF               |No PORT                       |Code                    |
# |CHN               |No PORT                       |Code                    |
# |CLX               |No PORT                       |Code                    |
# |CP                |No PORT                       |Code                    |
# |CPX               |No PORT                       |Code                    |
# |CXO               |No PORT                       |Code                    |
# |DAY               |No PORT                       |Code                    |
# |DEC               |No PORT                       |Code                    |
# |DRV               |No PORT                       |Code                    |
# |EGE               |No PORT                       |Code                    |
# |FSC               |No PORT                       |Code                    |
# |FTB               |No PORT                       |Code                    |
# |GAC               |No PORT                       |Code                    |
# |GMT               |No PORT                       |Code                    |
# |GPI               |No PORT                       |Code                    |
# |JBQ               |No PORT                       |Code                    |
# |JFA               |No PORT                       |Code                    |
# |JIG               |No PORT                       |Code                    |
# |JMZ               |No PORT                       |Code                    |
# |LIT               |No PORT                       |Code                    |
# |MTH               |No PORT                       |Code                    |
# |NC8               |No PORT                       |Code                    |
# |NGL               |No PORT                       |Code                    |
# |NK                |No PORT                       |Code                    |
# |NYL               |No PORT                       |Code                    |
# |OAI               |No PORT                       |Code                    |
# |OGS               |No PORT                       |Code                    |
# |OLM               |No PORT                       |Code                    |
# |OSN               |No PORT                       |Code                    |
# |OTS               |No PORT                       |Code                    |
# |PCW               |No PORT                       |Code                    |
# |PFN               |No PORT                       |Code                    |
# |PHF               |No PORT                       |Code                    |
# |PLB               |No PORT                       |Code                    |
# |RYY               |No PORT                       |Code                    |
# |SCH               |No PORT                       |Code                    |
# |SP0               |No PORT                       |Code                    |
# |SUS               |No PORT                       |Code                    |
# |TIW               |No PORT                       |Code                    |
# |W55               |No PORT                       |Code                    |
# |WA5               |No PORT                       |Code                    |
# |WTR               |No PORT                       |Code                    |
# |X44               |No PORT                       |Code                    |
# |X96               |No PORT                       |Code                    |
# |XNA               |No PORT                       |Code                    |
# |Y62               |No PORT                       |Code                    |
# |YGF               |No PORT                       |Code                    |
# |WAS               |WASHINGTON                    |DC                      |
# |DOV               |DOVER AFB,                    |DE                      |
# |DVD               |DOVER-AFB,                    |DE                      |
# |WLL               |WILMINGTON,                   |DE                      |
# |MAA               |Abu                           |Dhabi                   |
# |UIO               |QUITO (MARISCAL SUCR),        |ECUADOR                 |
# |LGW               |WEST SUSSEX,                  |ENGLAND                 |
# |LHR               |MIDDLESEX,                    |ENGLAND                 |
# |BEI               |BEICA #ARPT,                  |ETHIOPIA                |
# |HIL               |SHILLAVO,                     |ETHIOPIA                |
# |APF               |NAPLES,                       |FL                      |
# |BOC               |BOCAGRANDE,                   |FL                      |
# |CAN               |CAPE CANAVERAL,               |FL                      |
# |DAB               |DAYTONA BEACH INTERNATIONAL,  |FL                      |
# |FMY               |FORT MYERS,                   |FL                      |
# |FPF               |FORT PIERCE,                  |FL                      |
# |FPR               |ST LUCIE COUNTY,              |FL                      |
# |FRN               |FERNANDINA,                   |FL                      |
# |FTL               |FORT LAUDERDALE,              |FL                      |
# |GNV               |J R ALISON MUNI - GAINESVILLE,|FL                      |
# |HUR               |HURLBURT FIELD,               |FL                      |
# |JAC               |JACKSONVILLE,                 |FL                      |
# |KEY               |KEY WEST,                     |FL                      |
# |LEE               |LEESBURG MUNICIPAL AIRPORT,   |FL                      |
# |MIA               |MIAMI,                        |FL                      |
# |MLB               |MELBOURNE,                    |FL                      |
# |OPF               |OPA LOCKA,                    |FL                      |
# |ORL               |ORLANDO,                      |FL                      |
# |PAN               |PANAMA CITY,                  |FL                      |
# |PCF               |PORT CANAVERAL,               |FL                      |
# |PEN               |PENSACOLA,                    |FL                      |
# |PEV               |PORT EVERGLADES,              |FL                      |
# |PSJ               |PORT ST JOE,                  |FL                      |
# |SAU               |ST AUGUSTINE,                 |FL                      |
# |SFB               |SANFORD,                      |FL                      |
# |SGJ               |ST AUGUSTINE ARPT,            |FL                      |
# |SPE               |ST PETERSBURG,                |FL                      |
# |SRQ               |BRADENTON - SARASOTA,         |FL                      |
# |TAM               |TAMPA,                        |FL                      |
# |WPB               |WEST PALM BEACH,              |FL                      |
# |AGS               |BUSH FIELD - AUGUSTA,         |GA                      |
# |ATL               |ATLANTA,                      |GA                      |
# |BRU               |BRUNSWICK,                    |GA                      |
# |SAV               |SAVANNAH,                     |GA                      |
# |FOU               |FOUGAMOU #ARPT,               |GABON                   |
# |AGA               |AGANA,                        |GU                      |
# |SPV               |PAPUA, NEW                    |GUINEA                  |
# |TOK               |TOROKINA #ARPT, PAPUA, NEW    |GUINEA                  |
# |HHW               |HONOLULU,                     |HI                      |
# |KOA               |KEAHOLE-KONA,                 |HI                      |
# |LIH               |LIHUE,                        |HI                      |
# |OGG               |KAHULUI - MAUI,               |HI                      |
# |SWB               |SWANTON, VT (BP - SECTOR      |HQ                      |
# |CID               |CEDAR RAPIDS/IOWA CITY,       |IA                      |
# |DSM               |DES MOINES,                   |IA                      |
# |BOI               |AIR TERM. (GOWEN FLD) BOISE,  |ID                      |
# |EPI               |EASTPORT,                     |ID                      |
# |IDA               |FANNING FIELD - IDAHO FALLS,  |ID                      |
# |PTL               |PORTHILL,                     |ID                      |
# |CHI               |CHICAGO,                      |IL                      |
# |DPA               |DUPAGE COUNTY,                |IL                      |
# |MLI               |MOLINE,                       |IL                      |
# |PIA               |GREATER PEORIA,               |IL                      |
# |RFD               |GREATER ROCKFORD,             |IL                      |
# |SPI               |CAPITAL - SPRINGFIELD,        |IL                      |
# |UGN               |MEMORIAL - WAUKEGAN,          |IL                      |
# |GAR               |GARY,                         |IN                      |
# |HMM               |HAMMOND,                      |IN                      |
# |INP               |INDIANAPOLIS,                 |IN                      |
# |MRL               |MERRILLVILLE,                 |IN                      |
# |SBN               |SOUTH BEND,                   |IN                      |
# |LAH               |LABUHA ARPT,                  |INDONESIA               |
# |MAL               |MANGOLE ARPT,                 |INDONESIA               |
# |DUB               |DUBLIN,                       |IRELAND                 |
# |SHA               |SHANNON,                      |IRELAND                 |
# |GCM               |GRAND CAYMAN, CAYMAN          |ISLAND                  |
# |RIT               |ROME,                         |ITALY                   |
# |IWA               |INVALID - IWAKUNI,            |JAPAN                   |
# |NBO               |NAIROBI,                      |KENYA                   |
# |ICN               |INCHON, SEOUL                 |KOREA                   |
# |ICT               |MID-CONTINENT - WITCHITA,     |KS                      |
# |LEX               |BLUE GRASS - LEXINGTON,       |KY                      |
# |LOU               |LOUISVILLE,                   |KY                      |
# |BTN               |BATON ROUGE,                  |LA                      |
# |LAK               |LAKE CHARLES,                 |LA                      |
# |LKC               |LAKE CHARLES,                 |LA                      |
# |MGC               |MORGAN CITY,                  |LA                      |
# |MLU               |MONROE,                       |LA                      |
# |NOL               |NEW ORLEANS,                  |LA                      |
# |BED               |HANSCOM FIELD - BEDFORD,      |MA                      |
# |BOS               |BOSTON,                       |MA                      |
# |GLO               |GLOUCESTER,                   |MA                      |
# |ADW               |ANDREWS AFB,                  |MD                      |
# |BAL               |BALTIMORE,                    |MD                      |
# |MKG               |MUSKEGON,                     |MD                      |
# |PAX               |PATUXENT RIVER,               |MD                      |
# |BCK               |BUCKPORT,                     |ME                      |
# |BGM               |BANGOR,                       |ME                      |
# |BHM               |BAR HARBOR,                   |ME                      |
# |BOO               |BOOTHBAY HARBOR,              |ME                      |
# |BWM               |BRIDGEWATER,                  |ME                      |
# |CLS               |CALAIS,                       |ME                      |
# |COB               |COBURN GORE,                  |ME                      |
# |CRB               |CARIBOU,                      |ME                      |
# |EPM               |EASTPORT,                     |ME                      |
# |EPT               |EASTPORT MUNICIPAL,           |ME                      |
# |EST               |EASTCOURT,                    |ME                      |
# |FOR               |FOREST CITY,                  |ME                      |
# |FTF               |FORT FAIRFIELD,               |ME                      |
# |FTK               |FORT KENT,                    |ME                      |
# |HML               |HAMIIN,                       |ME                      |
# |HTM               |HOULTON,                      |ME                      |
# |JKM               |JACKMAN,                      |ME                      |
# |LIM               |LIMESTONE,                    |ME                      |
# |LUB               |LUBEC,                        |ME                      |
# |MAD               |MADAWASKA,                    |ME                      |
# |POM               |PORTLAND,                     |ME                      |
# |RGM               |RANGELEY,                     |ME                      |
# |SBR               |SOUTH BREWER,                 |ME                      |
# |SPA               |ST PAMPILE,                   |ME                      |
# |SRL               |ST AURELIE,                   |ME                      |
# |VCB               |VANCEBORO,                    |ME                      |
# |VNB               |VAN BUREN,                    |ME                      |
# |CUN               |CANCUN,                       |MEXICO                  |
# |SLP               |SAN LUIS POTOSI #ARPT,        |MEXICO                  |
# |VER               |VERACRUZ,                     |MEXICO                  |
# |AGN               |ALGONAC,                      |MI                      |
# |ALP               |ALPENA,                       |MI                      |
# |BCY               |BAY CITY,                     |MI                      |
# |DET               |DETROIT,                      |MI                      |
# |GRO               |GROSSE ISLE,                  |MI                      |
# |GRP               |GRAND RAPIDS,                 |MI                      |
# |ISL               |ISLE ROYALE,                  |MI                      |
# |MRC               |MARINE CITY,                  |MI                      |
# |MRY               |MARYSVILLE,                   |MI                      |
# |PHU               |PORT HURON,                   |MI                      |
# |PTK               |OAKLAND COUNTY - PONTIAC,     |MI                      |
# |RBT               |ROBERTS LANDING,              |MI                      |
# |SAG               |SAGINAW,                      |MI                      |
# |SCL               |ST CLAIR,                     |MI                      |
# |SSM               |SAULT STE. MARIE,             |MI                      |
# |YIP               |WILLOW RUN - YPSILANTI,       |MI                      |
# |48Y               |PINECREEK BORDER ARPT,        |MN                      |
# |BAU               |BAUDETTE,                     |MN                      |
# |CAR               |CARIBOU MUNICIPAL AIRPORT,    |MN                      |
# |CRA               |CRANE LAKE,                   |MN                      |
# |DUL               |DULUTH,                       |MN                      |
# |ELY               |ELY,                          |MN                      |
# |GPM               |GRAND PORTAGE,                |MN                      |
# |GTF               |Collapsed into INT,           |MN                      |
# |INL               |Collapsed into INT,           |MN                      |
# |INT               |INT''L FALLS,                 |MN                      |
# |LAN               |LANCASTER,                    |MN                      |
# |LIN               |NORTHERN SVC CENTER,          |MN                      |
# |MIC               |CRYSTAL MUNICIPAL AIRPORT,    |MN                      |
# |MSP               |MINN./ST PAUL,                |MN                      |
# |NOY               |NOYES,                        |MN                      |
# |PIN               |PINE CREEK,                   |MN                      |
# |RAN               |RAINER,                       |MN                      |
# |ROS               |ROSEAU,                       |MN                      |
# |RST               |ROCHESTER,                    |MN                      |
# |SPM               |ST PAUL,                      |MN                      |
# |SVC               |GRANT COUNTY - SILVER CITY,   |MN                      |
# |WAR               |WARROAD,                      |MN                      |
# |WSB               |WARROAD INTL, SPB,            |MN                      |
# |KAN               |KANSAS CITY,                  |MO                      |
# |SGF               |SPRINGFIELD-BRANSON,          |MO                      |
# |STL               |ST LOUIS,                     |MO                      |
# |GPT               |BILOXI REGIONAL,              |MS                      |
# |GTR               |GOLDEN TRIANGLE LOWNDES CNTY, |MS                      |
# |GUL               |GULFPORT,                     |MS                      |
# |JAN               |THOMPSON FIELD - JACKSON,     |MS                      |
# |PAS               |PASCAGOULA,                   |MS                      |
# |BIL               |BILLINGS,                     |MT                      |
# |BTM               |BUTTE,                        |MT                      |
# |BZN               |GALLATIN FIELD - BOZEMAN,     |MT                      |
# |CHF               |CHIEF MT,                     |MT                      |
# |CTB               |CUT BANK MUNICIPAL,           |MT                      |
# |CUT               |CUT BANK,                     |MT                      |
# |DLB               |DEL BONITA,                   |MT                      |
# |EUR               |EUREKA,                       |MT                      |
# |FCA               |GLACIER NATIONAL PARK,        |MT                      |
# |GGW               |GLASGOW,                      |MT                      |
# |GRE               |GREAT FALLS,                  |MT                      |
# |HEL               |HELENA,                       |MT                      |
# |HVR               |HAVRE,                        |MT                      |
# |KAL               |KALISPEL,                     |MT                      |
# |LWT               |LEWISTON,                     |MT                      |
# |MGM               |MORGAN,                       |MT                      |
# |OPH               |OPHEIM,                       |MT                      |
# |PIE               |PIEGAN,                       |MT                      |
# |RAY               |RAYMOND,                      |MT                      |
# |ROO               |ROOSVILLE,                    |MT                      |
# |SCO               |SCOBEY,                       |MT                      |
# |SWE               |SWEETGTASS,                   |MT                      |
# |TRL               |TRIAL CREEK,                  |MT                      |
# |TUR               |TURNER,                       |MT                      |
# |WCM               |WILLOW CREEK,                 |MT                      |
# |WHI               |WHITETAIL,                    |MT                      |
# |WHM               |WILD HORSE,                   |MT                      |
# |GDL               |GUADALAJARA, MIGUEL HIDAL,    |MX                      |
# |HMO               |GEN PESQUEIRA GARCIA,         |MX                      |
# |MEX               |JUAREZ INTL, MEXICO CITY,     |MX                      |
# |MTY               |GEN M. ESCOBEDO, Monterrey,   |MX                      |
# |ZZZ               |MEXICO Land (Banco de         |Mexico                  |
# |CLT               |CHARLOTTE,                    |NC                      |
# |FAY               |FAYETTEVILLE,                 |NC                      |
# |FOP               |MORRIS FIELDS AAF,            |NC                      |
# |GSO               |PIEDMONT TRIAD INTL AIRPORT,  |NC                      |
# |MRH               |MOREHEAD CITY,                |NC                      |
# |RDU               |RALEIGH/DURHAM,               |NC                      |
# |SSC               |SHAW AFB - SUMTER,            |NC                      |
# |WIL               |WILMINGTON,                   |NC                      |
# |AMB               |AMBROSE,                      |ND                      |
# |ANT               |ANTLER,                       |ND                      |
# |CRY               |CARBURY,                      |ND                      |
# |DNS               |DUNSEITH,                     |ND                      |
# |FAR               |FARGO,                        |ND                      |
# |FRT               |FORTUNA,                      |ND                      |
# |GRF               |GRAND FORKS,                  |ND                      |
# |HNN               |HANNAH,                       |ND                      |
# |HNS               |HANSBORO,                     |ND                      |
# |MAI               |MAIDA,                        |ND                      |
# |MND               |MINOT,                        |ND                      |
# |NEC               |NECHE,                        |ND                      |
# |NOO               |NOONAN,                       |ND                      |
# |NRG               |NORTHGATE,                    |ND                      |
# |PEM               |PEMBINA,                      |ND                      |
# |SAR               |SARLES,                       |ND                      |
# |SHR               |SHERWOOD,                     |ND                      |
# |SJO               |ST JOHN,                      |ND                      |
# |WAL               |WALHALLA,                     |ND                      |
# |WHO               |WESTHOPE,                     |ND                      |
# |WND               |WILLISTON,                    |ND                      |
# |OMA               |OMAHA,                        |NE                      |
# |AMS               |AMSTERDAM-SCHIPHOL,           |NETHERLANDS             |
# |LEB               |LEBANON,                      |NH                      |
# |MHT               |MANCHESTER,                   |NH                      |
# |PNH               |PITTSBURG,                    |NH                      |
# |PSM               |PORTSMOUTH,                   |NH                      |
# |ACY               |POMONA FIELD - ATLANTIC CITY, |NJ                      |
# |BYO               |BAYONNE,                      |NJ                      |
# |CNJ               |CAMDEN,                       |NJ                      |
# |HOB               |HOBOKEN,                      |NJ                      |
# |JER               |JERSEY CITY,                  |NJ                      |
# |MMU               |MORRISTOWN,                   |NJ                      |
# |NEW               |NEWARK/TETERBORO,             |NJ                      |
# |PER               |PERTH AMBOY,                  |NJ                      |
# |WRI               |MC GUIRE AFB - WRIGHTSOWN,    |NJ                      |
# |ABQ               |ALBUQUERQUE,                  |NM                      |
# |ALA               |ALAMAGORDO,                   |NM                      |
# |ANP               |ANTELOPE WELLS,               |NM                      |
# |CDD               |CRANE LAKE - ST. LOUIS CNTY,  |NM                      |
# |COL               |COLUMBUS,                     |NM                      |
# |CRL               |CARLSBAD,                     |NM                      |
# |DNM               |DEMING,                       |NM                      |
# |LAS               |LAS CRUCES,                   |NM                      |
# |LOB               |LORDSBURG,                    |NM                      |
# |RUI               |RUIDOSO,                      |NM                      |
# |STR               |SANTA TERESA,                 |NM                      |
# |PDN               |PASO DEL                      |NORTE                   |
# |FLX               |FALLON MUNICIPAL AIRPORT,     |NV                      |
# |LVG               |LAS VEGAS,                    |NV                      |
# |REN               |RENO,                         |NV                      |
# |RNO               |CANNON INTL - RENO/TAHOE,     |NV                      |
# |ALB               |ALBANY,                       |NY                      |
# |AXB               |ALEXANDRIA BAY,               |NY                      |
# |BUF               |BUFFALO,                      |NY                      |
# |CAP               |CAPE VINCENT,                 |NY                      |
# |CHM               |CHAMPLAIN,                    |NY                      |
# |CHT               |CHATEAUGAY,                   |NY                      |
# |CLA               |CLAYTON,                      |NY                      |
# |CNC               |CANNON CORNERS,               |NY                      |
# |CNH               |CANNON CORNERS,               |NY                      |
# |ELM               |REGIONAL ARPT - HORSEHEAD,    |NY                      |
# |FOK               |SUFFOLK COUNTY,               |NY                      |
# |FTC               |FORT COVINGTON,               |NY                      |
# |HPN               |WESTCHESTER - WHITE PLAINS,   |NY                      |
# |LAG               |LA GUARDIA,                   |NY                      |
# |LEW               |LEWISTON,                     |NY                      |
# |MAG               |MCGUIRE AFB,                  |NY                      |
# |MAS               |MASSENA,                      |NY                      |
# |MOO               |MOORES,                       |NY                      |
# |MRR               |MORRISTOWN,                   |NY                      |
# |NIA               |NIAGARA FALLS,                |NY                      |
# |NYC               |NEW YORK,                     |NY                      |
# |OGD               |OGDENSBURG,                   |NY                      |
# |OSW               |OSWEGO,                       |NY                      |
# |PBB               |PEACE BRIDGE,                 |NY                      |
# |RME               |ROME,                         |NY                      |
# |ROC               |ROCHESTER,                    |NY                      |
# |ROU               |ROUSES POINT,                 |NY                      |
# |SWF               |STEWART - ORANGE CNTY,        |NY                      |
# |SYR               |SYRACUSE,                     |NY                      |
# |THO               |THOUSAND ISLAND BRIDGE,       |NY                      |
# |TRO               |TROUT RIVER,                  |NY                      |
# |WAT               |WATERTOWN,                    |NY                      |
# |WRB               |WHIRLPOOL BRIDGE,             |NY                      |
# |YOU               |YOUNGSTOWN,                   |NY                      |
# |AKR               |AKRON,                        |OH                      |
# |ATB               |ASHTABULA,                    |OH                      |
# |CAK               |AKRON,                        |OH                      |
# |CIN               |CINCINNATI,                   |OH                      |
# |CLE               |CLEVELAND,                    |OH                      |
# |CLM               |COLUMBUS,                     |OH                      |
# |LOR               |LORAIN,                       |OH                      |
# |MBO               |MARBLE HEADS,                 |OH                      |
# |PUT               |PUT-IN-BAY,                   |OH                      |
# |SDY               |SANDUSKY,                     |OH                      |
# |TOL               |TOLEDO,                       |OH                      |
# |OKC               |OKLAHOMA CITY,                |OK                      |
# |TUL               |TULSA,                        |OK                      |
# |AST               |ASTORIA,                      |OR                      |
# |COO               |COOS BAY,                     |OR                      |
# |HIO               |HILLSBORO,                    |OR                      |
# |MED               |MEDFORD,                      |OR                      |
# |NPT               |NEWPORT,                      |OR                      |
# |POO               |PORTLAND,                     |OR                      |
# |RDM               |ROBERTS FIELDS - REDMOND,     |OR                      |
# |ERI               |ERIE,                         |PA                      |
# |HSB               |HARRISONBURG,                 |PA                      |
# |MDT               |HARRISBURG,                   |PA                      |
# |PHI               |PHILADELPHIA,                 |PA                      |
# |PIT               |PITTSBURG,                    |PA                      |
# |PTY               |OMAR TORRIJOS,                |PANAMA                  |
# |UNK               |UNKNOWN                       |POE                     |
# |AGU               |AGUADILLA,                    |PR                      |
# |BQN               |BORINQUEN - AGUADILLO,        |PR                      |
# |ENS               |ENSENADA,                     |PR                      |
# |FAJ               |FAJARDO,                      |PR                      |
# |HUM               |HUMACAO,                      |PR                      |
# |JCP               |CULEBRA - BENJAMIN RIVERA,    |PR                      |
# |JOB               |JOBOS,                        |PR                      |
# |MAY               |MAYAGUEZ,                     |PR                      |
# |PON               |PONCE,                        |PR                      |
# |PSE               |PONCE-MERCEDITA,              |PR                      |
# |SAJ               |SAN JUAN,                     |PR                      |
# |VQS               |VIEQUES-ARPT,                 |PR                      |
# |PEK               |BEIJING CAPITAL INTL,         |PRC                     |
# |XXX               |NOT                           |REPORTED/UNKNOWN        |
# |PRO               |PROVIDENCE,                   |RI                      |
# |PVD               |THEODORE FRANCIS - WARWICK,   |RI                      |
# |CND               |KOGALNICEANU,                 |ROMANIA                 |
# |SAN               |SAN SALVADOR, EL              |SALVADOR                |
# |CAE               |COLUMBIA,                     |SC                      |
# |CHL               |CHARLESTON,                   |SC                      |
# |GEO               |GEORGETOWN,                   |SC                      |
# |GRR               |GREER,                        |SC                      |
# |GSP               |GREENVILLE,                   |SC                      |
# |MYR               |MYRTLE BEACH,                 |SC                      |
# |HON               |HOWES REGIONAL ARPT - HURON,  |SD                      |
# |SPF               |BLACK HILLS, SPEARFISH,       |SD                      |
# |888               |UNIDENTIFED AIR /             |SEAPORT                 |
# |SAI               |SAIPAN,                       |SPN                     |
# |BAN               |BANKOK,                       |THAILAND                |
# |SNO               |SAKON NAKHON #ARPT,           |THAILAND                |
# |MEM               |MEMPHIS,                      |TN                      |
# |NSV               |NASHVILLE,                    |TN                      |
# |TRI               |TRI CITY ARPT,                |TN                      |
# |TYS               |MC GHEE TYSON - ALCOA,        |TN                      |
# |ADS               |ADDISON AIRPORT- ADDISON,     |TX                      |
# |ADT               |AMISTAD DAM,                  |TX                      |
# |AFW               |FORT WORTH ALLIANCE,          |TX                      |
# |ANZ               |ANZALDUAS,                    |TX                      |
# |AUS               |AUSTIN,                       |TX                      |
# |BBP               |BIG BEND PARK,                |TX                      |
# |BEA               |BEAUMONT,                     |TX                      |
# |BOA               |BRIDGE OF AMERICAS,           |TX                      |
# |BRO               |BROWNSVILLE,                  |TX                      |
# |BTC               |BP TACTICAL UNIT,             |TX                      |
# |CRP               |CORPUS CHRISTI,               |TX                      |
# |DAL               |DALLAS,                       |TX                      |
# |DLR               |DEL RIO,                      |TX                      |
# |DNA               |DONNA,                        |TX                      |
# |EGP               |EAGLE PASS,                   |TX                      |
# |ELP               |EL PASO,                      |TX                      |
# |FAB               |FABENS,                       |TX                      |
# |FAL               |FALCON HEIGHTS,               |TX                      |
# |FPT               |FREEPORT,                     |TX                      |
# |FTH               |FORT HANCOCK,                 |TX                      |
# |GAL               |GALVESTON,                    |TX                      |
# |HID               |HIDALGO,                      |TX                      |
# |HLG               |HARLINGEN,                    |TX                      |
# |HOU               |HOUSTON,                      |TX                      |
# |IND               |LOS INDIOS,                   |TX                      |
# |ISB               |PORT ISABEL,                  |TX                      |
# |LAR               |LAREDO,                       |TX                      |
# |LCB               |LAREDO COLUMBIA BRIDGE,       |TX                      |
# |LLB               |JUAREZ-LINCOLN BRIDGE,        |TX                      |
# |LOI               |LOS INDIOS,                   |TX                      |
# |LRN               |LAREDO NORTH,                 |TX                      |
# |LSE               |LOS EBANOS,                   |TX                      |
# |MAF               |ODESSA REGIONAL,              |TX                      |
# |MAR               |MARFA,                        |TX                      |
# |MCA               |MCALLEN,                      |TX                      |
# |MRS               |MARFA,                        |TX                      |
# |PAR               |PORT ARTHUR,                  |TX                      |
# |PGR               |PROGRESO,                     |TX                      |
# |PHR               |PHARR,                        |TX                      |
# |POE               |PORT OF EL PASO,              |TX                      |
# |PRE               |PRESIDIO,                     |TX                      |
# |RIO               |RIO GRANDE CITY,              |TX                      |
# |ROM               |ROMA,                         |TX                      |
# |SCC               |BP SPEC COORD. CTR,           |TX                      |
# |SGR               |HULL FIELD, SUGAR LAND ARPT,  |TX                      |
# |SNA               |SAN ANTONIO,                  |TX                      |
# |SNN               |SANDERSON,                    |TX                      |
# |VIB               |VETERAN INTL BRIDGE,          |TX                      |
# |YSL               |YSLETA,                       |TX                      |
# |MVD               |CARRASCO,                     |URUGUAY                 |
# |LGU               |CACHE AIRPORT - LOGAN,        |UT                      |
# |SLC               |SALT LAKE CITY,               |UT                      |
# |CHO               |ALBEMARLE CHARLOTTESVILLE,    |VA                      |
# |DAA               |DAVISON AAF - FAIRFAX CNTY,   |VA                      |
# |HEF               |MANASSAS,                     |VA                      |
# |HOP               |HOPEWELL,                     |VA                      |
# |NOR               |NORFOLK,                      |VA                      |
# |NWN               |NEWPORT,                      |VA                      |
# |RCM               |RICHMOND,                     |VA                      |
# |CHA               |CHARLOTTE AMALIE,             |VI                      |
# |CHR               |CHRISTIANSTED,                |VI                      |
# |CRU               |CRUZ BAY, ST JOHN,            |VI                      |
# |FRK               |FREDERIKSTED,                 |VI                      |
# |STT               |ST THOMAS,                    |VI                      |
# |ABG               |ALBURG,                       |VT                      |
# |ABS               |ALBURG SPRINGS,               |VT                      |
# |BEB               |BEEBE PLAIN,                  |VT                      |
# |BEE               |BEECHER FALLS,                |VT                      |
# |BRG               |BURLINGTON,                   |VT                      |
# |CNA               |CANAAN,                       |VT                      |
# |DER               |DERBY LINE,                   |VT                      |
# |ERC               |EAST RICHFORD,                |VT                      |
# |HIG               |HIGHGATE SPRINGS,             |VT                      |
# |MOR               |MORSES LINE,                  |VT                      |
# |NPV               |NEWPORT,                      |VT                      |
# |NRN               |NORTON,                       |VT                      |
# |NRT               |NORTH TROY,                   |VT                      |
# |PIV               |PINNACLE ROAD,                |VT                      |
# |RIF               |RICHFORT,                     |VT                      |
# |STA               |ST ALBANS,                    |VT                      |
# |WBE               |WEST BERKSHIRE,               |VT                      |
# |ABE               |ABERDEEN,                     |WA                      |
# |ANA               |ANACORTES,                    |WA                      |
# |BEL               |BELLINGHAM,                   |WA                      |
# |BLA               |BLAINE,                       |WA                      |
# |BWA               |BOUNDARY,                     |WA                      |
# |CUR               |CURLEW,                       |WA                      |
# |DVL               |DANVILLE,                     |WA                      |
# |EVE               |EVERETT,                      |WA                      |
# |FER               |FERRY,                        |WA                      |
# |FRI               |FRIDAY HARBOR,                |WA                      |
# |FWA               |FRONTIER,                     |WA                      |
# |KLM               |KALAMA,                       |WA                      |
# |LAU               |LAURIER,                      |WA                      |
# |LON               |LONGVIEW,                     |WA                      |
# |LYN               |LYNDEN,                       |WA                      |
# |MET               |METALINE FALLS,               |WA                      |
# |MWH               |MOSES LAKE GRANT COUNTY ARPT, |WA                      |
# |NEA               |NEAH BAY,                     |WA                      |
# |NIG               |NIGHTHAWK,                    |WA                      |
# |OLY               |OLYMPIA,                      |WA                      |
# |ORO               |OROVILLE,                     |WA                      |
# |PIR               |POINT ROBERTS,                |WA                      |
# |PNG               |PORT ANGELES,                 |WA                      |
# |PSC               |TRI-CITIES - PASCO,           |WA                      |
# |PTO               |PORT TOWNSEND,                |WA                      |
# |PWB               |PASCO,                        |WA                      |
# |SEA               |SEATTLE,                      |WA                      |
# |SPO               |SPOKANE,                      |WA                      |
# |SUM               |SUMAS,                        |WA                      |
# |TAC               |TACOMA,                       |WA                      |
# |VAN               |VANCOUVER,                    |WA                      |
# |BLI               |BELLINGHAM,                   |WASHINGTON              |
# |AGM               |ALGOMA,                       |WI                      |
# |BAY               |BAYFIELD,                     |WI                      |
# |GRB               |GREEN BAY,                    |WI                      |
# |MIL               |MILWAUKEE,                    |WI                      |
# |MNW               |MANITOWOC,                    |WI                      |
# |MSN               |TRUAX FIELD - DANE COUNTY,    |WI                      |
# |BLF               |MERCER COUNTY,                |WV                      |
# |CHS               |CHARLESTON,                   |WV                      |
# |CLK               |CLARKSBURG,                   |WV                      |
# |CSP               |CASPER,                       |WY                      |
# |LND               |LANDER,                       |WY                      |
# +------------------+------------------------------+------------------------+

# %%
# Difference of the remaining entries ==> 660 - 582 = 78
df_st_immigration_airports \
    .join(df_st_immigration_airports_regex_cleaned,
          df_st_immigration_airports.st_ia_airport_code == df_st_immigration_airports_regex_cleaned.st_ia_airport_code,
          'left_anti')  \
    .show(10000, False)
# Out:
# +------------------+---------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name   |st_ia_airport_state_code|
# +------------------+---------------------+------------------------+
# |BUS               |Collapsed (BUF)      |06/15                   |
# |FRG               |Collapsed (FOK)      |06/15                   |
# |HRL               |Collapsed (HLG)      |06/15                   |
# |IAG               |Collapsed (NIA)      |06/15                   |
# |ISP               |Collapsed (FOK)      |06/15                   |
# |JSJ               |Collapsed (SAJ)      |06/15                   |
# |PHN               |Collapsed (PHU)      |06/15                   |
# |STN               |Collapsed (STR)      |06/15                   |
# |T01               |Collapsed (SEA)      |06/15                   |
# |VMB               |Collapsed (VNB)      |06/15                   |
# |MAP               |MARIPOSA             |AZ                      |
# |.GA               |No PORT              |Code                    |
# |060               |No PORT              |Code                    |
# |5T6               |No PORT              |Code                    |
# |74S               |No PORT              |Code                    |
# |A2A               |No PORT              |Code                    |
# |ADU               |No PORT              |Code                    |
# |AG                |No PORT              |Code                    |
# |AKT               |No PORT              |Code                    |
# |AMT               |No PORT              |Code                    |
# |ASI               |No PORT              |Code                    |
# |ATW               |No PORT              |Code                    |
# |AUH               |No PORT              |Code                    |
# |BCM               |No PORT              |Code                    |
# |BKF               |No PORT              |Code                    |
# |CHN               |No PORT              |Code                    |
# |CLX               |No PORT              |Code                    |
# |CP                |No PORT              |Code                    |
# |CPX               |No PORT              |Code                    |
# |CXO               |No PORT              |Code                    |
# |DAY               |No PORT              |Code                    |
# |DEC               |No PORT              |Code                    |
# |DRV               |No PORT              |Code                    |
# |EGE               |No PORT              |Code                    |
# |FSC               |No PORT              |Code                    |
# |FTB               |No PORT              |Code                    |
# |GAC               |No PORT              |Code                    |
# |GMT               |No PORT              |Code                    |
# |GPI               |No PORT              |Code                    |
# |JBQ               |No PORT              |Code                    |
# |JFA               |No PORT              |Code                    |
# |JIG               |No PORT              |Code                    |
# |JMZ               |No PORT              |Code                    |
# |LIT               |No PORT              |Code                    |
# |MTH               |No PORT              |Code                    |
# |NC8               |No PORT              |Code                    |
# |NGL               |No PORT              |Code                    |
# |NK                |No PORT              |Code                    |
# |NYL               |No PORT              |Code                    |
# |OAI               |No PORT              |Code                    |
# |OGS               |No PORT              |Code                    |
# |OLM               |No PORT              |Code                    |
# |OSN               |No PORT              |Code                    |
# |OTS               |No PORT              |Code                    |
# |PCW               |No PORT              |Code                    |
# |PFN               |No PORT              |Code                    |
# |PHF               |No PORT              |Code                    |
# |PLB               |No PORT              |Code                    |
# |RYY               |No PORT              |Code                    |
# |SCH               |No PORT              |Code                    |
# |SP0               |No PORT              |Code                    |
# |SUS               |No PORT              |Code                    |
# |TIW               |No PORT              |Code                    |
# |W55               |No PORT              |Code                    |
# |WA5               |No PORT              |Code                    |
# |WTR               |No PORT              |Code                    |
# |X44               |No PORT              |Code                    |
# |X96               |No PORT              |Code                    |
# |XNA               |No PORT              |Code                    |
# |Y62               |No PORT              |Code                    |
# |YGF               |No PORT              |Code                    |
# |WAS               |WASHINGTON           |DC                      |
# |MAA               |Abu                  |Dhabi                   |
# |ZZZ               |MEXICO Land (Banco de|Mexico                  |
# |PDN               |PASO DEL             |NORTE                   |
# |UNK               |UNKNOWN              |POE                     |
# |XXX               |NOT                  |REPORTED/UNKNOWN        |
# |888               |UNIDENTIFED AIR /    |SEAPORT                 |
# +------------------+---------------------+------------------------+

# %%
# correct all entries that are not error-free as expected
df_st_immigration_airports = df_st_immigration_airports \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r'Collapsed \(\w+\)|No PORT|UNKNOWN', 'Invalid Airport Entry').alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r'06/15|Code|POE', 'Invalid State Code').alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"^DERBY LINE,.*", "DERBY LINE, VT (RT. 5)").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"5", "VT").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"^LOUIS BOTHA, SOUTH", "LOUIS BOTHA").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"AFRICA", "SOUTH AFRICA").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r",", "").alias("st_ia_airport_name"),
            "st_ia_airport_state_code") \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"^PASO DEL", "PASO DEL NORTE").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"NORTE", "TX").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"^UNIDENTIFED AIR /?", "Invalid Airport Entry").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"^SEAPORT?", "Invalid State Code").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"Abu", "Abu Dhabi").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"Dhabi", "Invalid State Code").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"DOVER-AFB", "Invalid Airport Entry").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"DE", "Invalid State Code").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"NOT REPORTED/UNKNOWNGALES", "NOGALES").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"AZ", "AZ").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"^NOT", "Invalid Airport Entry").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"REPORTED/UNKNOWN", "Invalid State Code").alias("st_ia_airport_state_code")) \
    .select("st_ia_airport_code",
            F.regexp_replace('st_ia_airport_name', r"INVALID - IWAKUNI", "IWAKUNI").alias("st_ia_airport_name"),
            F.regexp_replace("st_ia_airport_state_code", r"JAPAN", "JAPAN").alias("st_ia_airport_state_code")) \
    .sort("st_ia_airport_name", "st_ia_airport_code")

print(df_st_immigration_airports.count())
df_st_immigration_airports.show(1000, False)
# Out:
# 660
# +------------------+-----------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name           |st_ia_airport_state_code|
# +------------------+-----------------------------+------------------------+
# |ABE               |ABERDEEN                     |WA                      |
# |ADS               |ADDISON AIRPORT- ADDISON     |TX                      |
# |AGA               |AGANA                        |GU                      |
# |AGU               |AGUADILLA                    |PR                      |
# |BOI               |AIR TERM. (GOWEN FLD) BOISE  |ID                      |
# |AKR               |AKRON                        |OH                      |
# |CAK               |AKRON                        |OH                      |
# |ALA               |ALAMAGORDO                   |NM                      |
# |ALB               |ALBANY                       |NY                      |
# |CHO               |ALBEMARLE CHARLOTTESVILLE    |VA                      |
# |ABQ               |ALBUQUERQUE                  |NM                      |
# |ABG               |ALBURG                       |VT                      |
# |ABS               |ALBURG SPRINGS               |VT                      |
# |ALC               |ALCAN                        |AK                      |
# |AXB               |ALEXANDRIA BAY               |NY                      |
# |AGM               |ALGOMA                       |WI                      |
# |AGN               |ALGONAC                      |MI                      |
# |ALP               |ALPENA                       |MI                      |
# |AMB               |AMBROSE                      |ND                      |
# |ADT               |AMISTAD DAM                  |TX                      |
# |AMS               |AMSTERDAM-SCHIPHOL           |NETHERLANDS             |
# |ANA               |ANACORTES                    |WA                      |
# |ANC               |ANCHORAGE                    |AK                      |
# |AND               |ANDRADE                      |CA                      |
# |ADW               |ANDREWS AFB                  |MD                      |
# |ANP               |ANTELOPE WELLS               |NM                      |
# |ANT               |ANTLER                       |ND                      |
# |ANZ               |ANZALDUAS                    |TX                      |
# |APA               |ARAPAHOE COUNTY              |CO                      |
# |ARB               |ARUBA NETH                   |ANTILLES                |
# |ATB               |ASHTABULA                    |OH                      |
# |ASE               |ASPEN                        |CO                      |
# |AST               |ASTORIA                      |OR                      |
# |ATL               |ATLANTA                      |GA                      |
# |AUS               |AUSTIN                       |TX                      |
# |MAA               |Abu Dhabi                    |Invalid State Code      |
# |BAR               |BAKER AAF - BAKER ISLAND     |AK                      |
# |BAL               |BALTIMORE                    |MD                      |
# |BGM               |BANGOR                       |ME                      |
# |BAN               |BANKOK                       |THAILAND                |
# |BHM               |BAR HARBOR                   |ME                      |
# |BTN               |BATON ROUGE                  |LA                      |
# |BAU               |BAUDETTE                     |MN                      |
# |BCY               |BAY CITY                     |MI                      |
# |BAY               |BAYFIELD                     |WI                      |
# |BYO               |BAYONNE                      |NJ                      |
# |BEA               |BEAUMONT                     |TX                      |
# |BEB               |BEEBE PLAIN                  |VT                      |
# |BEE               |BEECHER FALLS                |VT                      |
# |BEI               |BEICA #ARPT                  |ETHIOPIA                |
# |PEK               |BEIJING CAPITAL INTL         |PRC                     |
# |BEL               |BELLINGHAM                   |WA                      |
# |BLI               |BELLINGHAM                   |WASHINGTON              |
# |BBP               |BIG BEND PARK                |TX                      |
# |BIL               |BILLINGS                     |MT                      |
# |GPT               |BILOXI REGIONAL              |MS                      |
# |BHX               |BIRMINGHAM                   |AL                      |
# |SPF               |BLACK HILLS SPEARFISH        |SD                      |
# |BLA               |BLAINE                       |WA                      |
# |LEX               |BLUE GRASS - LEXINGTON       |KY                      |
# |BOC               |BOCAGRANDE                   |FL                      |
# |BOG               |BOGOTA EL DORADO #ARPT       |COLOMBIA                |
# |BOO               |BOOTHBAY HARBOR              |ME                      |
# |BQN               |BORINQUEN - AGUADILLO        |PR                      |
# |BOS               |BOSTON                       |MA                      |
# |BWA               |BOUNDARY                     |WA                      |
# |SCC               |BP SPEC COORD. CTR           |TX                      |
# |BTC               |BP TACTICAL UNIT             |TX                      |
# |SRQ               |BRADENTON - SARASOTA         |FL                      |
# |BDL               |BRADLEY INTERNATIONAL        |CT                      |
# |BOA               |BRIDGE OF AMERICAS           |TX                      |
# |BGC               |BRIDGEPORT                   |CT                      |
# |BWM               |BRIDGEWATER                  |ME                      |
# |BRO               |BROWNSVILLE                  |TX                      |
# |BRU               |BRUNSWICK                    |GA                      |
# |BCK               |BUCKPORT                     |ME                      |
# |EZE               |BUENOS AIRES MINISTRO PIST   |ARGENTINA               |
# |BUF               |BUFFALO                      |NY                      |
# |BUR               |BURBANK                      |CA                      |
# |BRG               |BURLINGTON                   |VT                      |
# |AGS               |BUSH FIELD - AUGUSTA         |GA                      |
# |BTM               |BUTTE                        |MT                      |
# |LGU               |CACHE AIRPORT - LOGAN        |UT                      |
# |CLS               |CALAIS                       |ME                      |
# |CAL               |CALEXICO                     |CA                      |
# |CLG               |CALGARY                      |CANADA                  |
# |CNJ               |CAMDEN                       |NJ                      |
# |CAO               |CAMPO                        |CA                      |
# |CNA               |CANAAN                       |VT                      |
# |CUN               |CANCUN                       |MEXICO                  |
# |CNC               |CANNON CORNERS               |NY                      |
# |CNH               |CANNON CORNERS               |NY                      |
# |RNO               |CANNON INTL - RENO/TAHOE     |NV                      |
# |CAN               |CAPE CANAVERAL               |FL                      |
# |CAP               |CAPE VINCENT                 |NY                      |
# |SPI               |CAPITAL - SPRINGFIELD        |IL                      |
# |CRQ               |CARAVELAS BA #ARPT           |BRAZIL                  |
# |CRY               |CARBURY                      |ND                      |
# |CRB               |CARIBOU                      |ME                      |
# |CAR               |CARIBOU MUNICIPAL AIRPORT    |MN                      |
# |CRL               |CARLSBAD                     |NM                      |
# |MVD               |CARRASCO                     |URUGUAY                 |
# |CSP               |CASPER                       |WY                      |
# |CID               |CEDAR RAPIDS/IOWA CITY       |IA                      |
# |CHM               |CHAMPLAIN                    |NY                      |
# |CHL               |CHARLESTON                   |SC                      |
# |CHS               |CHARLESTON                   |WV                      |
# |CLT               |CHARLOTTE                    |NC                      |
# |CHA               |CHARLOTTE AMALIE             |VI                      |
# |CHT               |CHATEAUGAY                   |NY                      |
# |CHI               |CHICAGO                      |IL                      |
# |CHF               |CHIEF MT                     |MT                      |
# |CHR               |CHRISTIANSTED                |VI                      |
# |CIN               |CINCINNATI                   |OH                      |
# |CLK               |CLARKSBURG                   |WV                      |
# |CLA               |CLAYTON                      |NY                      |
# |CLE               |CLEVELAND                    |OH                      |
# |COB               |COBURN GORE                  |ME                      |
# |COS               |COLORADO SPRINGS             |CO                      |
# |CAE               |COLUMBIA                     |SC                      |
# |CLM               |COLUMBUS                     |OH                      |
# |COL               |COLUMBUS                     |NM                      |
# |COO               |COOS BAY                     |OR                      |
# |CRP               |CORPUS CHRISTI               |TX                      |
# |CRA               |CRANE LAKE                   |MN                      |
# |CDD               |CRANE LAKE - ST. LOUIS CNTY  |NM                      |
# |CRU               |CRUZ BAY ST JOHN             |VI                      |
# |MIC               |CRYSTAL MUNICIPAL AIRPORT    |MN                      |
# |JCP               |CULEBRA - BENJAMIN RIVERA    |PR                      |
# |CUR               |CURLEW                       |WA                      |
# |CUT               |CUT BANK                     |MT                      |
# |CTB               |CUT BANK MUNICIPAL           |MT                      |
# |GTF               |Collapsed into INT           |MN                      |
# |INL               |Collapsed into INT           |MN                      |
# |DAL               |DALLAS                       |TX                      |
# |DAC               |DALTONS CACHE                |AK                      |
# |DVL               |DANVILLE                     |WA                      |
# |DAA               |DAVISON AAF - FAIRFAX CNTY   |VA                      |
# |DAB               |DAYTONA BEACH INTERNATIONAL  |FL                      |
# |DLB               |DEL BONITA                   |MT                      |
# |DLR               |DEL RIO                      |TX                      |
# |DNM               |DEMING                       |NM                      |
# |DEN               |DENVER                       |CO                      |
# |DER               |DERBY LINE VT (RT. 5)        |VT                      |
# |DLV               |DERBY LINE VT (RT. 5)        |VT                      |
# |DSM               |DES MOINES                   |IA                      |
# |DET               |DETROIT                      |MI                      |
# |PIZ               |DEW STATION PT LAY DEW       |AK                      |
# |DNA               |DONNA                        |TX                      |
# |DOU               |DOUGLAS                      |AZ                      |
# |DOV               |DOVER AFB                    |Invalid State Code      |
# |DUB               |DUBLIN                       |IRELAND                 |
# |DUL               |DULUTH                       |MN                      |
# |DNS               |DUNSEITH                     |ND                      |
# |DPA               |DUPAGE COUNTY                |IL                      |
# |DTH               |DUTCH HARBOR                 |AK                      |
# |EGL               |EAGLE                        |AK                      |
# |EGP               |EAGLE PASS                   |TX                      |
# |ERC               |EAST RICHFORD                |VT                      |
# |EST               |EASTCOURT                    |ME                      |
# |EPI               |EASTPORT                     |ID                      |
# |EPM               |EASTPORT                     |ME                      |
# |EPT               |EASTPORT MUNICIPAL           |ME                      |
# |EDA               |EDMONTON                     |CANADA                  |
# |ELP               |EL PASO                      |TX                      |
# |ELY               |ELY                          |MN                      |
# |ENS               |ENSENADA                     |PR                      |
# |ERI               |ERIE                         |PA                      |
# |EUR               |EUREKA                       |MT                      |
# |EVE               |EVERETT                      |WA                      |
# |FAB               |FABENS                       |TX                      |
# |FRB               |FAIRBANKS                    |AK                      |
# |FAJ               |FAJARDO                      |PR                      |
# |FAL               |FALCON HEIGHTS               |TX                      |
# |FLX               |FALLON MUNICIPAL AIRPORT     |NV                      |
# |IDA               |FANNING FIELD - IDAHO FALLS  |ID                      |
# |FAR               |FARGO                        |ND                      |
# |FAY               |FAYETTEVILLE                 |NC                      |
# |FRN               |FERNANDINA                   |FL                      |
# |FER               |FERRY                        |WA                      |
# |FOR               |FOREST CITY                  |ME                      |
# |FTC               |FORT COVINGTON               |NY                      |
# |FTF               |FORT FAIRFIELD               |ME                      |
# |FTH               |FORT HANCOCK                 |TX                      |
# |FTK               |FORT KENT                    |ME                      |
# |FTL               |FORT LAUDERDALE              |FL                      |
# |FMY               |FORT MYERS                   |FL                      |
# |FPF               |FORT PIERCE                  |FL                      |
# |AFW               |FORT WORTH ALLIANCE          |TX                      |
# |FRT               |FORTUNA                      |ND                      |
# |FOU               |FOUGAMOU #ARPT               |GABON                   |
# |FRK               |FREDERIKSTED                 |VI                      |
# |FBA               |FREEPORT                     |BAHAMAS                 |
# |FPT               |FREEPORT                     |TX                      |
# |FRE               |FRESNO                       |CA                      |
# |FRI               |FRIDAY HARBOR                |WA                      |
# |FWA               |FRONTIER                     |WA                      |
# |BZN               |GALLATIN FIELD - BOZEMAN     |MT                      |
# |GAL               |GALVESTON                    |TX                      |
# |GAR               |GARY                         |IN                      |
# |MTY               |GEN M. ESCOBEDO Monterrey    |MX                      |
# |HMO               |GEN PESQUEIRA GARCIA         |MX                      |
# |GEO               |GEORGETOWN                   |SC                      |
# |FCA               |GLACIER NATIONAL PARK        |MT                      |
# |GGW               |GLASGOW                      |MT                      |
# |GLO               |GLOUCESTER                   |MA                      |
# |GTR               |GOLDEN TRIANGLE LOWNDES CNTY |MS                      |
# |GCM               |GRAND CAYMAN CAYMAN          |ISLAND                  |
# |GRF               |GRAND FORKS                  |ND                      |
# |GPM               |GRAND PORTAGE                |MN                      |
# |GRP               |GRAND RAPIDS                 |MI                      |
# |SVC               |GRANT COUNTY - SILVER CITY   |MN                      |
# |GRE               |GREAT FALLS                  |MT                      |
# |PIA               |GREATER PEORIA               |IL                      |
# |RFD               |GREATER ROCKFORD             |IL                      |
# |GRB               |GREEN BAY                    |WI                      |
# |GSP               |GREENVILLE                   |SC                      |
# |GRR               |GREER                        |SC                      |
# |GRO               |GROSSE ISLE                  |MI                      |
# |GRT               |GROTON                       |CT                      |
# |GDL               |GUADALAJARA MIGUEL HIDAL     |MX                      |
# |GRU               |GUARULHOS INTL SAO PAULO     |BRAZIL                  |
# |GUL               |GULFPORT                     |MS                      |
# |YHC               |HAKAI PASS                   |CANADA                  |
# |HML               |HAMIIN                       |ME                      |
# |HAM               |HAMILTON                     |BERMUDA                 |
# |HMM               |HAMMOND                      |IN                      |
# |HNN               |HANNAH                       |ND                      |
# |HNS               |HANSBORO                     |ND                      |
# |BED               |HANSCOM FIELD - BEDFORD      |MA                      |
# |HLG               |HARLINGEN                    |TX                      |
# |MDT               |HARRISBURG                   |PA                      |
# |HSB               |HARRISONBURG                 |PA                      |
# |HAR               |HARTFORD                     |CT                      |
# |HVR               |HAVRE                        |MT                      |
# |HEL               |HELENA                       |MT                      |
# |HID               |HIDALGO                      |TX                      |
# |HIG               |HIGHGATE SPRINGS             |VT                      |
# |HIO               |HILLSBORO                    |OR                      |
# |HOB               |HOBOKEN                      |NJ                      |
# |HOM               |HOMER                        |AK                      |
# |HHW               |HONOLULU                     |HI                      |
# |HOP               |HOPEWELL                     |VA                      |
# |HTM               |HOULTON                      |ME                      |
# |HOU               |HOUSTON                      |TX                      |
# |HON               |HOWES REGIONAL ARPT - HURON  |SD                      |
# |SGR               |HULL FIELD SUGAR LAND ARPT   |TX                      |
# |HUM               |HUMACAO                      |PR                      |
# |HUR               |HURLBURT FIELD               |FL                      |
# |HYD               |HYDER                        |AK                      |
# |HAL               |Halifax NS                   |Canada                  |
# |ICP               |IMPERIAL COUNTY              |CA                      |
# |ICN               |INCHON SEOUL                 |KOREA                   |
# |INP               |INDIANAPOLIS                 |IN                      |
# |INT               |INT''L FALLS                 |MN                      |
# |ISL               |ISLE ROYALE                  |MI                      |
# |IWA               |IWAKUNI                      |JAPAN                   |
# |.GA               |Invalid Airport Entry        |Invalid State Code      |
# |060               |Invalid Airport Entry        |Invalid State Code      |
# |5T6               |Invalid Airport Entry        |Invalid State Code      |
# |74S               |Invalid Airport Entry        |Invalid State Code      |
# |888               |Invalid Airport Entry        |Invalid State Code      |
# |A2A               |Invalid Airport Entry        |Invalid State Code      |
# |ADU               |Invalid Airport Entry        |Invalid State Code      |
# |AG                |Invalid Airport Entry        |Invalid State Code      |
# |AKT               |Invalid Airport Entry        |Invalid State Code      |
# |AMT               |Invalid Airport Entry        |Invalid State Code      |
# |ASI               |Invalid Airport Entry        |Invalid State Code      |
# |ATW               |Invalid Airport Entry        |Invalid State Code      |
# |AUH               |Invalid Airport Entry        |Invalid State Code      |
# |BCM               |Invalid Airport Entry        |Invalid State Code      |
# |BKF               |Invalid Airport Entry        |Invalid State Code      |
# |BUS               |Invalid Airport Entry        |Invalid State Code      |
# |CHN               |Invalid Airport Entry        |Invalid State Code      |
# |CLX               |Invalid Airport Entry        |Invalid State Code      |
# |CP                |Invalid Airport Entry        |Invalid State Code      |
# |CPX               |Invalid Airport Entry        |Invalid State Code      |
# |CXO               |Invalid Airport Entry        |Invalid State Code      |
# |DAY               |Invalid Airport Entry        |Invalid State Code      |
# |DEC               |Invalid Airport Entry        |Invalid State Code      |
# |DRV               |Invalid Airport Entry        |Invalid State Code      |
# |DVD               |Invalid Airport Entry        |Invalid State Code      |
# |EGE               |Invalid Airport Entry        |Invalid State Code      |
# |FRG               |Invalid Airport Entry        |Invalid State Code      |
# |FSC               |Invalid Airport Entry        |Invalid State Code      |
# |FTB               |Invalid Airport Entry        |Invalid State Code      |
# |GAC               |Invalid Airport Entry        |Invalid State Code      |
# |GMT               |Invalid Airport Entry        |Invalid State Code      |
# |GPI               |Invalid Airport Entry        |Invalid State Code      |
# |HRL               |Invalid Airport Entry        |Invalid State Code      |
# |IAG               |Invalid Airport Entry        |Invalid State Code      |
# |ISP               |Invalid Airport Entry        |Invalid State Code      |
# |JBQ               |Invalid Airport Entry        |Invalid State Code      |
# |JFA               |Invalid Airport Entry        |Invalid State Code      |
# |JIG               |Invalid Airport Entry        |Invalid State Code      |
# |JMZ               |Invalid Airport Entry        |Invalid State Code      |
# |JSJ               |Invalid Airport Entry        |Invalid State Code      |
# |LIT               |Invalid Airport Entry        |Invalid State Code      |
# |MTH               |Invalid Airport Entry        |Invalid State Code      |
# |NC8               |Invalid Airport Entry        |Invalid State Code      |
# |NGL               |Invalid Airport Entry        |Invalid State Code      |
# |NK                |Invalid Airport Entry        |Invalid State Code      |
# |NYL               |Invalid Airport Entry        |Invalid State Code      |
# |OAI               |Invalid Airport Entry        |Invalid State Code      |
# |OGS               |Invalid Airport Entry        |Invalid State Code      |
# |OLM               |Invalid Airport Entry        |Invalid State Code      |
# |OSN               |Invalid Airport Entry        |Invalid State Code      |
# |OTS               |Invalid Airport Entry        |Invalid State Code      |
# |PCW               |Invalid Airport Entry        |Invalid State Code      |
# |PFN               |Invalid Airport Entry        |Invalid State Code      |
# |PHF               |Invalid Airport Entry        |Invalid State Code      |
# |PHN               |Invalid Airport Entry        |Invalid State Code      |
# |PLB               |Invalid Airport Entry        |Invalid State Code      |
# |RYY               |Invalid Airport Entry        |Invalid State Code      |
# |SCH               |Invalid Airport Entry        |Invalid State Code      |
# |SP0               |Invalid Airport Entry        |Invalid State Code      |
# |STN               |Invalid Airport Entry        |Invalid State Code      |
# |SUS               |Invalid Airport Entry        |Invalid State Code      |
# |T01               |Invalid Airport Entry        |Invalid State Code      |
# |TIW               |Invalid Airport Entry        |Invalid State Code      |
# |UNK               |Invalid Airport Entry        |Invalid State Code      |
# |VMB               |Invalid Airport Entry        |Invalid State Code      |
# |W55               |Invalid Airport Entry        |Invalid State Code      |
# |WA5               |Invalid Airport Entry        |Invalid State Code      |
# |WTR               |Invalid Airport Entry        |Invalid State Code      |
# |X44               |Invalid Airport Entry        |Invalid State Code      |
# |X96               |Invalid Airport Entry        |Invalid State Code      |
# |XNA               |Invalid Airport Entry        |Invalid State Code      |
# |XXX               |Invalid Airport Entry        |Invalid State Code      |
# |Y62               |Invalid Airport Entry        |Invalid State Code      |
# |YGF               |Invalid Airport Entry        |Invalid State Code      |
# |GNV               |J R ALISON MUNI - GAINESVILLE|FL                      |
# |JKM               |JACKMAN                      |ME                      |
# |JAC               |JACKSONVILLE                 |FL                      |
# |JER               |JERSEY CITY                  |NJ                      |
# |JOB               |JOBOS                        |PR                      |
# |MEX               |JUAREZ INTL MEXICO CITY      |MX                      |
# |LLB               |JUAREZ-LINCOLN BRIDGE        |TX                      |
# |JUN               |JUNEAU                       |AK                      |
# |OGG               |KAHULUI - MAUI               |HI                      |
# |KLM               |KALAMA                       |WA                      |
# |KAL               |KALISPEL                     |MT                      |
# |KAN               |KANSAS CITY                  |MO                      |
# |KOA               |KEAHOLE-KONA                 |HI                      |
# |5KE               |KETCHIKAN                    |AK                      |
# |KET               |KETCHIKAN                    |AK                      |
# |KEY               |KEY WEST                     |FL                      |
# |BDA               |KINDLEY FIELD                |BERMUDA                 |
# |CND               |KOGALNICEANU                 |ROMANIA                 |
# |LAG               |LA GUARDIA                   |NY                      |
# |DRO               |LA PLATA - DURANGO           |CO                      |
# |LAH               |LABUHA ARPT                  |INDONESIA               |
# |LAK               |LAKE CHARLES                 |LA                      |
# |LKC               |LAKE CHARLES                 |LA                      |
# |LAN               |LANCASTER                    |MN                      |
# |LND               |LANDER                       |WY                      |
# |LAR               |LAREDO                       |TX                      |
# |LCB               |LAREDO COLUMBIA BRIDGE       |TX                      |
# |LRN               |LAREDO NORTH                 |TX                      |
# |LAS               |LAS CRUCES                   |NM                      |
# |LVG               |LAS VEGAS                    |NV                      |
# |LAU               |LAURIER                      |WA                      |
# |LEB               |LEBANON                      |NH                      |
# |LEE               |LEESBURG MUNICIPAL AIRPORT   |FL                      |
# |LEW               |LEWISTON                     |NY                      |
# |LWT               |LEWISTON                     |MT                      |
# |LIH               |LIHUE                        |HI                      |
# |LIM               |LIMESTONE                    |ME                      |
# |LIA               |LITTLE ROCK                  |AR                      |
# |LNB               |LONG BEACH                   |CA                      |
# |LON               |LONGVIEW                     |WA                      |
# |LOR               |LORAIN                       |OH                      |
# |LOB               |LORDSBURG                    |NM                      |
# |LOS               |LOS ANGELES                  |CA                      |
# |LSE               |LOS EBANOS                   |TX                      |
# |IND               |LOS INDIOS                   |TX                      |
# |LOI               |LOS INDIOS                   |TX                      |
# |DUR               |LOUIS BOTHA                  |SOUTH AFRICA            |
# |LOU               |LOUISVILLE                   |KY                      |
# |LUB               |LUBEC                        |ME                      |
# |LUK               |LUKEVILLE                    |AZ                      |
# |LYN               |LYNDEN                       |WA                      |
# |MAD               |MADAWASKA                    |ME                      |
# |HSV               |MADISON COUNTY - HUNTSVILLE  |AL                      |
# |AG0               |MAGNOLIA                     |AR                      |
# |MAI               |MAIDA                        |ND                      |
# |HEF               |MANASSAS                     |VA                      |
# |MHT               |MANCHESTER                   |NH                      |
# |MAL               |MANGOLE ARPT                 |INDONESIA               |
# |MNW               |MANITOWOC                    |WI                      |
# |MBO               |MARBLE HEADS                 |OH                      |
# |MAR               |MARFA                        |TX                      |
# |MRS               |MARFA                        |TX                      |
# |MRC               |MARINE CITY                  |MI                      |
# |MAP               |MARIPOSA                     |AZ                      |
# |MRY               |MARYSVILLE                   |MI                      |
# |MAS               |MASSENA                      |NY                      |
# |MAY               |MAYAGUEZ                     |PR                      |
# |TYS               |MC GHEE TYSON - ALCOA        |TN                      |
# |WRI               |MC GUIRE AFB - WRIGHTSOWN    |NJ                      |
# |MCA               |MCALLEN                      |TX                      |
# |MAG               |MCGUIRE AFB                  |NY                      |
# |BFL               |MEADOWS FIELD - BAKERSFIELD  |CA                      |
# |MDE               |MEDELLIN                     |COLOMBIA                |
# |MED               |MEDFORD                      |OR                      |
# |MLB               |MELBOURNE                    |FL                      |
# |UGN               |MEMORIAL - WAUKEGAN          |IL                      |
# |MEM               |MEMPHIS                      |TN                      |
# |BLF               |MERCER COUNTY                |WV                      |
# |MRL               |MERRILLVILLE                 |IN                      |
# |MET               |METALINE FALLS               |WA                      |
# |ZZZ               |MEXICO Land (Banco de        |Mexico                  |
# |MIA               |MIAMI                        |FL                      |
# |ICT               |MID-CONTINENT - WITCHITA     |KS                      |
# |LHR               |MIDDLESEX                    |ENGLAND                 |
# |MIL               |MILWAUKEE                    |WI                      |
# |MSP               |MINN./ST PAUL                |MN                      |
# |MND               |MINOT                        |ND                      |
# |MOB               |MOBILE                       |AL                      |
# |MLI               |MOLINE                       |IL                      |
# |MLU               |MONROE                       |LA                      |
# |MON               |MONTREAL                     |CANADA                  |
# |MOO               |MOORES                       |NY                      |
# |MRH               |MOREHEAD CITY                |NC                      |
# |MGM               |MORGAN                       |MT                      |
# |MGC               |MORGAN CITY                  |LA                      |
# |FOP               |MORRIS FIELDS AAF            |NC                      |
# |MMU               |MORRISTOWN                   |NJ                      |
# |MRR               |MORRISTOWN                   |NY                      |
# |MOR               |MORSES LINE                  |VT                      |
# |MWH               |MOSES LAKE GRANT COUNTY ARPT |WA                      |
# |MOS               |MOSES POINT INTERMEDIATE     |AK                      |
# |MKG               |MUSKEGON                     |MD                      |
# |MYR               |MYRTLE BEACH                 |SC                      |
# |NAC               |NACO                         |AZ                      |
# |NBO               |NAIROBI                      |KENYA                   |
# |APF               |NAPLES                       |FL                      |
# |NSV               |NASHVILLE                    |TN                      |
# |NAS               |NASSAU                       |BAHAMAS                 |
# |NEA               |NEAH BAY                     |WA                      |
# |NEC               |NECHE                        |ND                      |
# |NWH               |NEW HAVEN                    |CT                      |
# |NWL               |NEW LONDON                   |CT                      |
# |NOL               |NEW ORLEANS                  |LA                      |
# |NYC               |NEW YORK                     |NY                      |
# |NEW               |NEWARK/TETERBORO             |NJ                      |
# |TST               |NEWINGTON DATA CENTER TEST   |CT                      |
# |NPT               |NEWPORT                      |OR                      |
# |NPV               |NEWPORT                      |VT                      |
# |NWN               |NEWPORT                      |VA                      |
# |NIA               |NIAGARA FALLS                |NY                      |
# |NIG               |NIGHTHAWK                    |WA                      |
# |NIK               |NIKISKI                      |AK                      |
# |NOG               |NOGALES                      |AZ                      |
# |NOM               |NOM                          |AK                      |
# |NOO               |NOONAN                       |ND                      |
# |NOR               |NORFOLK                      |VA                      |
# |NCA               |NORTH CAICOS TURK &          |CAIMAN                  |
# |NRT               |NORTH TROY                   |VT                      |
# |LIN               |NORTHERN SVC CENTER          |MN                      |
# |NRG               |NORTHGATE                    |ND                      |
# |NRN               |NORTON                       |VT                      |
# |NOY               |NOYES                        |MN                      |
# |OAK               |OAKLAND                      |CA                      |
# |PTK               |OAKLAND COUNTY - PONTIAC     |MI                      |
# |MAF               |ODESSA REGIONAL              |TX                      |
# |OGD               |OGDENSBURG                   |NY                      |
# |OKC               |OKLAHOMA CITY                |OK                      |
# |OLY               |OLYMPIA                      |WA                      |
# |OMA               |OMAHA                        |NE                      |
# |PTY               |OMAR TORRIJOS                |PANAMA                  |
# |ONT               |ONTARIO                      |CA                      |
# |OPF               |OPA LOCKA                    |FL                      |
# |OPH               |OPHEIM                       |MT                      |
# |ORL               |ORLANDO                      |FL                      |
# |ORO               |OROVILLE                     |WA                      |
# |OSW               |OSWEGO                       |NY                      |
# |OTM               |OTAY MESA                    |CA                      |
# |OTT               |OTTAWA                       |CANADA                  |
# |BLT               |PACIFIC HWY. STATION         |CA                      |
# |PSP               |PALM SPRINGS                 |CA                      |
# |PAN               |PANAMA CITY                  |FL                      |
# |SPV               |PAPUA NEW                    |GUINEA                  |
# |PAS               |PASCAGOULA                   |MS                      |
# |PWB               |PASCO                        |WA                      |
# |PDN               |PASO DEL NORTE               |TX                      |
# |PAX               |PATUXENT RIVER               |MD                      |
# |PBB               |PEACE BRIDGE                 |NY                      |
# |PEM               |PEMBINA                      |ND                      |
# |PEN               |PENSACOLA                    |FL                      |
# |PER               |PERTH AMBOY                  |NJ                      |
# |PHR               |PHARR                        |TX                      |
# |PHI               |PHILADELPHIA                 |PA                      |
# |PHO               |PHOENIX                      |AZ                      |
# |GSO               |PIEDMONT TRIAD INTL AIRPORT  |NC                      |
# |PIE               |PIEGAN                       |MT                      |
# |PIN               |PINE CREEK                   |MN                      |
# |48Y               |PINECREEK BORDER ARPT        |MN                      |
# |PIV               |PINNACLE ROAD                |VT                      |
# |PIT               |PITTSBURG                    |PA                      |
# |PNH               |PITTSBURG                    |NH                      |
# |PIR               |POINT ROBERTS                |WA                      |
# |PKC               |POKER CREEK                  |AK                      |
# |ACY               |POMONA FIELD - ATLANTIC CITY |NJ                      |
# |PON               |PONCE                        |PR                      |
# |PSE               |PONCE-MERCEDITA              |PR                      |
# |PNG               |PORT ANGELES                 |WA                      |
# |PAR               |PORT ARTHUR                  |TX                      |
# |PCF               |PORT CANAVERAL               |FL                      |
# |PEV               |PORT EVERGLADES              |FL                      |
# |PHU               |PORT HURON                   |MI                      |
# |ISB               |PORT ISABEL                  |TX                      |
# |ORI               |PORT LIONS SPB               |AK                      |
# |POE               |PORT OF EL PASO              |TX                      |
# |PSJ               |PORT ST JOE                  |FL                      |
# |PTO               |PORT TOWNSEND                |WA                      |
# |POR               |PORTAL                       |AZ                      |
# |PTL               |PORTHILL                     |ID                      |
# |POM               |PORTLAND                     |ME                      |
# |POO               |PORTLAND                     |OR                      |
# |PSM               |PORTSMOUTH                   |NH                      |
# |PRE               |PRESIDIO                     |TX                      |
# |PGR               |PROGRESO                     |TX                      |
# |PRO               |PROVIDENCE                   |RI                      |
# |PUT               |PUT-IN-BAY                   |OH                      |
# |UIO               |QUITO (MARISCAL SUCR)        |ECUADOR                 |
# |RAN               |RAINER                       |MN                      |
# |RDU               |RALEIGH/DURHAM               |NC                      |
# |RGM               |RANGELEY                     |ME                      |
# |RAY               |RAYMOND                      |MT                      |
# |ELM               |REGIONAL ARPT - HORSEHEAD    |NY                      |
# |REN               |RENO                         |NV                      |
# |RIF               |RICHFORT                     |VT                      |
# |RCM               |RICHMOND                     |VA                      |
# |RIO               |RIO GRANDE CITY              |TX                      |
# |RIV               |RIVERSIDE                    |CA                      |
# |RDM               |ROBERTS FIELDS - REDMOND     |OR                      |
# |RBT               |ROBERTS LANDING              |MI                      |
# |ROC               |ROCHESTER                    |NY                      |
# |RST               |ROCHESTER                    |MN                      |
# |ROG               |ROGERS ARPT                  |AR                      |
# |ROM               |ROMA                         |TX                      |
# |RIT               |ROME                         |ITALY                   |
# |RME               |ROME                         |NY                      |
# |ROO               |ROOSVILLE                    |MT                      |
# |ROS               |ROSEAU                       |MN                      |
# |ROU               |ROUSES POINT                 |NY                      |
# |RUI               |RUIDOSO                      |NM                      |
# |SAC               |SACRAMENTO                   |CA                      |
# |SAG               |SAGINAW                      |MI                      |
# |SAI               |SAIPAN                       |SPN                     |
# |SNO               |SAKON NAKHON #ARPT           |THAILAND                |
# |SLS               |SALINAS                      |CA                      |
# |SLC               |SALT LAKE CITY               |UT                      |
# |SNA               |SAN ANTONIO                  |TX                      |
# |SDP               |SAN DIEGO                    |CA                      |
# |SFR               |SAN FRANCISCO                |CA                      |
# |SNJ               |SAN JOSE                     |CA                      |
# |SAJ               |SAN JUAN                     |PR                      |
# |SLU               |SAN LUIS                     |AZ                      |
# |SLI               |SAN LUIS OBISPO              |CA                      |
# |SLO               |SAN LUIS OBISPO              |CA                      |
# |SLP               |SAN LUIS POTOSI #ARPT        |MEXICO                  |
# |SPC               |SAN PEDRO                    |CA                      |
# |SAN               |SAN SALVADOR EL              |SALVADOR                |
# |SYS               |SAN YSIDRO                   |CA                      |
# |SNN               |SANDERSON                    |TX                      |
# |SDY               |SANDUSKY                     |OH                      |
# |SFB               |SANFORD                      |FL                      |
# |SAA               |SANTA ANA                    |CA                      |
# |STR               |SANTA TERESA                 |NM                      |
# |SRO               |SANTANA RAMOS #ARPT          |COLOMBIA                |
# |SAR               |SARLES                       |ND                      |
# |SAS               |SASABE                       |AZ                      |
# |YXE               |SASKATOON                    |CANADA                  |
# |SSM               |SAULT STE. MARIE             |MI                      |
# |SAV               |SAVANNAH                     |GA                      |
# |SCO               |SCOBEY                       |MT                      |
# |SEA               |SEATTLE                      |WA                      |
# |SHA               |SHANNON                      |IRELAND                 |
# |SSC               |SHAW AFB - SUMTER            |NC                      |
# |SHR               |SHERWOOD                     |ND                      |
# |HIL               |SHILLAVO                     |ETHIOPIA                |
# |SKA               |SKAGWAY                      |AK                      |
# |SBN               |SOUTH BEND                   |IN                      |
# |SBR               |SOUTH BREWER                 |ME                      |
# |SPO               |SPOKANE                      |WA                      |
# |SGF               |SPRINGFIELD-BRANSON          |MO                      |
# |STA               |ST ALBANS                    |VT                      |
# |SAU               |ST AUGUSTINE                 |FL                      |
# |SGJ               |ST AUGUSTINE ARPT            |FL                      |
# |SRL               |ST AURELIE                   |ME                      |
# |SCL               |ST CLAIR                     |MI                      |
# |SJO               |ST JOHN                      |ND                      |
# |STL               |ST LOUIS                     |MO                      |
# |FPR               |ST LUCIE COUNTY              |FL                      |
# |SPA               |ST PAMPILE                   |ME                      |
# |SPM               |ST PAUL                      |MN                      |
# |SPE               |ST PETERSBURG                |FL                      |
# |STT               |ST THOMAS                    |VI                      |
# |SNP               |ST. PAUL ISLAND              |AK                      |
# |SWF               |STEWART - ORANGE CNTY        |NY                      |
# |STO               |STOCKTON                     |CA                      |
# |FOK               |SUFFOLK COUNTY               |NY                      |
# |SUM               |SUMAS                        |WA                      |
# |SWB               |SWANTON VT (BP - SECTOR      |HQ                      |
# |SWE               |SWEETGTASS                   |MT                      |
# |SYR               |SYRACUSE                     |NY                      |
# |TAC               |TACOMA                       |WA                      |
# |TAM               |TAMPA                        |FL                      |
# |TEC               |TECATE                       |CA                      |
# |PVD               |THEODORE FRANCIS - WARWICK   |RI                      |
# |JAN               |THOMPSON FIELD - JACKSON     |MS                      |
# |THO               |THOUSAND ISLAND BRIDGE       |NY                      |
# |TKI               |TOKEEN                       |AK                      |
# |TOL               |TOLEDO                       |OH                      |
# |TOK               |TOROKINA #ARPT PAPUA NEW     |GUINEA                  |
# |TOR               |TORONTO                      |CANADA                  |
# |TRV               |TRAVIS-AFB                   |CA                      |
# |TRI               |TRI CITY ARPT                |TN                      |
# |PSC               |TRI-CITIES - PASCO           |WA                      |
# |TRL               |TRIAL CREEK                  |MT                      |
# |TRO               |TROUT RIVER                  |NY                      |
# |MSN               |TRUAX FIELD - DANE COUNTY    |WI                      |
# |TUC               |TUCSON                       |AZ                      |
# |TUL               |TULSA                        |OK                      |
# |TUR               |TURNER                       |MT                      |
# |VNB               |VAN BUREN                    |ME                      |
# |VNY               |VAN NUYS                     |CA                      |
# |VCB               |VANCEBORO                    |ME                      |
# |VAN               |VANCOUVER                    |WA                      |
# |VCV               |VANCOUVER                    |CANADA                  |
# |VER               |VERACRUZ                     |MEXICO                  |
# |VIB               |VETERAN INTL BRIDGE          |TX                      |
# |VIC               |VICTORIA                     |CANADA                  |
# |VQS               |VIEQUES-ARPT                 |PR                      |
# |WAL               |WALHALLA                     |ND                      |
# |WAR               |WARROAD                      |MN                      |
# |WSB               |WARROAD INTL SPB             |MN                      |
# |WAS               |WASHINGTON                   |DC                      |
# |WAT               |WATERTOWN                    |NY                      |
# |WBE               |WEST BERKSHIRE               |VT                      |
# |WPB               |WEST PALM BEACH              |FL                      |
# |LGW               |WEST SUSSEX                  |ENGLAND                 |
# |HPN               |WESTCHESTER - WHITE PLAINS   |NY                      |
# |WHO               |WESTHOPE                     |ND                      |
# |WRB               |WHIRLPOOL BRIDGE             |NY                      |
# |WHI               |WHITETAIL                    |MT                      |
# |WHM               |WILD HORSE                   |MT                      |
# |WND               |WILLISTON                    |ND                      |
# |WCM               |WILLOW CREEK                 |MT                      |
# |YIP               |WILLOW RUN - YPSILANTI       |MI                      |
# |WIL               |WILMINGTON                   |NC                      |
# |WLL               |WILMINGTON                   |Invalid State Code      |
# |WIN               |WINNIPEG                     |CANADA                  |
# |WRA               |WRANGELL                     |AK                      |
# |YOU               |YOUNGSTOWN                   |NY                      |
# |YSL               |YSLETA                       |TX                      |
# |YUI               |YUMA                         |AZ                      |
# |YUM               |YUMA                         |AZ                      |
# +------------------+-----------------------------+------------------------+

# %%
# check if former invalid entries are cleaned correctly
# Difference of the remaining entries ==> 660 - 582 = 78
df_st_immigration_airports \
    .join(df_st_immigration_airports_regex_cleaned,
          df_st_immigration_airports.st_ia_airport_code == df_st_immigration_airports_regex_cleaned.st_ia_airport_code, 'left_anti')  \
    .show(10000, False)
# Out:
# +------------------+---------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name   |st_ia_airport_state_code|
# +------------------+---------------------+------------------------+
# |MAA               |Abu Dhabi            |Invalid State Code      |
# |.GA               |Invalid Airport Entry|Invalid State Code      |
# |060               |Invalid Airport Entry|Invalid State Code      |
# |5T6               |Invalid Airport Entry|Invalid State Code      |
# |74S               |Invalid Airport Entry|Invalid State Code      |
# |888               |Invalid Airport Entry|Invalid State Code      |
# |A2A               |Invalid Airport Entry|Invalid State Code      |
# |ADU               |Invalid Airport Entry|Invalid State Code      |
# |AG                |Invalid Airport Entry|Invalid State Code      |
# |AKT               |Invalid Airport Entry|Invalid State Code      |
# |AMT               |Invalid Airport Entry|Invalid State Code      |
# |ASI               |Invalid Airport Entry|Invalid State Code      |
# |ATW               |Invalid Airport Entry|Invalid State Code      |
# |AUH               |Invalid Airport Entry|Invalid State Code      |
# |BCM               |Invalid Airport Entry|Invalid State Code      |
# |BKF               |Invalid Airport Entry|Invalid State Code      |
# |BUS               |Invalid Airport Entry|Invalid State Code      |
# |CHN               |Invalid Airport Entry|Invalid State Code      |
# |CLX               |Invalid Airport Entry|Invalid State Code      |
# |CP                |Invalid Airport Entry|Invalid State Code      |
# |CPX               |Invalid Airport Entry|Invalid State Code      |
# |CXO               |Invalid Airport Entry|Invalid State Code      |
# |DAY               |Invalid Airport Entry|Invalid State Code      |
# |DEC               |Invalid Airport Entry|Invalid State Code      |
# |DRV               |Invalid Airport Entry|Invalid State Code      |
# |EGE               |Invalid Airport Entry|Invalid State Code      |
# |FRG               |Invalid Airport Entry|Invalid State Code      |
# |FSC               |Invalid Airport Entry|Invalid State Code      |
# |FTB               |Invalid Airport Entry|Invalid State Code      |
# |GAC               |Invalid Airport Entry|Invalid State Code      |
# |GMT               |Invalid Airport Entry|Invalid State Code      |
# |GPI               |Invalid Airport Entry|Invalid State Code      |
# |HRL               |Invalid Airport Entry|Invalid State Code      |
# |IAG               |Invalid Airport Entry|Invalid State Code      |
# |ISP               |Invalid Airport Entry|Invalid State Code      |
# |JBQ               |Invalid Airport Entry|Invalid State Code      |
# |JFA               |Invalid Airport Entry|Invalid State Code      |
# |JIG               |Invalid Airport Entry|Invalid State Code      |
# |JMZ               |Invalid Airport Entry|Invalid State Code      |
# |JSJ               |Invalid Airport Entry|Invalid State Code      |
# |LIT               |Invalid Airport Entry|Invalid State Code      |
# |MTH               |Invalid Airport Entry|Invalid State Code      |
# |NC8               |Invalid Airport Entry|Invalid State Code      |
# |NGL               |Invalid Airport Entry|Invalid State Code      |
# |NK                |Invalid Airport Entry|Invalid State Code      |
# |NYL               |Invalid Airport Entry|Invalid State Code      |
# |OAI               |Invalid Airport Entry|Invalid State Code      |
# |OGS               |Invalid Airport Entry|Invalid State Code      |
# |OLM               |Invalid Airport Entry|Invalid State Code      |
# |OSN               |Invalid Airport Entry|Invalid State Code      |
# |OTS               |Invalid Airport Entry|Invalid State Code      |
# |PCW               |Invalid Airport Entry|Invalid State Code      |
# |PFN               |Invalid Airport Entry|Invalid State Code      |
# |PHF               |Invalid Airport Entry|Invalid State Code      |
# |PHN               |Invalid Airport Entry|Invalid State Code      |
# |PLB               |Invalid Airport Entry|Invalid State Code      |
# |RYY               |Invalid Airport Entry|Invalid State Code      |
# |SCH               |Invalid Airport Entry|Invalid State Code      |
# |SP0               |Invalid Airport Entry|Invalid State Code      |
# |STN               |Invalid Airport Entry|Invalid State Code      |
# |SUS               |Invalid Airport Entry|Invalid State Code      |
# |T01               |Invalid Airport Entry|Invalid State Code      |
# |TIW               |Invalid Airport Entry|Invalid State Code      |
# |UNK               |Invalid Airport Entry|Invalid State Code      |
# |VMB               |Invalid Airport Entry|Invalid State Code      |
# |W55               |Invalid Airport Entry|Invalid State Code      |
# |WA5               |Invalid Airport Entry|Invalid State Code      |
# |WTR               |Invalid Airport Entry|Invalid State Code      |
# |X44               |Invalid Airport Entry|Invalid State Code      |
# |X96               |Invalid Airport Entry|Invalid State Code      |
# |XNA               |Invalid Airport Entry|Invalid State Code      |
# |XXX               |Invalid Airport Entry|Invalid State Code      |
# |Y62               |Invalid Airport Entry|Invalid State Code      |
# |YGF               |Invalid Airport Entry|Invalid State Code      |
# |MAP               |MARIPOSA             |AZ                      |
# |ZZZ               |MEXICO Land (Banco de|Mexico                  |
# |PDN               |PASO DEL NORTE       |TX                      |
# |WAS               |WASHINGTON           |DC                      |
# +------------------+---------------------+------------------------+

# %%
# Write data as new CSV file to disk
location_to_write = '../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/st_immigration_airports.csv'

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_immigration_airports \
    .coalesce(1)\
    .write\
    .mode("overwrite") \
    .csv(location_to_write, header = 'true')

# %%
# write df_st_immigration_airports back to stage area on file system
location_to_write = "../P8_capstone_resource_files/parquet_stage/PQ2/st_immigration_airports"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_immigration_airports \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .parquet(location_to_write, compression="gzip")

# %%
# Read written data frame back into memory
# st_immigration_airports:
location_st_immigration_airports = "../P8_capstone_resource_files/parquet_stage/PQ2/st_immigration_airports"
df_st_immigration_airports = spark.read.parquet(location_st_immigration_airports)

# current Schema of staging table st_immigration_airports
print(df_st_immigration_airports.count())
df_st_immigration_airports.printSchema()
df_st_immigration_airports.show(10, False)
# Out:
# 660
# root
#  |-- st_ia_airport_code: string (nullable = true)
#  |-- st_ia_airport_name: string (nullable = true)
#  |-- st_ia_airport_state_code: string (nullable = true)
#
# +------------------+---------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name         |st_ia_airport_state_code|
# +------------------+---------------------------+------------------------+
# |ABE               |ABERDEEN                   |WA                      |
# |ADS               |ADDISON AIRPORT- ADDISON   |TX                      |
# |AGA               |AGANA                      |GU                      |
# |AGU               |AGUADILLA                  |PR                      |
# |BOI               |AIR TERM. (GOWEN FLD) BOISE|ID                      |
# |AKR               |AKRON                      |OH                      |
# |CAK               |AKRON                      |OH                      |
# |ALA               |ALAMAGORDO                 |NM                      |
# |ALB               |ALBANY                     |NY                      |
# |CHO               |ALBEMARLE CHARLOTTESVILLE  |VA                      |
# +------------------+---------------------------+------------------------+
# only showing top 10 rows

# %% [markdown]
# 2. Add the column `st_ia_airport_state_code --> st_i94_port_state_code` to staging table `st_i94_immigration` based on staging
#    table `st_immigration_airports`. This information is needed to connect the `us-cities-demographics.json` file later on.

# %%
# read df_st_i94_immigrations staging table and add column `st_i94_port_state_code` to it. Write data frame back to disk.

# Read written data frame back into memory
# st_i94_immigrations:
location_st_i94_immigrations = "../P8_capstone_resource_files/parquet_stage/PQ1/st_i94_immigrations"
df_st_i94_immigrations = spark.read.parquet(location_st_i94_immigrations)

# st_immigration_airports:
location_st_immigration_airports = "../P8_capstone_resource_files/parquet_stage/PQ2/st_immigration_airports"
df_st_immigration_airports = spark.read.parquet(location_st_immigration_airports)


print(df_st_i94_immigrations.count())
df_st_i94_immigrations.printSchema()
df_st_i94_immigrations.show(5, False)

print(df_st_immigration_airports.count())
df_st_immigration_airports.printSchema()
df_st_immigration_airports.show(5, False)
# Out:
# 12228839
# root
#  |-- st_i94_cit: integer (nullable = true)
#  |-- st_i94_port: string (nullable = true)
#  |-- st_i94_addr: string (nullable = true)
#  |-- st_i94_arrdate: integer (nullable = true)
#  |-- st_i94_arrdate_iso: date (nullable = true)
#  |-- st_i94_depdate: integer (nullable = true)
#  |-- st_i94_depdate_iso: date (nullable = true)
#  |-- st_i94_dtadfile: date (nullable = true)
#  |-- st_i94_matflag: string (nullable = true)
#  |-- st_i94_count: integer (nullable = true)
#  |-- st_i94_id: integer (nullable = true)
#  |-- st_i94_year: integer (nullable = true)
#  |-- st_i94_month: integer (nullable = true)
#
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# |st_i94_cit|st_i94_port|st_i94_addr|st_i94_arrdate|st_i94_arrdate_iso|st_i94_depdate|st_i94_depdate_iso|st_i94_dtadfile|st_i94_matflag|st_i94_count|st_i94_id|st_i94_year|st_i94_month|
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# |254       |DAL        |KY         |20661         |2016-07-26        |20664         |2016-07-29        |2016-07-29     |M             |1           |8643306  |2016       |7           |
# |0         |HHW        |99         |20636         |2016-07-01        |20713         |2016-09-16        |2016-07-01     |M             |1           |7195726  |2016       |7           |
# |254       |DAL        |KY         |20661         |2016-07-26        |20670         |2016-08-04        |2016-08-04     |M             |1           |8626942  |2016       |7           |
# |0         |NYC        |99         |20636         |2016-07-01        |20714         |2016-09-17        |2016-07-01     |M             |1           |7196164  |2016       |7           |
# |254       |DAL        |KY         |20661         |2016-07-26        |20684         |2016-08-18        |2016-08-18     |M             |1           |8638982  |2016       |7           |
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# only showing top 5 rows
#
# 660
# root
#  |-- st_ia_airport_code: string (nullable = true)
#  |-- st_ia_airport_name: string (nullable = true)
#  |-- st_ia_airport_state_code: string (nullable = true)
#
# +------------------+---------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name         |st_ia_airport_state_code|
# +------------------+---------------------------+------------------------+
# |ABE               |ABERDEEN                   |WA                      |
# |ADS               |ADDISON AIRPORT- ADDISON   |TX                      |
# |AGA               |AGANA                      |GU                      |
# |AGU               |AGUADILLA                  |PR                      |
# |BOI               |AIR TERM. (GOWEN FLD) BOISE|ID                      |
# +------------------+---------------------------+------------------------+
# only showing top 5 rows

# %%
########################################################################################################################
# check if st_i94_dept_date_iso is 1900-01-01 (default value - No onward travel is planned)
df_st_i94_immigrations \
    .filter(df_st_i94_immigrations.st_i94_depdate == 0)\
    .show(5, False)
# Out:
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# |st_i94_cit|st_i94_port|st_i94_addr|st_i94_arrdate|st_i94_arrdate_iso|st_i94_depdate|st_i94_depdate_iso|st_i94_dtadfile|st_i94_matflag|st_i94_count|st_i94_id|st_i94_year|st_i94_month|
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# |254       |NYC        |KY         |20661         |2016-07-26        |0             |1900-01-01        |2016-07-26     |NA            |1           |8614304  |2016       |7           |
# |254       |BOS        |MA         |20661         |2016-07-26        |0             |1900-01-01        |2016-07-26     |NA            |1           |8682856  |2016       |7           |
# |254       |DET        |MA         |20661         |2016-07-26        |0             |1900-01-01        |2016-07-26     |NA            |1           |8650284  |2016       |7           |
# |0         |AGA        |CT         |20636         |2016-07-01        |0             |1900-01-01        |2016-07-01     |NA            |1           |7195700  |2016       |7           |
# |254       |LOS        |MA         |20661         |2016-07-26        |0             |1900-01-01        |2016-07-26     |NA            |1           |8619452  |2016       |7           |
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+
# only showing top 5 rows

# %%
# add column `st_i94_port_state_code` to data frame st_i94_immigrations
df_st_i94_immigrations = df_st_i94_immigrations \
    .join(df_st_immigration_airports,
          [df_st_i94_immigrations.st_i94_port == df_st_immigration_airports.st_ia_airport_code], 'left_outer') \
    .drop("st_ia_airport_code", "st_ia_airport_name") \
    .withColumnRenamed("st_ia_airport_state_code", "st_i94_port_state_code")

# %%
# rename
# check if `st_i94_port_state_code` has null values
df_st_i94_immigrations\
    .fillna(value='NA', subset=['st_i94_port_state_code'])\
    .groupBy("st_i94_port_state_code")\
    .count() \
    .sort("st_i94_port_state_code")\
    .orderBy("count")\
    .show(500)
# Out:
# +----------------------+-------+
# |st_i94_port_state_code|  count|
# +----------------------+-------+
# |                    NA|      1|
# |              ANTILLES|      4|
# |                    AR|      6|
# |                 JAPAN|      7|
# |                    IA|     14|
# |                    OK|     15|
# |                    MS|     20|
# |                    NE|     35|
# |            WASHINGTON|     40|
# |                    KY|     61|
# |                    KS|     82|
# |                BRAZIL|    113|
# |                    NH|    178|
# |                    VA|    207|
# |                    SC|    246|
# |                    AL|    265|
# |                Canada|    266|
# |                    WV|    432|
# |                    WI|    999|
# |                    IN|   1720|
# |                    NM|   1812|
# |                    TN|   2388|
# |                    CT|   2612|
# |                    MO|   2761|
# |               BERMUDA|   3084|
# |                    RI|   3085|
# |                    ID|   3086|
# |               BAHAMAS|   5055|
# |                    LA|   7671|
# |                    ND|  10712|
# |               IRELAND|  13085|
# |                    MT|  13234|
# |                    ME|  13283|
# |                    AK|  14118|
# |                    OH|  19155|
# |                    VI|  20196|
# |                    MD|  28986|
# |                    VT|  34992|
# |                CAIMAN|  37507|
# |                    OR|  42663|
# |                    UT|  43296|
# |                   SPN|  56091|
# |                    PR|  67409|
# |                CANADA|  70486|
# |    Invalid State Code|  79085|
# |                    AZ|  85820|
# |                    GU|  90049|
# |                    CO|  95135|
# |                    MN| 104198|
# |                    NC| 128321|
# |                    HI| 144079|
# |                    NV| 173905|
# |                    PA| 192605|
# |                    MI| 288534|
# |                    MA| 382419|
# |                    WA| 385673|
# |                    DC| 570668|
# |                    GA| 606096|
# |                    NJ| 663772|
# |                    IL| 792661|
# |                    TX|1204503|
# |                    FL|1856287|
# |                    NY|1889318|
# |                    CA|1974233|
# +----------------------+-------+

# %%
# get entry with null value
df_st_i94_immigrations \
    .filter(col("st_i94_port_state_code").isNull()).show()
# Out:
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+
# |st_i94_cit|st_i94_port|st_i94_addr|st_i94_arrdate|st_i94_arrdate_iso|st_i94_depdate|st_i94_depdate_iso|st_i94_dtadfile|st_i94_matflag|st_i94_count|st_i94_id|st_i94_year|st_i94_month|st_i94_port_state_code|
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+
# |       117|        OCA|         NY|         20682|        2016-08-16|             0|        1900-01-01|     2016-08-16|            NA|           1| 10124860|       2016|           8|                  null|
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+

# %%
# get status
print(df_st_i94_immigrations.count())
df_st_i94_immigrations.printSchema()
df_st_i94_immigrations.show(5, False)
# Out:
# 12228839
# root
#  |-- st_i94_cit: integer (nullable = true)
#  |-- st_i94_port: string (nullable = true)
#  |-- st_i94_addr: string (nullable = true)
#  |-- st_i94_arrdate: integer (nullable = true)
#  |-- st_i94_arrdate_iso: date (nullable = true)
#  |-- st_i94_depdate: integer (nullable = true)
#  |-- st_i94_depdate_iso: date (nullable = true)
#  |-- st_i94_dtadfile: date (nullable = true)
#  |-- st_i94_matflag: string (nullable = true)
#  |-- st_i94_count: integer (nullable = true)
#  |-- st_i94_id: integer (nullable = true)
#  |-- st_i94_year: integer (nullable = true)
#  |-- st_i94_month: integer (nullable = true)
#  |-- st_i94_port_state_code: string (nullable = true)
#
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+
# |st_i94_cit|st_i94_port|st_i94_addr|st_i94_arrdate|st_i94_arrdate_iso|st_i94_depdate|st_i94_depdate_iso|st_i94_dtadfile|st_i94_matflag|st_i94_count|st_i94_id|st_i94_year|st_i94_month|st_i94_port_state_code|
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+
# |254       |DAL        |KY         |20661         |2016-07-26        |20664         |2016-07-29        |2016-07-29     |M             |1           |8643306  |2016       |7           |TX                    |
# |0         |HHW        |99         |20636         |2016-07-01        |20713         |2016-09-16        |2016-07-01     |M             |1           |7195726  |2016       |7           |HI                    |
# |254       |DAL        |KY         |20661         |2016-07-26        |20670         |2016-08-04        |2016-08-04     |M             |1           |8626942  |2016       |7           |TX                    |
# |0         |NYC        |99         |20636         |2016-07-01        |20714         |2016-09-17        |2016-07-01     |M             |1           |7196164  |2016       |7           |NY                    |
# |254       |DAL        |KY         |20661         |2016-07-26        |20684         |2016-08-18        |2016-08-18     |M             |1           |8638982  |2016       |7           |TX                    |
# +----------+-----------+-----------+--------------+------------------+--------------+------------------+---------------+--------------+------------+---------+-----------+------------+----------------------+
# only showing top 5 rows

# %%
# write st_i94_immigrations back to file system
location_to_write = "../P8_capstone_resource_files/parquet_stage/PQ2/st_i94_immigrations"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_i94_immigrations \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .partitionBy('st_i94_year', 'st_i94_month') \
    .parquet(location_to_write, compression="gzip")

# %% [markdown]
# 3. Add new column `st_i94_port_state_code --> f_i94_port_state_code` to existing fact table `f_i94_immigrations`.

# %%
# Read data frames back into memory
# st_i94_immigrations with column `st_i94_port_state_code`:
location_st_i94_immigrations = "../P8_capstone_resource_files/parquet_stage/PQ2/st_i94_immigrations"
df_st_i94_immigrations = spark.read.parquet(location_st_i94_immigrations)

# f_i94_immigrations:
location_f_i94_immigrations = "../P8_capstone_resource_files/parquet_star/PQ1/f_i94_immigrations"
df_f_i94_immigrations = spark.read.parquet(location_f_i94_immigrations)

# show current schemas
print(df_st_i94_immigrations.count())
df_st_i94_immigrations.printSchema()

print(df_f_i94_immigrations.count())
df_f_i94_immigrations.printSchema()
# Out:
# 12228839
# root
#  |-- st_i94_cit: integer (nullable = true)
#  |-- st_i94_port: string (nullable = true)
#  |-- st_i94_addr: string (nullable = true)
#  |-- st_i94_arrdate: integer (nullable = true)
#  |-- st_i94_arrdate_iso: date (nullable = true)
#  |-- st_i94_depdate: integer (nullable = true)
#  |-- st_i94_depdate_iso: date (nullable = true)
#  |-- st_i94_dtadfile: date (nullable = true)
#  |-- st_i94_matflag: string (nullable = true)
#  |-- st_i94_count: integer (nullable = true)
#  |-- st_i94_id: integer (nullable = true)
#  |-- st_i94_port_state_code: string (nullable = true)
#  |-- st_i94_year: integer (nullable = true)
#  |-- st_i94_month: integer (nullable = true)
#
# 12228839
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)

# %%
# get only the needed columns to join
df_st_i94_immigrations_2_join = df_st_i94_immigrations \
    .select("st_i94_id", "st_i94_port_state_code")


# add new columns to fact table `df_f_i94_immigrations`
df_f_i94_immigrations = df_f_i94_immigrations  \
    .join(df_st_i94_immigrations_2_join, df_f_i94_immigrations.f_i94_id == df_st_i94_immigrations_2_join.st_i94_id, 'inner') \
    .drop("st_i94_id") \
    .withColumnRenamed("st_i94_port_state_code", "f_i94_port_state_code") \
    .withColumn("d_sd_id", col("f_i94_addr"))

# %%
df_f_i94_immigrations.printSchema()
df_f_i94_immigrations.show(5, False)
# Out:
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)
#  |-- f_i94_port_state_code: string (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+----------+-----------+---------------------+-------+
# |f_i94_cit|f_i94_port|f_i94_addr|f_i94_arrdate_iso|f_i94_depdate_iso|f_i94_dtadfile|f_i94_matflag|f_i94_count|f_i94_id|d_ic_id|d_ia_id|d_da_id   |d_dd_id   |f_i94_year|f_i94_month|f_i94_port_state_code|d_sd_id|
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+----------+-----------+---------------------+-------+
# |516      |NYC       |NY        |2016-12-06       |2017-02-07       |2016-12-07    |M            |1          |148     |516    |NYC    |2016-12-06|2017-02-07|2016      |12         |NY                   |NY     |
# |101      |NYC       |NY        |2016-01-25       |1900-01-01       |9999-12-31    |NA           |1          |463     |101    |NYC    |2016-01-25|1900-01-01|2016      |1          |NY                   |NY     |
# |101      |WAS       |VA        |2016-01-16       |2016-01-20       |2016-01-16    |M            |1          |471     |101    |WAS    |2016-01-16|2016-01-20|2016      |1          |DC                   |VA     |
# |516      |MIA       |FL        |2016-12-01       |2016-12-02       |2016-12-01    |M            |1          |496     |516    |MIA    |2016-12-01|2016-12-02|2016      |12         |FL                   |FL     |
# |101      |NYC       |NY        |2016-01-14       |2016-02-04       |2016-01-14    |M            |1          |833     |101    |NYC    |2016-01-14|2016-02-04|2016      |1          |NY                   |NY     |
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+----------+-----------+---------------------+-------+
# only showing top 5 rows

# %%
# write fact table f_i94_immigration (~ 109,7 MB)
location_to_write = "../P8_capstone_resource_files/parquet_star/PQ2/f_i94_immigrations"

if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_f_i94_immigrations \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .partitionBy("f_i94_year", "f_i94_month")\
    .parquet(location_to_write, compression="gzip")

# %% [markdown]
# 4. Creation of a dimension named `d_immigration_airports` based on staging table `st_immigration_airports`.

# %%
# st_immigration_airports:
location_st_immigration_airports = "../P8_capstone_resource_files/parquet_stage/PQ2/st_immigration_airports"
df_d_immigration_airports = spark.read.parquet(location_st_immigration_airports)

print(df_d_immigration_airports.count())
df_d_immigration_airports.printSchema()
df_d_immigration_airports.show(5, False)
# Out:
# 660
# root
#  |-- st_ia_airport_code: string (nullable = true)
#  |-- st_ia_airport_name: string (nullable = true)
#  |-- st_ia_airport_state_code: string (nullable = true)
#
# +------------------+---------------------------+------------------------+
# |st_ia_airport_code|st_ia_airport_name         |st_ia_airport_state_code|
# +------------------+---------------------------+------------------------+
# |ABE               |ABERDEEN                   |WA                      |
# |ADS               |ADDISON AIRPORT- ADDISON   |TX                      |
# |AGA               |AGANA                      |GU                      |
# |AGU               |AGUADILLA                  |PR                      |
# |BOI               |AIR TERM. (GOWEN FLD) BOISE|ID                      |
# +------------------+---------------------------+------------------------+
# only showing top 5 rows

# %%
df_d_immigration_airports = df_d_immigration_airports  \
    .withColumn("d_ia_id", df_d_immigration_airports.st_ia_airport_code) \
    .withColumnRenamed("st_ia_airport_code", "d_ia_airport_code") \
    .withColumnRenamed("st_ia_airport_name", "d_ia_airport_name") \
    .withColumnRenamed("st_ia_airport_state_code", "d_ia_airport_state_code")

df_d_immigration_airports.printSchema()
df_d_immigration_airports.show(5, False)
# Out:
# root
#  |-- d_ia_airport_code: string (nullable = true)
#  |-- d_ia_airport_name: string (nullable = true)
#  |-- d_ia_airport_state_code: string (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#
# +-----------------+---------------------------+-----------------------+-------+
# |d_ia_airport_code|d_ia_airport_name          |d_ia_airport_state_code|d_ia_id|
# +-----------------+---------------------------+-----------------------+-------+
# |ABE              |ABERDEEN                   |WA                     |ABE    |
# |ADS              |ADDISON AIRPORT- ADDISON   |TX                     |ADS    |
# |AGA              |AGANA                      |GU                     |AGA    |
# |AGU              |AGUADILLA                  |PR                     |AGU    |
# |BOI              |AIR TERM. (GOWEN FLD) BOISE|ID                     |BOI    |
# +-----------------+---------------------------+-----------------------+-------+
# only showing top 5 rows

# %%
# write dimension table d_immigration_airports to disk (~ 10 kB)
location_to_write = "../P8_capstone_resource_files/parquet_star/PQ2/d_immigration_airports"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_d_immigration_airports \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .parquet(location_to_write, compression="gzip")

# %% [markdown]
# 5. Mapping of dimension `d_immigration_airports` to  fact table `f_i94_immigration` based on columns
#    (`st_immigration_airports.st_ia_airport_code` --> `d_immigration_airports.d_ia_id`) ==
#    (`st_i94_immigration.st_i94_port` --> `f_i94_immigration.d_ia_id`).

# %% [markdown]
# 6. Answer Project Question 2: At what airports do foreign persons arrive for immigration to the U.S.?

# %%
# Read written data frame back into memory
df_f_i94_immigrations = spark.read.parquet("../P8_capstone_resource_files/parquet_star/PQ2/f_i94_immigrations")
df_d_immigration_airports = spark.read.parquet("../P8_capstone_resource_files/parquet_star/PQ2/d_immigration_airports")

# check read data frames
print(df_f_i94_immigrations.count())
df_f_i94_immigrations.printSchema()
df_f_i94_immigrations.show(5, False)

print(df_d_immigration_airports.count())
df_d_immigration_airports.printSchema()
df_d_immigration_airports.show(5, False)
# Out:
# 12228839
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_port_state_code: string (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)
#
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+---------------------+-------+----------+-----------+
# |f_i94_cit|f_i94_port|f_i94_addr|f_i94_arrdate_iso|f_i94_depdate_iso|f_i94_dtadfile|f_i94_matflag|f_i94_count|f_i94_id|d_ic_id|d_ia_id|d_da_id   |d_dd_id   |f_i94_port_state_code|d_sd_id|f_i94_year|f_i94_month|
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+---------------------+-------+----------+-----------+
# |0        |SFR       |CA        |2016-07-20       |2016-09-23       |2016-07-20    |M            |1          |7194720 |0      |SFR    |2016-07-20|2016-09-23|CA                   |CA     |2016      |7          |
# |0        |STT       |VQ        |2016-07-31       |1900-01-01       |2016-07-31    |NA           |1          |7194986 |0      |STT    |2016-07-31|1900-01-01|VI                   |VQ     |2016      |7          |
# |0        |DEN       |CA        |2016-07-11       |2016-09-16       |2016-07-11    |M            |1          |7194820 |0      |DEN    |2016-07-11|2016-09-16|CO                   |CA     |2016      |7          |
# |0        |TAM       |FL        |2016-07-29       |1900-01-01       |2016-07-29    |NA           |1          |7196142 |0      |TAM    |2016-07-29|1900-01-01|FL                   |FL     |2016      |7          |
# |0        |NYC       |AZ        |2016-07-01       |2016-09-24       |2016-07-01    |M            |1          |7195060 |0      |NYC    |2016-07-01|2016-09-24|NY                   |AZ     |2016      |7          |
# +---------+----------+----------+-----------------+-----------------+--------------+-------------+-----------+--------+-------+-------+----------+----------+---------------------+-------+----------+-----------+
# only showing top 5 rows
#
# 660
# root
#  |-- d_ia_airport_code: string (nullable = true)
#  |-- d_ia_airport_name: string (nullable = true)
#  |-- d_ia_airport_state_code: string (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#
# +-----------------+---------------------------+-----------------------+-------+
# |d_ia_airport_code|d_ia_airport_name          |d_ia_airport_state_code|d_ia_id|
# +-----------------+---------------------------+-----------------------+-------+
# |ABE              |ABERDEEN                   |WA                     |ABE    |
# |ADS              |ADDISON AIRPORT- ADDISON   |TX                     |ADS    |
# |AGA              |AGANA                      |GU                     |AGA    |
# |AGU              |AGUADILLA                  |PR                     |AGU    |
# |BOI              |AIR TERM. (GOWEN FLD) BOISE|ID                     |BOI    |
# +-----------------+---------------------------+-----------------------+-------+
# only showing top 5 rows

# %%
# Register data frames as Views
df_f_i94_immigrations.createOrReplaceTempView("f_i94_immigrations")
df_d_immigration_airports.createOrReplaceTempView("d_immigration_airports")

# SQL to answer project question 2 (From which country do immigrants come to the U.S. and how many?)
df_pq2 = spark.sql(" select   d_ia.d_ia_airport_code as airport_code"
                     "       ,d_ia.d_ia_airport_name as airport_name"
                     "       ,d_ia.d_ia_airport_state_code as airport_state_code"
                     "       ,sum(f_i94.f_i94_count) as immigrants"
                     "       ,RANK() OVER (ORDER BY count(f_i94.f_i94_count) desc) Immigration_airport_rank"
                     " from f_i94_immigrations f_i94"
                     " join d_immigration_airports d_ia on f_i94.d_ia_id = d_ia.d_ia_id"
                     " group by airport_code"
                     "       , airport_name"
                     "       , airport_state_code"
                     " order by Immigration_airport_rank asc ")

df_pq2.show(5000, False)
# Out:
# +------------+----------------------------+------------------+----------+------------------------+
# |airport_code|airport_name                |airport_state_code|immigrants|Immigration_airport_rank|
# +------------+----------------------------+------------------+----------+------------------------+
# |NYC         |NEW YORK                    |NY                |1669429   |1                       |
# |MIA         |MIAMI                       |FL                |1139100   |2                       |
# |LOS         |LOS ANGELES                 |CA                |1134611   |3                       |
# |CHI         |CHICAGO                     |IL                |792628    |4                       |
# |NEW         |NEWARK/TETERBORO            |NJ                |663630    |5                       |
# |SFR         |SAN FRANCISCO               |CA                |628438    |6                       |
# |HOU         |HOUSTON                     |TX                |609343    |7                       |
# |ATL         |ATLANTA                     |GA                |605856    |8                       |
# |WAS         |WASHINGTON                  |DC                |570668    |9                       |
# |DAL         |DALLAS                      |TX                |490050    |10                      |
# |BOS         |BOSTON                      |MA                |382112    |11                      |
# |FTL         |FORT LAUDERDALE             |FL                |337598    |12                      |
# |SEA         |SEATTLE                     |WA                |272207    |13                      |
# |DET         |DETROIT                     |MI                |262744    |14                      |
# |ORL         |ORLANDO                     |FL                |257311    |15                      |
# |PHI         |PHILADELPHIA                |PA                |185469    |16                      |
# |LVG         |LAS VEGAS                   |NV                |171358    |17                      |
# |HHW         |HONOLULU                    |HI                |131980    |18                      |
# |CLT         |CHARLOTTE                   |NC                |112025    |19                      |
# |SPM         |ST PAUL                     |MN                |101986    |20                      |
# |DEN         |DENVER                      |CO                |95133     |21                      |
# |AGA         |AGANA                       |GU                |90049     |22                      |
# |BLA         |BLAINE                      |WA                |89275     |23                      |
# |PHO         |PHOENIX                     |AZ                |72405     |24                      |
# |SAJ         |SAN JUAN                    |PR                |67010     |25                      |
# |SAI         |SAIPAN                      |SPN               |56091     |26                      |
# |TAM         |TAMPA                       |FL                |55731     |27                      |
# |NIA         |NIAGARA FALLS               |NY                |55369     |28                      |
# |PBB         |PEACE BRIDGE                |NY                |54885     |29                      |
# |SDP         |SAN DIEGO                   |CA                |54608     |30                      |
# |CHM         |CHAMPLAIN                   |NY                |45012     |31                      |
# |SLC         |SALT LAKE CITY              |UT                |43296     |32                      |
# |SNJ         |SAN JOSE                    |CA                |42772     |33                      |
# |POO         |PORTLAND                    |OR                |42652     |34                      |
# |XXX         |Invalid Airport Entry       |Invalid State Code|39376     |35                      |
# |NCA         |NORTH CAICOS TURK &         |CAIMAN            |37507     |36                      |
# |SYS         |SAN YSIDRO                  |CA                |34341     |37                      |
# |LEW         |LEWISTON                    |NY                |31932     |38                      |
# |SNA         |SAN ANTONIO                 |TX                |31129     |39                      |
# |BAL         |BALTIMORE                   |MD                |28804     |40                      |
# |PHU         |PORT HURON                  |MI                |23142     |41                      |
# |WPB         |WEST PALM BEACH             |FL                |22691     |42                      |
# |OAK         |OAKLAND                     |CA                |22445     |43                      |
# |X96         |Invalid Airport Entry       |Invalid State Code|21870     |44                      |
# |HIG         |HIGHGATE SPRINGS            |VT                |21619     |45                      |
# |VCV         |VANCOUVER                   |CANADA            |21200     |46                      |
# |TOR         |TORONTO                     |CANADA            |17259     |47                      |
# |STT         |ST THOMAS                   |VI                |17152     |48                      |
# |AUS         |AUSTIN                      |TX                |16832     |49                      |
# |RDU         |RALEIGH/DURHAM              |NC                |16106     |50                      |
# |FMY         |FORT MYERS                  |FL                |15555     |51                      |
# |YHC         |HAKAI PASS                  |CANADA            |15211     |52                      |
# |SAC         |SACRAMENTO                  |CA                |14540     |53                      |
# |OTM         |OTAY MESA                   |CA                |14182     |54                      |
# |MAA         |Abu Dhabi                   |Invalid State Code|14047     |55                      |
# |CIN         |CINCINNATI                  |OH                |12657     |56                      |
# |THO         |THOUSAND ISLAND BRIDGE      |NY                |12583     |57                      |
# |DER         |DERBY LINE VT (RT. 5)       |VT                |10390     |58                      |
# |DUB         |DUBLIN                      |IRELAND           |9766      |59                      |
# |SFB         |SANFORD                     |FL                |9604      |60                      |
# |SUM         |SUMAS                       |WA                |9499      |61                      |
# |PEM         |PEMBINA                     |ND                |8992      |62                      |
# |LLB         |JUAREZ-LINCOLN BRIDGE       |TX                |8583      |63                      |
# |ANC         |ANCHORAGE                   |AK                |8521      |64                      |
# |VIC         |VICTORIA                    |CANADA            |8518      |65                      |
# |LYN         |LYNDEN                      |WA                |8464      |66                      |
# |OGG         |KAHULUI - MAUI              |HI                |8423      |67                      |
# |BUF         |BUFFALO                     |NY                |8296      |68                      |
# |PSP         |PALM SPRINGS                |CA                |7940      |69                      |
# |ANZ         |ANZALDUAS                   |TX                |7844      |70                      |
# |OPF         |OPA LOCKA                   |FL                |7718      |71                      |
# |NOL         |NEW ORLEANS                 |LA                |7649      |72                      |
# |PIT         |PITTSBURG                   |PA                |6708      |73                      |
# |CAL         |CALEXICO                    |CA                |6697      |74                      |
# |ONT         |ONTARIO                     |CA                |6595      |75                      |
# |PEV         |PORT EVERGLADES             |FL                |5986      |76                      |
# |SWE         |SWEETGTASS                  |MT                |5431      |77                      |
# |TUC         |TUCSON                      |AZ                |5223      |78                      |
# |NAS         |NASSAU                      |BAHAMAS           |5049      |79                      |
# |MON         |MONTREAL                    |CANADA            |4562      |80                      |
# |BOA         |BRIDGE OF AMERICAS          |TX                |4352      |81                      |
# |YSL         |YSLETA                      |TX                |4342      |82                      |
# |BRO         |BROWNSVILLE                 |TX                |4263      |83                      |
# |MCA         |MCALLEN                     |TX                |4247      |84                      |
# |HID         |HIDALGO                     |TX                |4221      |85                      |
# |NOG         |NOGALES                     |AZ                |4030      |86                      |
# |LAR         |LAREDO                      |TX                |3888      |87                      |
# |CLE         |CLEVELAND                   |OH                |3799      |88                      |
# |CLS         |CALAIS                      |ME                |3407      |89                      |
# |BGM         |BANGOR                      |ME                |3385      |90                      |
# |SHA         |SHANNON                     |IRELAND           |3319      |91                      |
# |HAM         |HAMILTON                    |BERMUDA           |3084      |92                      |
# |HTM         |HOULTON                     |ME                |3072      |93                      |
# |PVD         |THEODORE FRANCIS - WARWICK  |RI                |2925      |94                      |
# |ROO         |ROOSVILLE                   |MT                |2819      |95                      |
# |OGD         |OGDENSBURG                  |NY                |2805      |96                      |
# |AXB         |ALEXANDRIA BAY              |NY                |2789      |97                      |
# |PDN         |PASO DEL NORTE              |TX                |2745      |98                      |
# |CLM         |COLUMBUS                    |OH                |2678      |99                      |
# |PHR         |PHARR                       |TX                |2669      |100                     |
# |EPI         |EASTPORT                    |ID                |2565      |101                     |
# |RNO         |CANNON INTL - RENO/TAHOE    |NV                |2493      |102                     |
# |PIE         |PIEGAN                      |MT                |2453      |103                     |
# |HAR         |HARTFORD                    |CT                |2420      |104                     |
# |LNB         |LONG BEACH                  |CA                |2366      |105                     |
# |SRQ         |BRADENTON - SARASOTA        |FL                |2362      |106                     |
# |KOA         |KEAHOLE-KONA                |HI                |2308      |107                     |
# |PIR         |POINT ROBERTS               |WA                |2270      |108                     |
# |ORO         |OROVILLE                    |WA                |2265      |109                     |
# |ALC         |ALCAN                       |AK                |2264      |110                     |
# |NSV         |NASHVILLE                   |TN                |2262      |111                     |
# |CLG         |CALGARY                     |CANADA            |2149      |112                     |
# |SSM         |SAULT STE. MARIE            |MI                |2084      |113                     |
# |CHR         |CHRISTIANSTED               |VI                |2080      |114                     |
# |ELP         |EL PASO                     |TX                |1937      |115                     |
# |SKA         |SKAGWAY                     |AK                |1924      |116                     |
# |TEC         |TECATE                      |CA                |1891      |117                     |
# |POR         |PORTAL                      |AZ                |1802      |118                     |
# |SAA         |SANTA ANA                   |CA                |1788      |119                     |
# |INP         |INDIANAPOLIS                |IN                |1720      |120                     |
# |LCB         |LAREDO COLUMBIA BRIDGE      |TX                |1587      |121                     |
# |STR         |SANTA TERESA                |NM                |1581      |122                     |
# |CHF         |CHIEF MT                    |MT                |1560      |123                     |
# |STL         |ST LOUIS                    |MO                |1552      |124                     |
# |JKM         |JACKMAN                     |ME                |1453      |125                     |
# |MAS         |MASSENA                     |NY                |1445      |126                     |
# |YGF         |Invalid Airport Entry       |Invalid State Code|1405      |127                     |
# |LIH         |LIHUE                       |HI                |1368      |128                     |
# |LOI         |LOS INDIOS                  |TX                |1361      |129                     |
# |JMZ         |Invalid Airport Entry       |Invalid State Code|1292      |130                     |
# |KAN         |KANSAS CITY                 |MO                |1209      |131                     |
# |HPN         |WESTCHESTER - WHITE PLAINS  |NY                |1081      |132                     |
# |VIB         |VETERAN INTL BRIDGE         |TX                |1036      |133                     |
# |ROC         |ROCHESTER                   |NY                |979       |134                     |
# |MIL         |MILWAUKEE                   |WI                |971       |135                     |
# |CHA         |CHARLOTTE AMALIE            |VI                |964       |136                     |
# |LUK         |LUKEVILLE                   |AZ                |960       |137                     |
# |GPM         |GRAND PORTAGE               |MN                |900       |138                     |
# |KEY         |KEY WEST                    |FL                |864       |139                     |
# |COB         |COBURN GORE                 |ME                |860       |140                     |
# |ROU         |ROUSES POINT                |NY                |840       |141                     |
# |SYR         |SYRACUSE                    |NY                |830       |142                     |
# |DOU         |DOUGLAS                     |AZ                |736       |143                     |
# |EGP         |EAGLE PASS                  |TX                |731       |144                     |
# |OTT         |OTTAWA                      |CANADA            |712       |145                     |
# |AND         |ANDRADE                     |CA                |709       |146                     |
# |DAC         |DALTONS CACHE               |AK                |705       |147                     |
# |DLR         |DEL RIO                     |TX                |606       |148                     |
# |FWA         |FRONTIER                    |WA                |576       |149                     |
# |EDA         |EDMONTON                    |CANADA            |553       |150                     |
# |INT         |INT''L FALLS                |MN                |549       |151                     |
# |SLU         |SAN LUIS                    |AZ                |537       |152                     |
# |PTL         |PORTHILL                    |ID                |521       |153                     |
# |CNA         |CANAAN                      |VT                |496       |154                     |
# |DNS         |DUNSEITH                    |ND                |485       |155                     |
# |DNA         |DONNA                       |TX                |484       |156                     |
# |MLB         |MELBOURNE                   |FL                |482       |157                     |
# |WBE         |WEST BERKSHIRE              |VT                |467       |158                     |
# |FRB         |FAIRBANKS                   |AK                |461       |159                     |
# |POM         |PORTLAND                    |ME                |457       |160                     |
# |PGR         |PROGRESO                    |TX                |454       |161                     |
# |SPE         |ST PETERSBURG               |FL                |439       |162                     |
# |CHS         |CHARLESTON                  |WV                |432       |163                     |
# |MET         |METALINE FALLS              |WA                |426       |164                     |
# |MDT         |HARRISBURG                  |PA                |413       |165                     |
# |NRT         |NORTH TROY                  |VT                |404       |166                     |
# |RIF         |RICHFORT                    |VT                |402       |167                     |
# |RAY         |RAYMOND                     |MT                |401       |168                     |
# |W55         |Invalid Airport Entry       |Invalid State Code|391       |169                     |
# |ABG         |ALBURG                      |VT                |342       |170                     |
# |WIN         |WINNIPEG                    |CANADA            |322       |171                     |
# |MRC         |MARINE CITY                 |MI                |319       |172                     |
# |BED         |HANSCOM FIELD - BEDFORD     |MA                |307       |173                     |
# |BQN         |BORINQUEN - AGUADILLO       |PR                |303       |174                     |
# |PRE         |PRESIDIO                    |TX                |301       |175                     |
# |JAC         |JACKSONVILLE                |FL                |277       |176                     |
# |TRO         |TROUT RIVER                 |NY                |276       |177                     |
# |HAL         |Halifax NS                  |Canada            |266       |178                     |
# |SAV         |SAVANNAH                    |GA                |240       |179                     |
# |ROM         |ROMA                        |TX                |238       |180                     |
# |FPR         |ST LUCIE COUNTY             |FL                |237       |181                     |
# |WAL         |WALHALLA                    |ND                |233       |182                     |
# |SGR         |HULL FIELD SUGAR LAND ARPT  |TX                |229       |183                     |
# |MOB         |MOBILE                      |AL                |226       |184                     |
# |DLB         |DEL BONITA                  |MT                |223       |185                     |
# |VNY         |VAN NUYS                    |CA                |209       |186                     |
# |LAU         |LAURIER                     |WA                |203       |187                     |
# |LAN         |LANCASTER                   |MN                |198       |188                     |
# |MOO         |MOORES                      |NY                |196       |189                     |
# |NRN         |NORTON                      |VT                |192       |190                     |
# |WIL         |WILMINGTON                  |NC                |190       |191                     |
# |ABS         |ALBURG SPRINGS              |VT                |189       |192                     |
# |COL         |COLUMBUS                    |NM                |185       |193                     |
# |MAF         |ODESSA REGIONAL             |TX                |182       |194                     |
# |ADW         |ANDREWS AFB                 |MD                |182       |194                     |
# |MAD         |MADAWASKA                   |ME                |179       |196                     |
# |WAR         |WARROAD                     |MN                |179       |196                     |
# |NOR         |NORFOLK                     |VA                |175       |198                     |
# |FRT         |FORTUNA                     |ND                |175       |198                     |
# |CHT         |CHATEAUGAY                  |NY                |170       |200                     |
# |ADS         |ADDISON AIRPORT- ADDISON    |TX                |170       |200                     |
# |MOR         |MORSES LINE                 |VT                |170       |200                     |
# |CHL         |CHARLESTON                  |SC                |163       |203                     |
# |PRO         |PROVIDENCE                  |RI                |160       |204                     |
# |ROS         |ROSEAU                      |MN                |160       |204                     |
# |FOK         |SUFFOLK COUNTY              |NY                |160       |204                     |
# |KET         |KETCHIKAN                   |AK                |158       |207                     |
# |HVR         |HAVRE                       |MT                |156       |208                     |
# |X44         |Invalid Airport Entry       |Invalid State Code|150       |209                     |
# |GAL         |GALVESTON                   |TX                |148       |210                     |
# |FER         |FERRY                       |WA                |144       |211                     |
# |5T6         |Invalid Airport Entry       |Invalid State Code|137       |212                     |
# |BDL         |BRADLEY INTERNATIONAL       |CT                |135       |213                     |
# |NEC         |NECHE                       |ND                |131       |214                     |
# |HNS         |HANSBORO                    |ND                |131       |214                     |
# |FTC         |FORT COVINGTON              |NY                |130       |216                     |
# |AGN         |ALGONAC                     |MI                |130       |216                     |
# |MEM         |MEMPHIS                     |TN                |126       |218                     |
# |PSM         |PORTSMOUTH                  |NH                |125       |219                     |
# |BWA         |BOUNDARY                    |WA                |125       |219                     |
# |NAC         |NACO                        |AZ                |121       |221                     |
# |RST         |ROCHESTER                   |MN                |119       |222                     |
# |MMU         |MORRISTOWN                  |NJ                |117       |223                     |
# |CRQ         |CARAVELAS BA #ARPT          |BRAZIL            |113       |224                     |
# |BEB         |BEEBE PLAIN                 |VT                |111       |225                     |
# |ADT         |AMISTAD DAM                 |TX                |107       |226                     |
# |NRG         |NORTHGATE                   |ND                |106       |227                     |
# |LUB         |LUBEC                       |ME                |106       |227                     |
# |BEE         |BEECHER FALLS               |VT                |104       |229                     |
# |DVL         |DANVILLE                    |WA                |99        |230                     |
# |CRP         |CORPUS CHRISTI              |TX                |96        |231                     |
# |TUR         |TURNER                      |MT                |93        |232                     |
# |APF         |NAPLES                      |FL                |87        |233                     |
# |PTK         |OAKLAND COUNTY - PONTIAC    |MI                |87        |233                     |
# |FTF         |FORT FAIRFIELD              |ME                |85        |235                     |
# |AUH         |Invalid Airport Entry       |Invalid State Code|84        |236                     |
# |NOO         |NOONAN                      |ND                |84        |236                     |
# |ICT         |MID-CONTINENT - WITCHITA    |KS                |82        |238                     |
# |BRG         |BURLINGTON                  |VT                |80        |239                     |
# |BWM         |BRIDGEWATER                 |ME                |74        |240                     |
# |WHO         |WESTHOPE                    |ND                |72        |241                     |
# |PAR         |PORT ARTHUR                 |TX                |71        |242                     |
# |VNB         |VAN BUREN                   |ME                |69        |243                     |
# |PCF         |PORT CANAVERAL              |FL                |64        |244                     |
# |DAB         |DAYTONA BEACH INTERNATIONAL |FL                |64        |244                     |
# |GSP         |GREENVILLE                  |SC                |63        |246                     |
# |FAL         |FALCON HEIGHTS              |TX                |61        |247                     |
# |FAR         |FARGO                       |ND                |60        |248                     |
# |FTK         |FORT KENT                   |ME                |58        |249                     |
# |SHR         |SHERWOOD                    |ND                |57        |250                     |
# |TST         |NEWINGTON DATA CENTER TEST  |CT                |56        |251                     |
# |REN         |RENO                        |NV                |54        |252                     |
# |SWF         |STEWART - ORANGE CNTY       |NY                |54        |252                     |
# |CRY         |CARBURY                     |ND                |54        |252                     |
# |FPT         |FREEPORT                    |TX                |54        |252                     |
# |SPC         |SAN PEDRO                   |CA                |50        |256                     |
# |SJO         |ST JOHN                     |ND                |49        |257                     |
# |FAJ         |FAJARDO                     |PR                |49        |257                     |
# |FRE         |FRESNO                      |CA                |49        |257                     |
# |RIO         |RIO GRANDE CITY             |TX                |49        |257                     |
# |BAU         |BAUDETTE                    |MN                |48        |261                     |
# |CXO         |Invalid Airport Entry       |Invalid State Code|47        |262                     |
# |GAC         |Invalid Airport Entry       |Invalid State Code|46        |263                     |
# |SGJ         |ST AUGUSTINE ARPT           |FL                |45        |264                     |
# |JFA         |Invalid Airport Entry       |Invalid State Code|43        |265                     |
# |LEX         |BLUE GRASS - LEXINGTON      |KY                |43        |265                     |
# |VCB         |VANCEBORO                   |ME                |41        |267                     |
# |PEN         |PENSACOLA                   |FL                |41        |267                     |
# |NIG         |NIGHTHAWK                   |WA                |41        |267                     |
# |BLI         |BELLINGHAM                  |WASHINGTON        |40        |270                     |
# |ABQ         |ALBUQUERQUE                 |NM                |40        |270                     |
# |BZN         |GALLATIN FIELD - BOZEMAN    |MT                |40        |270                     |
# |5KE         |KETCHIKAN                   |AK                |38        |273                     |
# |NYL         |Invalid Airport Entry       |Invalid State Code|38        |273                     |
# |DUL         |DULUTH                      |MN                |36        |275                     |
# |HLG         |HARLINGEN                   |TX                |36        |275                     |
# |SPO         |SPOKANE                     |WA                |36        |275                     |
# |OMA         |OMAHA                       |NE                |35        |278                     |
# |BHX         |BIRMINGHAM                  |AL                |32        |279                     |
# |ALB         |ALBANY                      |NY                |32        |279                     |
# |PNH         |PITTSBURG                   |NH                |30        |281                     |
# |FAB         |FABENS                      |TX                |29        |282                     |
# |JUN         |JUNEAU                      |AK                |26        |283                     |
# |GRB         |GREEN BAY                   |WI                |26        |283                     |
# |ERC         |EAST RICHFORD               |VT                |26        |283                     |
# |MHT         |MANCHESTER                  |NH                |23        |286                     |
# |GRF         |GRAND FORKS                 |ND                |23        |286                     |
# |RCM         |RICHMOND                    |VA                |23        |286                     |
# |FPF         |FORT PIERCE                 |FL                |23        |286                     |
# |BTN         |BATON ROUGE                 |LA                |22        |290                     |
# |MTH         |Invalid Airport Entry       |Invalid State Code|21        |291                     |
# |DOV         |DOVER AFB                   |Invalid State Code|21        |291                     |
# |LIM         |LIMESTONE                   |ME                |20        |293                     |
# |PIN         |PINE CREEK                  |MN                |20        |293                     |
# |RYY         |Invalid Airport Entry       |Invalid State Code|20        |293                     |
# |WRI         |MC GUIRE AFB - WRIGHTSOWN   |NJ                |20        |293                     |
# |MAI         |MAIDA                       |ND                |20        |293                     |
# |HEL         |HELENA                      |MT                |19        |298                     |
# |YIP         |WILLOW RUN - YPSILANTI      |MI                |19        |298                     |
# |WLL         |WILMINGTON                  |Invalid State Code|19        |298                     |
# |LOU         |LOUISVILLE                  |KY                |18        |301                     |
# |PON         |PONCE                       |PR                |17        |302                     |
# |ANT         |ANTLER                      |ND                |17        |302                     |
# |SDY         |SANDUSKY                    |OH                |16        |304                     |
# |MND         |MINOT                       |ND                |16        |304                     |
# |DPA         |DUPAGE COUNTY               |IL                |16        |304                     |
# |ERI         |ERIE                        |PA                |15        |307                     |
# |SUS         |Invalid Airport Entry       |Invalid State Code|15        |307                     |
# |OKC         |OKLAHOMA CITY               |OK                |15        |307                     |
# |DSM         |DES MOINES                  |IA                |14        |310                     |
# |MWH         |MOSES LAKE GRANT COUNTY ARPT|WA                |13        |311                     |
# |TKI         |TOKEEN                      |AK                |13        |311                     |
# |AGU         |AGUADILLA                   |PR                |12        |313                     |
# |HML         |HAMIIN                      |ME                |12        |313                     |
# |AFW         |FORT WORTH ALLIANCE         |TX                |12        |313                     |
# |PCW         |Invalid Airport Entry       |Invalid State Code|12        |313                     |
# |OGS         |Invalid Airport Entry       |Invalid State Code|12        |313                     |
# |MYR         |MYRTLE BEACH                |SC                |11        |318                     |
# |PAS         |PASCAGOULA                  |MS                |11        |318                     |
# |RFD         |GREATER ROCKFORD            |IL                |10        |320                     |
# |FRI         |FRIDAY HARBOR               |WA                |10        |320                     |
# |WRB         |WHIRLPOOL BRIDGE            |NY                |10        |320                     |
# |ATW         |Invalid Airport Entry       |Invalid State Code|9         |323                     |
# |HEF         |MANASSAS                    |VA                |9         |323                     |
# |MGM         |MORGAN                      |MT                |9         |323                     |
# |HIO         |HILLSBORO                   |OR                |8         |326                     |
# |CNC         |CANNON CORNERS              |NY                |8         |326                     |
# |LSE         |LOS EBANOS                  |TX                |8         |326                     |
# |GUL         |GULFPORT                    |MS                |8         |326                     |
# |PSE         |PONCE-MERCEDITA             |PR                |8         |326                     |
# |FCA         |GLACIER NATIONAL PARK       |MT                |8         |326                     |
# |BEL         |BELLINGHAM                  |WA                |7         |332                     |
# |SNN         |SANDERSON                   |TX                |7         |332                     |
# |VQS         |VIEQUES-ARPT                |PR                |7         |332                     |
# |LWT         |LEWISTON                    |MT                |7         |332                     |
# |Y62         |Invalid Airport Entry       |Invalid State Code|7         |332                     |
# |PKC         |POKER CREEK                 |AK                |7         |332                     |
# |UGN         |MEMORIAL - WAUKEGAN         |IL                |7         |332                     |
# |HSV         |MADISON COUNTY - HUNTSVILLE |AL                |7         |332                     |
# |GRP         |GRAND RAPIDS                |MI                |7         |332                     |
# |CAE         |COLUMBIA                    |SC                |7         |332                     |
# |IWA         |IWAKUNI                     |JAPAN             |7         |332                     |
# |RME         |ROME                        |NY                |6         |343                     |
# |ROG         |ROGERS ARPT                 |AR                |6         |343                     |
# |ANP         |ANTELOPE WELLS              |NM                |6         |343                     |
# |FBA         |FREEPORT                    |BAHAMAS           |6         |343                     |
# |PNG         |PORT ANGELES                |WA                |5         |347                     |
# |SAS         |SASABE                      |AZ                |5         |347                     |
# |LEE         |LEESBURG MUNICIPAL AIRPORT  |FL                |5         |347                     |
# |WCM         |WILLOW CREEK                |MT                |5         |347                     |
# |CTB         |CUT BANK MUNICIPAL          |MT                |5         |347                     |
# |TIW         |Invalid Airport Entry       |Invalid State Code|4         |352                     |
# |PHF         |Invalid Airport Entry       |Invalid State Code|4         |352                     |
# |CAK         |AKRON                       |OH                |4         |352                     |
# |ACY         |POMONA FIELD - ATLANTIC CITY|NJ                |4         |352                     |
# |LON         |LONGVIEW                    |WA                |4         |352                     |
# |WND         |WILLISTON                   |ND                |4         |352                     |
# |SPA         |ST PAMPILE                  |ME                |4         |352                     |
# |CPX         |Invalid Airport Entry       |Invalid State Code|4         |352                     |
# |ARB         |ARUBA NETH                  |ANTILLES          |4         |352                     |
# |NC8         |Invalid Airport Entry       |Invalid State Code|3         |361                     |
# |COO         |COOS BAY                    |OR                |3         |361                     |
# |WHM         |WILD HORSE                  |MT                |3         |361                     |
# |MAY         |MAYAGUEZ                    |PR                |3         |361                     |
# |48Y         |PINECREEK BORDER ARPT       |MN                |2         |365                     |
# |RIV         |RIVERSIDE                   |CA                |2         |365                     |
# |HNN         |HANNAH                      |ND                |2         |365                     |
# |GRR         |GREER                       |SC                |2         |365                     |
# |AGM         |ALGOMA                      |WI                |2         |365                     |
# |ANA         |ANACORTES                   |WA                |2         |365                     |
# |APA         |ARAPAHOE COUNTY             |CO                |2         |365                     |
# |ABE         |ABERDEEN                    |WA                |2         |365                     |
# |SCO         |SCOBEY                      |MT                |2         |365                     |
# |SAG         |SAGINAW                     |MI                |2         |365                     |
# |DAY         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |FTH         |FORT HANCOCK                |TX                |1         |375                     |
# |CLA         |CLAYTON                     |NY                |1         |375                     |
# |TOL         |TOLEDO                      |OH                |1         |375                     |
# |PFN         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |SAR         |SARLES                      |ND                |1         |375                     |
# |RGM         |RANGELEY                    |ME                |1         |375                     |
# |GMT         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |ASI         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |SAU         |ST AUGUSTINE                |FL                |1         |375                     |
# |BKF         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |SCH         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |PAN         |PANAMA CITY                 |FL                |1         |375                     |
# |GPT         |BILOXI REGIONAL             |MS                |1         |375                     |
# |OTS         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |74S         |Invalid Airport Entry       |Invalid State Code|1         |375                     |
# |BOC         |BOCAGRANDE                  |FL                |1         |375                     |
# |YUM         |YUMA                        |AZ                |1         |375                     |
# |NWH         |NEW HAVEN                   |CT                |1         |375                     |
# |HOM         |HOMER                       |AK                |1         |375                     |
# |CRA         |CRANE LAKE                  |MN                |1         |375                     |
# |PER         |PERTH AMBOY                 |NJ                |1         |375                     |
# +------------+----------------------------+------------------+----------+------------------------+
