# %% [markdown]
# # Project 08 - Analysis of U.S. Immigration (I-94) Data
# ### Udacity Data Engineer - Capstone Project
# > by Peter Wissel | 2021-04-03
#
# ## Project Overview
# This project works with a data set for immigration to the United States. The supplementary datasets will include data on
# airport codes, U.S. city demographics and temperature data.
#
# The following process is divided into five sub-steps to illustrate how to answer the questions set by the business
# analytics team.
#
# The project file follows the following steps:
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
#
# ##### 3.1.4. To which states in the U.S. do immigrants want to continue their travel after their initial arrival and what demographics can immigrants expect when they arrive in the destination state, such as average temperature, population numbers or population density? [(Data pipeline)](#question4_data_pipeline) <a name="question4_description">
# 1. Clean data and create staging table `st_state_destinations` from file
#    [I94_SAS_Labels_I94ADDR.txt](../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94ADDR.txt)
#    based on columns `st_sd_state_code` and `st_sd_state_name`.
# 2. Extract some demographic data from file [us-cities-demographics.json](../P8_capstone_resource_files/us-cities-demographics.json)
#    like `age_median`, `population_male`, `population_female`, `population_total` or `foreign_born` and add them to staging
#    table `st_state_destinations`.
# 3. Creation of a dimension named `d_state_destinations` based on staging table `st_state_destinations`.
# 4. Mapping of dimension `d_state_destinations` to  fact table `f_i94_immigration` based on columns
#    (`st_state_destinations.st_sd_state_code` --> `d_state_destinations.d_sd_id`) ==
#    (`st_i94_immigration.st_i94_addr` --> `f_i94_immigration.d_sd_id`).
# 5. Clean fact table `f_i94_immigration` based on the dimension `d_state_destinations`. All unrecognizable columns will
#    be set to 99 (all other countries).
# 6. Answer Project Question 4: To which states in the U.S. do immigrants want to continue their travel after their initial
#    arrival and what demographics can immigrants expect when they arrive in the destination state, such as average
#    temperature, population numbers or population density?

# %% [markdown]
# ##### 4.1.4. To which states in the U.S. do immigrants want to continue their travel after their initial arrival and what demographics can immigrants expect when they arrive in the destination state, such as average temperature, population numbers or population density? [(Data description)](#question4_description) <a name="question4_data_pipeline">
# 1. Clean data and create staging table `st_state_destinations` from file
#    [I94_SAS_Labels_I94ADDR.txt](../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94ADDR.txt)
#    based on columns `st_sd_state_code` and `st_sd_state_name`.

# %%
###### Imports and Installs section
import shutil
import pandas as pd
import pyspark.sql.functions as F
# import spark as spark
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, IntegerType, LongType, TimestampType, DateType
from datetime import datetime, timedelta
from pyspark.sql import SparkSession, DataFrameNaFunctions
from pyspark.sql.functions import when, count, col, to_date, datediff, date_format, month
import re
import json
from os import path

MAX_MEMORY = "5g"

spark = SparkSession\
    .builder\
    .appName("etl pipeline for project 8 - I94 data") \
    .config("spark.jars.packages","saurfang:spark-sas7bdat:3.0.0-s_2.12")\
    .config('spark.sql.repl.eagerEval.enabled', True) \
    .config("spark.executor.memory", MAX_MEMORY) \
    .config("spark.driver.memory", MAX_MEMORY) \
    .appName("Foo") \
    .enableHiveSupport()\
    .getOrCreate()

# setting the current LOG-Level
spark.sparkContext.setLogLevel('ERROR')

# %%
# get data
location_to_read = "../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94ADDR.txt"
df_st_I94_SAS_Labels_I94ADDR = spark.read.text(location_to_read)

df_st_I94_SAS_Labels_I94ADDR.printSchema()
df_st_I94_SAS_Labels_I94ADDR.show(5, False)

# get regex_cleaned values -->
regex_cleaned = r"^\s+'([9+A-Z]+)'='([A-Z\s.]+)'"

df_st_I94_SAS_Labels_I94ADDR_regex_cleaned = df_st_I94_SAS_Labels_I94ADDR \
    .select( F.regexp_extract('value',regex_cleaned, 1).alias('st_sd_state_code'),
             F.regexp_extract('value',regex_cleaned, 2).alias('st_sd_state_name')) \
    .drop_duplicates() \
    .orderBy("st_sd_state_code")

print(df_st_I94_SAS_Labels_I94ADDR_regex_cleaned.count())
df_st_I94_SAS_Labels_I94ADDR_regex_cleaned.show(100)
# Out:
# root
#  |-- value: string (nullable = true)
#
# +------------------+
# |value             |
# +------------------+
# |	'AL'='ALABAMA'   |
# |	'AK'='ALASKA'    |
# |	'AZ'='ARIZONA'   |
# |	'AR'='ARKANSAS'  |
# |	'CA'='CALIFORNIA'|
# +------------------+
# only showing top 5 rows
#
# 55
# +----------------+-----------------+
# |st_sd_state_code| st_sd_state_name|
# +----------------+-----------------+
# |              99|  ALL OTHER CODES|
# |              AK|           ALASKA|
# |              AL|          ALABAMA|
# |              AR|         ARKANSAS|
# |              AZ|          ARIZONA|
# |              CA|       CALIFORNIA|
# |              CO|         COLORADO|
# |              CT|      CONNECTICUT|
# |              DC|DIST. OF COLUMBIA|
# |              DE|         DELAWARE|
# |              FL|          FLORIDA|
# |              GA|          GEORGIA|
# |              GU|             GUAM|
# |              HI|           HAWAII|
# |              IA|             IOWA|
# |              ID|            IDAHO|
# |              IL|         ILLINOIS|
# |              IN|          INDIANA|
# |              KS|           KANSAS|
# |              KY|         KENTUCKY|
# |              LA|        LOUISIANA|
# |              MA|    MASSACHUSETTS|
# |              MD|         MARYLAND|
# |              ME|            MAINE|
# |              MI|         MICHIGAN|
# |              MN|        MINNESOTA|
# |              MO|         MISSOURI|
# |              MS|      MISSISSIPPI|
# |              MT|          MONTANA|
# |              NC|      N. CAROLINA|
# |              ND|        N. DAKOTA|
# |              NE|         NEBRASKA|
# |              NH|    NEW HAMPSHIRE|
# |              NJ|       NEW JERSEY|
# |              NM|       NEW MEXICO|
# |              NV|           NEVADA|
# |              NY|         NEW YORK|
# |              OH|             OHIO|
# |              OK|         OKLAHOMA|
# |              OR|           OREGON|
# |              PA|     PENNSYLVANIA|
# |              PR|      PUERTO RICO|
# |              RI|     RHODE ISLAND|
# |              SC|      S. CAROLINA|
# |              SD|        S. DAKOTA|
# |              TN|        TENNESSEE|
# |              TX|            TEXAS|
# |              UT|             UTAH|
# |              VA|         VIRGINIA|
# |              VI|   VIRGIN ISLANDS|
# |              VT|          VERMONT|
# |              WA|       WASHINGTON|
# |              WI|        WISCONSIN|
# |              WV|      W. VIRGINIA|
# |              WY|          WYOMING|
# +----------------+-----------------+

# %%
# This step is optional
location_to_write = "../P8_capstone_resource_files/I94_sas_labels_descriptions_extracted_data/I94_SAS_Labels_I94ADDR.csv"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_I94_SAS_Labels_I94ADDR_regex_cleaned\
    .coalesce(1)\
    .write\
    .option("header", "true")\
    .csv(location_to_write, mode='overwrite')

# %% [markdown]
# 2. Extract some demographic data from file [us-cities-demographics.json](../P8_capstone_resource_files/us-cities-demographics.json)
#    like `age_median`, `population_male`, `population_female`, `population_total` or `foreign_born` and add them to staging
#    table `st_state_destinations`.

# %%
# get data from JSON-file
location_to_read = "../P8_capstone_resource_files/us-cities-demographics.json"
df_us_cities_demographics = spark.read.json(location_to_read)

print(df_us_cities_demographics.count())
df_us_cities_demographics.printSchema()
# Out:
# 2891
# root
#  |-- datasetid: string (nullable = true)
#  |-- fields: struct (nullable = true)
#  |    |-- average_household_size: double (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- female_population: long (nullable = true)
#  |    |-- foreign_born: long (nullable = true)
#  |    |-- male_population: long (nullable = true)
#  |    |-- median_age: double (nullable = true)
#  |    |-- number_of_veterans: long (nullable = true)
#  |    |-- race: string (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- state_code: string (nullable = true)
#  |    |-- total_population: long (nullable = true)
#  |-- record_timestamp: string (nullable = true)
#  |-- recordid: string (nullable = true)

# %%
#Check data for further processing
df_us_cities_demographics \
    .filter("fields.state == 'Alabama'") \
    .select("fields.state_code"
            , "fields.state"
            , "fields.city"
            , "fields.median_age"
            , "fields.male_population"
            , "fields.female_population"
            , "fields.total_population"
            , "fields.foreign_born") \
    .distinct()\
    .orderBy("fields.state_code")\
    .show(50)
# Out:
# +----------+-------+----------+----------+---------------+-----------------+----------------+------------+
# |state_code|  state|      city|median_age|male_population|female_population|total_population|foreign_born|
# +----------+-------+----------+----------+---------------+-----------------+----------------+------------+
# |        AL|Alabama|Tuscaloosa|      29.1|          47293|            51045|           98338|        4706|
# |        AL|Alabama|    Dothan|      38.9|          32172|            35364|           67536|        1699|
# |        AL|Alabama|Huntsville|      38.1|          91764|            97350|          189114|       12691|
# |        AL|Alabama|    Mobile|      38.0|          91275|           103030|          194305|        7234|
# |        AL|Alabama|Birmingham|      35.6|         102122|           112789|          214911|        8258|
# |        AL|Alabama|Montgomery|      35.4|          94582|           106004|          200586|        9337|
# |        AL|Alabama|    Hoover|      38.5|          38040|            46799|           84839|        8229|
# +----------+-------+----------+----------+---------------+-----------------+----------------+------------+

# %%
# Get only values aggregated by state and not the city values.
df_us_cities_demographics_agg = df_us_cities_demographics \
    .groupBy("fields.state_code", "fields.state") \
    .agg(  F.round(F.avg('fields.median_age'),1).alias('st_sd_age_median')
          ,F.round(F.avg('fields.male_population').cast(IntegerType()),2).alias('st_sd_population_male')
          ,F.round(F.avg('fields.female_population').cast(IntegerType()),2).alias('st_sd_population_female')
          ,F.round(F.avg('fields.total_population').cast(IntegerType()),2).alias('st_sd_population_total')
          ,F.round(F.avg('fields.foreign_born').cast(IntegerType()),2).alias('st_sd_foreign_born')
           ) \
    .orderBy("fields.state_code")\
    .withColumnRenamed("fields.state_code", "state_code")\
    .withColumnRenamed("fields.state", "state")

# %%
print(df_us_cities_demographics_agg.count())
df_us_cities_demographics_agg.printSchema()
df_us_cities_demographics_agg.show(500)
# Out:
# 49
# root
#  |-- state_code: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- st_sd_age_median: double (nullable = true)
#  |-- st_sd_population_male: integer (nullable = true)
#  |-- st_sd_population_female: integer (nullable = true)
#  |-- st_sd_population_total: integer (nullable = true)
#  |-- st_sd_foreign_born: integer (nullable = true)
#
# +----------+--------------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |state_code|               state|st_sd_age_median|st_sd_population_male|st_sd_population_female|st_sd_population_total|st_sd_foreign_born|
# +----------+--------------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |        AK|              Alaska|            32.2|               152945|                 145750|                298695|             33258|
# |        AL|             Alabama|            36.2|                72005|                  79856|                151861|              7427|
# |        AR|            Arkansas|            32.7|                48300|                  51109|                 99409|             10612|
# |        AZ|             Arizona|            35.0|               139215|                 142005|                281221|             42644|
# |        CA|          California|            36.2|                90319|                  92290|                182609|             54821|
# |        CO|            Colorado|            35.8|                90913|                  92565|                183479|             21101|
# |        CT|         Connecticut|            35.0|                54447|                  57222|                111669|             28570|
# |        DC|District of Columbia|            33.8|               319705|                 352523|                672228|             95117|
# |        DE|            Delaware|            36.4|                32680|                  39277|                 71957|              3336|
# |        FL|             Florida|            39.5|                70602|                  75919|                145523|             35340|
# |        GA|             Georgia|            33.8|                74574|                  80973|                155548|             13435|
# |        HI|              Hawaii|            41.4|               176807|                 175959|                352766|            101312|
# |        IA|                Iowa|            32.5|                52119|                  53880|                106000|              9112|
# |        ID|               Idaho|            34.8|                66367|                  66593|                132961|              9375|
# |        IL|            Illinois|            35.7|               120262|                 127148|                247410|             50907|
# |        IN|             Indiana|            33.8|                86272|                  92115|                178388|             13992|
# |        KS|              Kansas|            34.8|                80592|                  83447|                164039|             16949|
# |        KY|            Kentucky|            36.0|               226241|                 238697|                464938|             33244|
# |        LA|           Louisiana|            34.6|                78374|                  84199|                162574|             10427|
# |        MA|       Massachusetts|            35.5|                70160|                  74723|                144884|             37301|
# |        MD|            Maryland|            36.4|                62795|                  68417|                131212|             22979|
# |        ME|               Maine|            40.3|                31480|                  35392|                 66872|              9229|
# |        MI|            Michigan|            37.0|                66041|                  71746|                137787|             15374|
# |        MN|           Minnesota|            35.6|                64422|                  66025|                130447|             19812|
# |        MO|            Missouri|            34.9|                81473|                  87325|                168799|             11010|
# |        MS|         Mississippi|            33.2|                58625|                  68212|                126838|              2359|
# |        MT|             Montana|            35.5|                43853|                  46793|                 90647|              2988|
# |        NC|      North Carolina|            33.8|               104721|                 113863|                218585|             27094|
# |        ND|        North Dakota|            34.3|                47617|                  47127|                 94745|              5746|
# |        NE|            Nebraska|            33.3|               178666|                 181950|                360616|             35610|
# |        NH|       New Hampshire|            37.8|                48885|                  50213|                 99099|             13599|
# |        NJ|          New Jersey|            35.3|                60053|                  61543|                121596|             40837|
# |        NM|          New Mexico|            37.8|               102252|                 107508|                209760|             22278|
# |        NV|              Nevada|            36.1|               124293|                 124677|                248971|             53481|
# |        NY|            New York|            35.6|               433755|                 473689|                907445|            318275|
# |        OH|                Ohio|            35.6|               119454|                 127414|                246868|             17834|
# |        OK|            Oklahoma|            33.4|               119095|                 122403|                241499|             25195|
# |        OR|              Oregon|            36.1|                88430|                  91133|                179563|             23219|
# |        PA|        Pennsylvania|            34.0|               167112|                 181457|                348569|             43634|
# |        PR|         Puerto Rico|            40.7|                71542|                  84676|                156219|              null|
# |        RI|        Rhode Island|            37.7|                51304|                  53227|                104532|             22710|
# |        SC|      South Carolina|            33.8|                52720|                  55070|                107790|              5584|
# |        SD|        South Dakota|            37.1|                61359|                  61190|                122549|              7654|
# |        TN|           Tennessee|            34.3|               116458|                 126499|                242958|             20457|
# |        TX|               Texas|            33.4|               127700|                 130738|                258439|             53106|
# |        UT|                Utah|            30.9|                53890|                  52769|                106659|             13579|
# |        VA|            Virginia|            34.4|                82891|                  85939|                168830|             19232|
# |        WA|          Washington|            35.3|                73270|                  73794|                147065|             25938|
# |        WI|           Wisconsin|            33.5|                76533|                  80482|                157016|             13854|
# +----------+--------------------+----------------+---------------------+-----------------------+----------------------+------------------+

# %%
# Join "df_st_I94_SAS_Labels_I94ADDR_regex_cleaned" and "df_us_cities_demographics" to get new data frame "df_st_state_destinations"
# fill up null values with 0
df_st_state_destinations = df_st_I94_SAS_Labels_I94ADDR_regex_cleaned \
    .join(df_us_cities_demographics_agg, df_st_I94_SAS_Labels_I94ADDR_regex_cleaned.st_sd_state_code ==
          df_us_cities_demographics_agg.state_code, 'left'  ) \
    .drop("state_code", "state") \
    .withColumn("st_sd_state_name", F.initcap(col("st_sd_state_name"))) \
    .fillna(value=0.0 ,subset=['st_sd_age_median'])\
    .fillna(value=0 ,subset=['st_sd_population_male'])\
    .fillna(value=0 ,subset=['st_sd_population_female'])\
    .fillna(value=0 ,subset=['st_sd_population_total'])\
    .fillna(value=0 ,subset=['st_sd_foreign_born'])

# %%
df_st_state_destinations.show()
# Out:
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |st_sd_state_code| st_sd_state_name|st_sd_age_median|st_sd_population_male|st_sd_population_female|st_sd_population_total|st_sd_foreign_born|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |              WY|          Wyoming|             0.0|                    0|                      0|                     0|                 0|
# |              TN|        Tennessee|            34.3|               116458|                 126499|                242958|             20457|
# |              KS|           Kansas|            34.8|                80592|                  83447|                164039|             16949|
# |              IA|             Iowa|            32.5|                52119|                  53880|                106000|              9112|
# |              NV|           Nevada|            36.1|               124293|                 124677|                248971|             53481|
# |              IN|          Indiana|            33.8|                86272|                  92115|                178388|             13992|
# |              PR|      Puerto Rico|            40.7|                71542|                  84676|                156219|                 0|
# |              WI|        Wisconsin|            33.5|                76533|                  80482|                157016|             13854|
# |              NY|         New York|            35.6|               433755|                 473689|                907445|            318275|
# |              RI|     Rhode Island|            37.7|                51304|                  53227|                104532|             22710|
# |              MN|        Minnesota|            35.6|                64422|                  66025|                130447|             19812|
# |              DC|Dist. Of Columbia|            33.8|               319705|                 352523|                672228|             95117|
# |              SD|        S. Dakota|            37.1|                61359|                  61190|                122549|              7654|
# |              MI|         Michigan|            37.0|                66041|                  71746|                137787|             15374|
# |              ME|            Maine|            40.3|                31480|                  35392|                 66872|              9229|
# |              AL|          Alabama|            36.2|                72005|                  79856|                151861|              7427|
# |              FL|          Florida|            39.5|                70602|                  75919|                145523|             35340|
# |              PA|     Pennsylvania|            34.0|               167112|                 181457|                348569|             43634|
# |              CT|      Connecticut|            35.0|                54447|                  57222|                111669|             28570|
# |              ND|        N. Dakota|            34.3|                47617|                  47127|                 94745|              5746|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# only showing top 20 rows

# %%
# check results
print(df_st_state_destinations.count())
df_st_state_destinations.printSchema()
df_st_state_destinations\
    .orderBy("st_sd_state_code") \
    .show(100)
# Out:
# 55
# root
#  |-- st_sd_state_code: string (nullable = true)
#  |-- st_sd_state_name: string (nullable = true)
#  |-- st_sd_age_median: double (nullable = false)
#  |-- st_sd_population_male: integer (nullable = true)
#  |-- st_sd_population_female: integer (nullable = true)
#  |-- st_sd_population_total: integer (nullable = true)
#  |-- st_sd_foreign_born: integer (nullable = true)
#
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |st_sd_state_code| st_sd_state_name|st_sd_age_median|st_sd_population_male|st_sd_population_female|st_sd_population_total|st_sd_foreign_born|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |              99|  All Other Codes|             0.0|                    0|                      0|                     0|                 0|
# |              AK|           Alaska|            32.2|               152945|                 145750|                298695|             33258|
# |              AL|          Alabama|            36.2|                72005|                  79856|                151861|              7427|
# |              AR|         Arkansas|            32.7|                48300|                  51109|                 99409|             10612|
# |              AZ|          Arizona|            35.0|               139215|                 142005|                281221|             42644|
# |              CA|       California|            36.2|                90319|                  92290|                182609|             54821|
# |              CO|         Colorado|            35.8|                90913|                  92565|                183479|             21101|
# |              CT|      Connecticut|            35.0|                54447|                  57222|                111669|             28570|
# |              DC|Dist. Of Columbia|            33.8|               319705|                 352523|                672228|             95117|
# |              DE|         Delaware|            36.4|                32680|                  39277|                 71957|              3336|
# |              FL|          Florida|            39.5|                70602|                  75919|                145523|             35340|
# |              GA|          Georgia|            33.8|                74574|                  80973|                155548|             13435|
# |              GU|             Guam|             0.0|                    0|                      0|                     0|                 0|
# |              HI|           Hawaii|            41.4|               176807|                 175959|                352766|            101312|
# |              IA|             Iowa|            32.5|                52119|                  53880|                106000|              9112|
# |              ID|            Idaho|            34.8|                66367|                  66593|                132961|              9375|
# |              IL|         Illinois|            35.7|               120262|                 127148|                247410|             50907|
# |              IN|          Indiana|            33.8|                86272|                  92115|                178388|             13992|
# |              KS|           Kansas|            34.8|                80592|                  83447|                164039|             16949|
# |              KY|         Kentucky|            36.0|               226241|                 238697|                464938|             33244|
# |              LA|        Louisiana|            34.6|                78374|                  84199|                162574|             10427|
# |              MA|    Massachusetts|            35.5|                70160|                  74723|                144884|             37301|
# |              MD|         Maryland|            36.4|                62795|                  68417|                131212|             22979|
# |              ME|            Maine|            40.3|                31480|                  35392|                 66872|              9229|
# |              MI|         Michigan|            37.0|                66041|                  71746|                137787|             15374|
# |              MN|        Minnesota|            35.6|                64422|                  66025|                130447|             19812|
# |              MO|         Missouri|            34.9|                81473|                  87325|                168799|             11010|
# |              MS|      Mississippi|            33.2|                58625|                  68212|                126838|              2359|
# |              MT|          Montana|            35.5|                43853|                  46793|                 90647|              2988|
# |              NC|      N. Carolina|            33.8|               104721|                 113863|                218585|             27094|
# |              ND|        N. Dakota|            34.3|                47617|                  47127|                 94745|              5746|
# |              NE|         Nebraska|            33.3|               178666|                 181950|                360616|             35610|
# |              NH|    New Hampshire|            37.8|                48885|                  50213|                 99099|             13599|
# |              NJ|       New Jersey|            35.3|                60053|                  61543|                121596|             40837|
# |              NM|       New Mexico|            37.8|               102252|                 107508|                209760|             22278|
# |              NV|           Nevada|            36.1|               124293|                 124677|                248971|             53481|
# |              NY|         New York|            35.6|               433755|                 473689|                907445|            318275|
# |              OH|             Ohio|            35.6|               119454|                 127414|                246868|             17834|
# |              OK|         Oklahoma|            33.4|               119095|                 122403|                241499|             25195|
# |              OR|           Oregon|            36.1|                88430|                  91133|                179563|             23219|
# |              PA|     Pennsylvania|            34.0|               167112|                 181457|                348569|             43634|
# |              PR|      Puerto Rico|            40.7|                71542|                  84676|                156219|                 0|
# |              RI|     Rhode Island|            37.7|                51304|                  53227|                104532|             22710|
# |              SC|      S. Carolina|            33.8|                52720|                  55070|                107790|              5584|
# |              SD|        S. Dakota|            37.1|                61359|                  61190|                122549|              7654|
# |              TN|        Tennessee|            34.3|               116458|                 126499|                242958|             20457|
# |              TX|            Texas|            33.4|               127700|                 130738|                258439|             53106|
# |              UT|             Utah|            30.9|                53890|                  52769|                106659|             13579|
# |              VA|         Virginia|            34.4|                82891|                  85939|                168830|             19232|
# |              VI|   Virgin Islands|             0.0|                    0|                      0|                     0|                 0|
# |              VT|          Vermont|             0.0|                    0|                      0|                     0|                 0|
# |              WA|       Washington|            35.3|                73270|                  73794|                147065|             25938|
# |              WI|        Wisconsin|            33.5|                76533|                  80482|                157016|             13854|
# |              WV|      W. Virginia|             0.0|                    0|                      0|                     0|                 0|
# |              WY|          Wyoming|             0.0|                    0|                      0|                     0|                 0|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+

# %%
df_st_state_destinations
# Out:
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |st_sd_state_code| st_sd_state_name|st_sd_age_median|st_sd_population_male|st_sd_population_female|st_sd_population_total|st_sd_foreign_born|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |              WY|          Wyoming|             0.0|                    0|                      0|                     0|                 0|
# |              TN|        Tennessee|            34.3|               116458|                 126499|                242958|             20457|
# |              KS|           Kansas|            34.8|                80592|                  83447|                164039|             16949|
# |              IA|             Iowa|            32.5|                52119|                  53880|                106000|              9112|
# |              NV|           Nevada|            36.1|               124293|                 124677|                248971|             53481|
# |              IN|          Indiana|            33.8|                86272|                  92115|                178388|             13992|
# |              PR|      Puerto Rico|            40.7|                71542|                  84676|                156219|                 0|
# |              WI|        Wisconsin|            33.5|                76533|                  80482|                157016|             13854|
# |              NY|         New York|            35.6|               433755|                 473689|                907445|            318275|
# |              RI|     Rhode Island|            37.7|                51304|                  53227|                104532|             22710|
# |              MN|        Minnesota|            35.6|                64422|                  66025|                130447|             19812|
# |              DC|Dist. Of Columbia|            33.8|               319705|                 352523|                672228|             95117|
# |              SD|        S. Dakota|            37.1|                61359|                  61190|                122549|              7654|
# |              MI|         Michigan|            37.0|                66041|                  71746|                137787|             15374|
# |              ME|            Maine|            40.3|                31480|                  35392|                 66872|              9229|
# |              AL|          Alabama|            36.2|                72005|                  79856|                151861|              7427|
# |              FL|          Florida|            39.5|                70602|                  75919|                145523|             35340|
# |              PA|     Pennsylvania|            34.0|               167112|                 181457|                348569|             43634|
# |              CT|      Connecticut|            35.0|                54447|                  57222|                111669|             28570|
# |              ND|        N. Dakota|            34.3|                47617|                  47127|                 94745|              5746|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# only showing top 20 rows

# %%
# check results
print(df_st_state_destinations.count())
df_st_state_destinations.printSchema()
df_st_state_destinations\
    .orderBy("st_sd_state_code") \
    .show(100)
# Out:
# 55
# root
#  |-- st_sd_state_code: string (nullable = true)
#  |-- st_sd_state_name: string (nullable = true)
#  |-- st_sd_age_median: double (nullable = false)
#  |-- st_sd_population_male: integer (nullable = true)
#  |-- st_sd_population_female: integer (nullable = true)
#  |-- st_sd_population_total: integer (nullable = true)
#  |-- st_sd_foreign_born: integer (nullable = true)
#
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |st_sd_state_code| st_sd_state_name|st_sd_age_median|st_sd_population_male|st_sd_population_female|st_sd_population_total|st_sd_foreign_born|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+
# |              99|  All Other Codes|             0.0|                    0|                      0|                     0|                 0|
# |              AK|           Alaska|            32.2|               152945|                 145750|                298695|             33258|
# |              AL|          Alabama|            36.2|                72005|                  79856|                151861|              7427|
# |              AR|         Arkansas|            32.7|                48300|                  51109|                 99409|             10612|
# |              AZ|          Arizona|            35.0|               139215|                 142005|                281221|             42644|
# |              CA|       California|            36.2|                90319|                  92290|                182609|             54821|
# |              CO|         Colorado|            35.8|                90913|                  92565|                183479|             21101|
# |              CT|      Connecticut|            35.0|                54447|                  57222|                111669|             28570|
# |              DC|Dist. Of Columbia|            33.8|               319705|                 352523|                672228|             95117|
# |              DE|         Delaware|            36.4|                32680|                  39277|                 71957|              3336|
# |              FL|          Florida|            39.5|                70602|                  75919|                145523|             35340|
# |              GA|          Georgia|            33.8|                74574|                  80973|                155548|             13435|
# |              GU|             Guam|             0.0|                    0|                      0|                     0|                 0|
# |              HI|           Hawaii|            41.4|               176807|                 175959|                352766|            101312|
# |              IA|             Iowa|            32.5|                52119|                  53880|                106000|              9112|
# |              ID|            Idaho|            34.8|                66367|                  66593|                132961|              9375|
# |              IL|         Illinois|            35.7|               120262|                 127148|                247410|             50907|
# |              IN|          Indiana|            33.8|                86272|                  92115|                178388|             13992|
# |              KS|           Kansas|            34.8|                80592|                  83447|                164039|             16949|
# |              KY|         Kentucky|            36.0|               226241|                 238697|                464938|             33244|
# |              LA|        Louisiana|            34.6|                78374|                  84199|                162574|             10427|
# |              MA|    Massachusetts|            35.5|                70160|                  74723|                144884|             37301|
# |              MD|         Maryland|            36.4|                62795|                  68417|                131212|             22979|
# |              ME|            Maine|            40.3|                31480|                  35392|                 66872|              9229|
# |              MI|         Michigan|            37.0|                66041|                  71746|                137787|             15374|
# |              MN|        Minnesota|            35.6|                64422|                  66025|                130447|             19812|
# |              MO|         Missouri|            34.9|                81473|                  87325|                168799|             11010|
# |              MS|      Mississippi|            33.2|                58625|                  68212|                126838|              2359|
# |              MT|          Montana|            35.5|                43853|                  46793|                 90647|              2988|
# |              NC|      N. Carolina|            33.8|               104721|                 113863|                218585|             27094|
# |              ND|        N. Dakota|            34.3|                47617|                  47127|                 94745|              5746|
# |              NE|         Nebraska|            33.3|               178666|                 181950|                360616|             35610|
# |              NH|    New Hampshire|            37.8|                48885|                  50213|                 99099|             13599|
# |              NJ|       New Jersey|            35.3|                60053|                  61543|                121596|             40837|
# |              NM|       New Mexico|            37.8|               102252|                 107508|                209760|             22278|
# |              NV|           Nevada|            36.1|               124293|                 124677|                248971|             53481|
# |              NY|         New York|            35.6|               433755|                 473689|                907445|            318275|
# |              OH|             Ohio|            35.6|               119454|                 127414|                246868|             17834|
# |              OK|         Oklahoma|            33.4|               119095|                 122403|                241499|             25195|
# |              OR|           Oregon|            36.1|                88430|                  91133|                179563|             23219|
# |              PA|     Pennsylvania|            34.0|               167112|                 181457|                348569|             43634|
# |              PR|      Puerto Rico|            40.7|                71542|                  84676|                156219|                 0|
# |              RI|     Rhode Island|            37.7|                51304|                  53227|                104532|             22710|
# |              SC|      S. Carolina|            33.8|                52720|                  55070|                107790|              5584|
# |              SD|        S. Dakota|            37.1|                61359|                  61190|                122549|              7654|
# |              TN|        Tennessee|            34.3|               116458|                 126499|                242958|             20457|
# |              TX|            Texas|            33.4|               127700|                 130738|                258439|             53106|
# |              UT|             Utah|            30.9|                53890|                  52769|                106659|             13579|
# |              VA|         Virginia|            34.4|                82891|                  85939|                168830|             19232|
# |              VI|   Virgin Islands|             0.0|                    0|                      0|                     0|                 0|
# |              VT|          Vermont|             0.0|                    0|                      0|                     0|                 0|
# |              WA|       Washington|            35.3|                73270|                  73794|                147065|             25938|
# |              WI|        Wisconsin|            33.5|                76533|                  80482|                157016|             13854|
# |              WV|      W. Virginia|             0.0|                    0|                      0|                     0|                 0|
# |              WY|          Wyoming|             0.0|                    0|                      0|                     0|                 0|
# +----------------+-----------------+----------------+---------------------+-----------------------+----------------------+------------------+

# %%
# store staging table
location_to_write = "../P8_capstone_resource_files/parquet_stage/PQ4/st_state_destinations"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_state_destinations \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .parquet(location_to_write, compression="gzip")

# %% [markdown]
# 3. Creation of a dimension named `d_state_destinations` based on staging table `st_state_destinations`.

# %%
# get data to process and store dimension "d_state_destinations"
location_to_read = "../P8_capstone_resource_files/parquet_stage/PQ4/st_state_destinations"
df_st_state_destinations = spark.read.parquet(location_to_read)

print(df_st_state_destinations.count())
df_st_state_destinations.printSchema()

df_st_state_destinations = df_st_state_destinations \
    .withColumn("d_sd_id", col("st_sd_state_code")) \
    .withColumnRenamed("st_sd_state_code", "d_sd_state_code") \
    .withColumnRenamed("st_sd_state_name", "d_sd_state_name") \
    .withColumnRenamed("st_sd_age_median", "d_sd_age_median") \
    .withColumnRenamed("st_sd_population_male", "d_sd_population_male") \
    .withColumnRenamed("st_sd_population_female", "d_sd_population_female") \
    .withColumnRenamed("st_sd_population_total", "d_sd_population_total") \
    .withColumnRenamed("st_sd_foreign_born", "d_sd_foreign_born") \

df_st_state_destinations.printSchema()

# store dimension table
location_to_write = "../P8_capstone_resource_files/parquet_star/PQ4/d_state_destinations"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_st_state_destinations \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .parquet(location_to_write, compression="gzip")

df_st_state_destinations.orderBy("d_sd_state_code").show(1000)
# Out:
# 55
# root
#  |-- st_sd_state_code: string (nullable = true)
#  |-- st_sd_state_name: string (nullable = true)
#  |-- st_sd_age_median: double (nullable = true)
#  |-- st_sd_population_male: integer (nullable = true)
#  |-- st_sd_population_female: integer (nullable = true)
#  |-- st_sd_population_total: integer (nullable = true)
#  |-- st_sd_foreign_born: integer (nullable = true)
#
# root
#  |-- d_sd_state_code: string (nullable = true)
#  |-- d_sd_state_name: string (nullable = true)
#  |-- d_sd_age_median: double (nullable = true)
#  |-- d_sd_population_male: integer (nullable = true)
#  |-- d_sd_population_female: integer (nullable = true)
#  |-- d_sd_population_total: integer (nullable = true)
#  |-- d_sd_foreign_born: integer (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#
# +---------------+-----------------+---------------+--------------------+----------------------+---------------------+-----------------+-------+
# |d_sd_state_code|  d_sd_state_name|d_sd_age_median|d_sd_population_male|d_sd_population_female|d_sd_population_total|d_sd_foreign_born|d_sd_id|
# +---------------+-----------------+---------------+--------------------+----------------------+---------------------+-----------------+-------+
# |             99|  All Other Codes|            0.0|                   0|                     0|                    0|                0|     99|
# |             AK|           Alaska|           32.2|              152945|                145750|               298695|            33258|     AK|
# |             AL|          Alabama|           36.2|               72005|                 79856|               151861|             7427|     AL|
# |             AR|         Arkansas|           32.7|               48300|                 51109|                99409|            10612|     AR|
# |             AZ|          Arizona|           35.0|              139215|                142005|               281221|            42644|     AZ|
# |             CA|       California|           36.2|               90319|                 92290|               182609|            54821|     CA|
# |             CO|         Colorado|           35.8|               90913|                 92565|               183479|            21101|     CO|
# |             CT|      Connecticut|           35.0|               54447|                 57222|               111669|            28570|     CT|
# |             DC|Dist. Of Columbia|           33.8|              319705|                352523|               672228|            95117|     DC|
# |             DE|         Delaware|           36.4|               32680|                 39277|                71957|             3336|     DE|
# |             FL|          Florida|           39.5|               70602|                 75919|               145523|            35340|     FL|
# |             GA|          Georgia|           33.8|               74574|                 80973|               155548|            13435|     GA|
# |             GU|             Guam|            0.0|                   0|                     0|                    0|                0|     GU|
# |             HI|           Hawaii|           41.4|              176807|                175959|               352766|           101312|     HI|
# |             IA|             Iowa|           32.5|               52119|                 53880|               106000|             9112|     IA|
# |             ID|            Idaho|           34.8|               66367|                 66593|               132961|             9375|     ID|
# |             IL|         Illinois|           35.7|              120262|                127148|               247410|            50907|     IL|
# |             IN|          Indiana|           33.8|               86272|                 92115|               178388|            13992|     IN|
# |             KS|           Kansas|           34.8|               80592|                 83447|               164039|            16949|     KS|
# |             KY|         Kentucky|           36.0|              226241|                238697|               464938|            33244|     KY|
# |             LA|        Louisiana|           34.6|               78374|                 84199|               162574|            10427|     LA|
# |             MA|    Massachusetts|           35.5|               70160|                 74723|               144884|            37301|     MA|
# |             MD|         Maryland|           36.4|               62795|                 68417|               131212|            22979|     MD|
# |             ME|            Maine|           40.3|               31480|                 35392|                66872|             9229|     ME|
# |             MI|         Michigan|           37.0|               66041|                 71746|               137787|            15374|     MI|
# |             MN|        Minnesota|           35.6|               64422|                 66025|               130447|            19812|     MN|
# |             MO|         Missouri|           34.9|               81473|                 87325|               168799|            11010|     MO|
# |             MS|      Mississippi|           33.2|               58625|                 68212|               126838|             2359|     MS|
# |             MT|          Montana|           35.5|               43853|                 46793|                90647|             2988|     MT|
# |             NC|      N. Carolina|           33.8|              104721|                113863|               218585|            27094|     NC|
# |             ND|        N. Dakota|           34.3|               47617|                 47127|                94745|             5746|     ND|
# |             NE|         Nebraska|           33.3|              178666|                181950|               360616|            35610|     NE|
# |             NH|    New Hampshire|           37.8|               48885|                 50213|                99099|            13599|     NH|
# |             NJ|       New Jersey|           35.3|               60053|                 61543|               121596|            40837|     NJ|
# |             NM|       New Mexico|           37.8|              102252|                107508|               209760|            22278|     NM|
# |             NV|           Nevada|           36.1|              124293|                124677|               248971|            53481|     NV|
# |             NY|         New York|           35.6|              433755|                473689|               907445|           318275|     NY|
# |             OH|             Ohio|           35.6|              119454|                127414|               246868|            17834|     OH|
# |             OK|         Oklahoma|           33.4|              119095|                122403|               241499|            25195|     OK|
# |             OR|           Oregon|           36.1|               88430|                 91133|               179563|            23219|     OR|
# |             PA|     Pennsylvania|           34.0|              167112|                181457|               348569|            43634|     PA|
# |             PR|      Puerto Rico|           40.7|               71542|                 84676|               156219|                0|     PR|
# |             RI|     Rhode Island|           37.7|               51304|                 53227|               104532|            22710|     RI|
# |             SC|      S. Carolina|           33.8|               52720|                 55070|               107790|             5584|     SC|
# |             SD|        S. Dakota|           37.1|               61359|                 61190|               122549|             7654|     SD|
# |             TN|        Tennessee|           34.3|              116458|                126499|               242958|            20457|     TN|
# |             TX|            Texas|           33.4|              127700|                130738|               258439|            53106|     TX|
# |             UT|             Utah|           30.9|               53890|                 52769|               106659|            13579|     UT|
# |             VA|         Virginia|           34.4|               82891|                 85939|               168830|            19232|     VA|
# |             VI|   Virgin Islands|            0.0|                   0|                     0|                    0|                0|     VI|
# |             VT|          Vermont|            0.0|                   0|                     0|                    0|                0|     VT|
# |             WA|       Washington|           35.3|               73270|                 73794|               147065|            25938|     WA|
# |             WI|        Wisconsin|           33.5|               76533|                 80482|               157016|            13854|     WI|
# |             WV|      W. Virginia|            0.0|                   0|                     0|                    0|                0|     WV|
# |             WY|          Wyoming|            0.0|                   0|                     0|                    0|                0|     WY|
# +---------------+-----------------+---------------+--------------------+----------------------+---------------------+-----------------+-------+

# %% [markdown]
# 4. Mapping of dimension `d_state_destinations` to  fact table `f_i94_immigration` based on columns
#    (`st_state_destinations.st_sd_state_code` --> `d_state_destinations.d_sd_id`) ==
#    (`st_i94_immigration.st_i94_addr` --> `f_i94_immigration.d_sd_id`).

# %% [markdown]
# 5. Clean fact table `f_i94_immigration` based on the dimension `d_state_destinations`. All unrecognizable columns will
# be set to 99 (all other countries).

# %%
#Get data for further processing
location_to_read = "../P8_capstone_resource_files/parquet_star/PQ3/f_i94_immigrations"
df_f_i94_immigrations = spark.read.parquet(location_to_read)

print(df_f_i94_immigrations.count())
df_f_i94_immigrations.printSchema()

location_to_read = "../P8_capstone_resource_files/parquet_star/PQ4/d_state_destinations"
df_d_state_destinations = spark.read.parquet(location_to_read)

print(df_d_state_destinations.count())
df_d_state_destinations.printSchema()
# Out:
# 12228839
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_port_state_code: string (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)
#
# 55
# root
#  |-- d_sd_state_code: string (nullable = true)
#  |-- d_sd_state_name: string (nullable = true)
#  |-- d_sd_age_median: double (nullable = true)
#  |-- d_sd_population_male: integer (nullable = true)
#  |-- d_sd_population_female: integer (nullable = true)
#  |-- d_sd_population_total: integer (nullable = true)
#  |-- d_sd_foreign_born: integer (nullable = true)
#  |-- d_sd_id: string (nullable = true)

# %%
# prepare data frame `df_f_i94_immigrations_2_join` to get only the allowed state codes
df_f_i94_immigrations_2_join = df_d_state_destinations \
    .select("d_sd_id")\
    .withColumnRenamed("d_sd_id", "d_sd_id_reference") \
    .orderBy("d_sd_id_reference")

print(df_f_i94_immigrations_2_join.count())
df_f_i94_immigrations_2_join.printSchema()
df_f_i94_immigrations_2_join.show(60)
# Out:
# 55
# root
#  |-- d_sd_id_reference: string (nullable = true)
#
# +-----------------+
# |d_sd_id_reference|
# +-----------------+
# |               99|
# |               AK|
# |               AL|
# |               AR|
# |               AZ|
# |               CA|
# |               CO|
# |               CT|
# |               DC|
# |               DE|
# |               FL|
# |               GA|
# |               GU|
# |               HI|
# |               IA|
# |               ID|
# |               IL|
# |               IN|
# |               KS|
# |               KY|
# |               LA|
# |               MA|
# |               MD|
# |               ME|
# |               MI|
# |               MN|
# |               MO|
# |               MS|
# |               MT|
# |               NC|
# |               ND|
# |               NE|
# |               NH|
# |               NJ|
# |               NM|
# |               NV|
# |               NY|
# |               OH|
# |               OK|
# |               OR|
# |               PA|
# |               PR|
# |               RI|
# |               SC|
# |               SD|
# |               TN|
# |               TX|
# |               UT|
# |               VA|
# |               VI|
# |               VT|
# |               WA|
# |               WI|
# |               WV|
# |               WY|
# +-----------------+

# %%
# prepare and create a cleaned column "d_sd_id_cleaned"
df_f_i94_immigrations \
    .select("d_sd_id", "f_i94_addr") \
    .join(df_f_i94_immigrations_2_join, df_f_i94_immigrations_2_join.d_sd_id_reference == df_f_i94_immigrations.d_sd_id, 'left') \
    .withColumn("d_sd_id_cleaned", when(col("d_sd_id_reference").isNull(), "99")\
                .otherwise(col("d_sd_id_reference"))) \
    .filter(col("d_sd_id_reference").isNull())\
    .distinct() \
    .orderBy("d_sd_id") \
    .show(5000)
# Out:
# +-------+----------+-----------------+---------------+
# |d_sd_id|f_i94_addr|d_sd_id_reference|d_sd_id_cleaned|
# +-------+----------+-----------------+---------------+
# |     **|        **|             null|             99|
# |     ..|        ..|             null|             99|
# |     .7|        .7|             null|             99|
# |     .9|        .9|             null|             99|
# |     .A|        .A|             null|             99|
# |     .C|        .C|             null|             99|
# |     .D|        .D|             null|             99|
# |     .F|        .F|             null|             99|
# |     .H|        .H|             null|             99|
# |     .I|        .I|             null|             99|
# |     .K|        .K|             null|             99|
# |     .L|        .L|             null|             99|
# |     .M|        .M|             null|             99|
# |     .N|        .N|             null|             99|
# |     .O|        .O|             null|             99|
# |     .S|        .S|             null|             99|
# |     .T|        .T|             null|             99|
# |     .V|        .V|             null|             99|
# |     .W|        .W|             null|             99|
# |      /|         /|             null|             99|
# |      0|         0|             null|             99|
# |     00|        00|             null|             99|
# |     01|        01|             null|             99|
# |     02|        02|             null|             99|
# |     03|        03|             null|             99|
# |     04|        04|             null|             99|
# |     06|        06|             null|             99|
# |     07|        07|             null|             99|
# |     08|        08|             null|             99|
# |      1|         1|             null|             99|
# |     10|        10|             null|             99|
# |     11|        11|             null|             99|
# |     12|        12|             null|             99|
# |     13|        13|             null|             99|
# |     14|        14|             null|             99|
# |     15|        15|             null|             99|
# |     16|        16|             null|             99|
# |     17|        17|             null|             99|
# |     18|        18|             null|             99|
# |     19|        19|             null|             99|
# |      2|         2|             null|             99|
# |     20|        20|             null|             99|
# |     21|        21|             null|             99|
# |     22|        22|             null|             99|
# |     23|        23|             null|             99|
# |     26|        26|             null|             99|
# |     27|        27|             null|             99|
# |     28|        28|             null|             99|
# |     29|        29|             null|             99|
# |      3|         3|             null|             99|
# |     30|        30|             null|             99|
# |     31|        31|             null|             99|
# |     32|        32|             null|             99|
# |     33|        33|             null|             99|
# |     34|        34|             null|             99|
# |     35|        35|             null|             99|
# |     36|        36|             null|             99|
# |     37|        37|             null|             99|
# |     38|        38|             null|             99|
# |     3F|        3F|             null|             99|
# |     3H|        3H|             null|             99|
# |     3M|        3M|             null|             99|
# |     3R|        3R|             null|             99|
# |     40|        40|             null|             99|
# |     41|        41|             null|             99|
# |     43|        43|             null|             99|
# |     44|        44|             null|             99|
# |     45|        45|             null|             99|
# |     46|        46|             null|             99|
# |     48|        48|             null|             99|
# |     49|        49|             null|             99|
# |     4B|        4B|             null|             99|
# |      5|         5|             null|             99|
# |     50|        50|             null|             99|
# |     51|        51|             null|             99|
# |     52|        52|             null|             99|
# |     53|        53|             null|             99|
# |     54|        54|             null|             99|
# |     55|        55|             null|             99|
# |     57|        57|             null|             99|
# |     58|        58|             null|             99|
# |      6|         6|             null|             99|
# |     60|        60|             null|             99|
# |     61|        61|             null|             99|
# |     62|        62|             null|             99|
# |     63|        63|             null|             99|
# |     64|        64|             null|             99|
# |     65|        65|             null|             99|
# |     67|        67|             null|             99|
# |     68|        68|             null|             99|
# |      7|         7|             null|             99|
# |     70|        70|             null|             99|
# |     71|        71|             null|             99|
# |     72|        72|             null|             99|
# |     73|        73|             null|             99|
# |     74|        74|             null|             99|
# |     75|        75|             null|             99|
# |     76|        76|             null|             99|
# |     77|        77|             null|             99|
# |     78|        78|             null|             99|
# |     79|        79|             null|             99|
# |      8|         8|             null|             99|
# |     80|        80|             null|             99|
# |     81|        81|             null|             99|
# |     82|        82|             null|             99|
# |     83|        83|             null|             99|
# |     84|        84|             null|             99|
# |     85|        85|             null|             99|
# |     87|        87|             null|             99|
# |     89|        89|             null|             99|
# |     8T|        8T|             null|             99|
# |      9|         9|             null|             99|
# |     90|        90|             null|             99|
# |     91|        91|             null|             99|
# |     92|        92|             null|             99|
# |     93|        93|             null|             99|
# |     94|        94|             null|             99|
# |     95|        95|             null|             99|
# |     96|        96|             null|             99|
# |     97|        97|             null|             99|
# |     98|        98|             null|             99|
# |      A|         A|             null|             99|
# |     AA|        AA|             null|             99|
# |     AB|        AB|             null|             99|
# |     AC|        AC|             null|             99|
# |     AD|        AD|             null|             99|
# |     AE|        AE|             null|             99|
# |     AF|        AF|             null|             99|
# |     AG|        AG|             null|             99|
# |     AH|        AH|             null|             99|
# |     AI|        AI|             null|             99|
# |     AJ|        AJ|             null|             99|
# |     AM|        AM|             null|             99|
# |     AN|        AN|             null|             99|
# |     AO|        AO|             null|             99|
# |     AP|        AP|             null|             99|
# |     AQ|        AQ|             null|             99|
# |     AS|        AS|             null|             99|
# |     AT|        AT|             null|             99|
# |     AU|        AU|             null|             99|
# |     AV|        AV|             null|             99|
# |     AW|        AW|             null|             99|
# |     AX|        AX|             null|             99|
# |     AY|        AY|             null|             99|
# |      B|         B|             null|             99|
# |     B2|        B2|             null|             99|
# |     B3|        B3|             null|             99|
# |     B6|        B6|             null|             99|
# |     B7|        B7|             null|             99|
# |     B9|        B9|             null|             99|
# |     BA|        BA|             null|             99|
# |     BB|        BB|             null|             99|
# |     BC|        BC|             null|             99|
# |     BD|        BD|             null|             99|
# |     BE|        BE|             null|             99|
# |     BF|        BF|             null|             99|
# |     BG|        BG|             null|             99|
# |     BH|        BH|             null|             99|
# |     BI|        BI|             null|             99|
# |     BJ|        BJ|             null|             99|
# |     BK|        BK|             null|             99|
# |     BL|        BL|             null|             99|
# |     BM|        BM|             null|             99|
# |     BN|        BN|             null|             99|
# |     BO|        BO|             null|             99|
# |     BQ|        BQ|             null|             99|
# |     BR|        BR|             null|             99|
# |     BS|        BS|             null|             99|
# |     BT|        BT|             null|             99|
# |     BU|        BU|             null|             99|
# |     BV|        BV|             null|             99|
# |     BW|        BW|             null|             99|
# |     BX|        BX|             null|             99|
# |     BY|        BY|             null|             99|
# |     BZ|        BZ|             null|             99|
# |      C|         C|             null|             99|
# |     C0|        C0|             null|             99|
# |     CB|        CB|             null|             99|
# |     CC|        CC|             null|             99|
# |     CD|        CD|             null|             99|
# |     CE|        CE|             null|             99|
# |     CF|        CF|             null|             99|
# |     CG|        CG|             null|             99|
# |     CH|        CH|             null|             99|
# |     CI|        CI|             null|             99|
# |     CK|        CK|             null|             99|
# |     CL|        CL|             null|             99|
# |     CM|        CM|             null|             99|
# |     CN|        CN|             null|             99|
# |     CP|        CP|             null|             99|
# |     CQ|        CQ|             null|             99|
# |     CR|        CR|             null|             99|
# |     CS|        CS|             null|             99|
# |     CU|        CU|             null|             99|
# |     CV|        CV|             null|             99|
# |     CW|        CW|             null|             99|
# |     CX|        CX|             null|             99|
# |     CY|        CY|             null|             99|
# |     CZ|        CZ|             null|             99|
# |      D|         D|             null|             99|
# |     D.|        D.|             null|             99|
# |     DA|        DA|             null|             99|
# |     DB|        DB|             null|             99|
# |     DD|        DD|             null|             99|
# |     DF|        DF|             null|             99|
# |     DG|        DG|             null|             99|
# |     DH|        DH|             null|             99|
# |     DI|        DI|             null|             99|
# |     DK|        DK|             null|             99|
# |     DL|        DL|             null|             99|
# |     DM|        DM|             null|             99|
# |     DN|        DN|             null|             99|
# |     DO|        DO|             null|             99|
# |     DR|        DR|             null|             99|
# |     DS|        DS|             null|             99|
# |     DT|        DT|             null|             99|
# |     DU|        DU|             null|             99|
# |     DV|        DV|             null|             99|
# |     DW|        DW|             null|             99|
# |     DX|        DX|             null|             99|
# |     DY|        DY|             null|             99|
# |     DZ|        DZ|             null|             99|
# |      E|         E|             null|             99|
# |     E2|        E2|             null|             99|
# |     E3|        E3|             null|             99|
# |     E4|        E4|             null|             99|
# |     EA|        EA|             null|             99|
# |     EB|        EB|             null|             99|
# |     EC|        EC|             null|             99|
# |     ED|        ED|             null|             99|
# |     EE|        EE|             null|             99|
# |     EG|        EG|             null|             99|
# |     EH|        EH|             null|             99|
# |     EI|        EI|             null|             99|
# |     EL|        EL|             null|             99|
# |     EM|        EM|             null|             99|
# |     EN|        EN|             null|             99|
# |     EP|        EP|             null|             99|
# |     EQ|        EQ|             null|             99|
# |     ER|        ER|             null|             99|
# |     ES|        ES|             null|             99|
# |     ET|        ET|             null|             99|
# |     EU|        EU|             null|             99|
# |     EV|        EV|             null|             99|
# |     EW|        EW|             null|             99|
# |     EX|        EX|             null|             99|
# |     EY|        EY|             null|             99|
# |     EZ|        EZ|             null|             99|
# |      F|         F|             null|             99|
# |     F1|        F1|             null|             99|
# |     FA|        FA|             null|             99|
# |     FC|        FC|             null|             99|
# |     FD|        FD|             null|             99|
# |     FE|        FE|             null|             99|
# |     FF|        FF|             null|             99|
# |     FG|        FG|             null|             99|
# |     FH|        FH|             null|             99|
# |     FI|        FI|             null|             99|
# |     FJ|        FJ|             null|             99|
# |     FK|        FK|             null|             99|
# |     FM|        FM|             null|             99|
# |     FN|        FN|             null|             99|
# |     FO|        FO|             null|             99|
# |     FP|        FP|             null|             99|
# |     FR|        FR|             null|             99|
# |     FS|        FS|             null|             99|
# |     FT|        FT|             null|             99|
# |     FU|        FU|             null|             99|
# |     FW|        FW|             null|             99|
# |     FX|        FX|             null|             99|
# |     FY|        FY|             null|             99|
# |     FZ|        FZ|             null|             99|
# |      G|         G|             null|             99|
# |     G3|        G3|             null|             99|
# |     G5|        G5|             null|             99|
# |     G6|        G6|             null|             99|
# |     G7|        G7|             null|             99|
# |     G8|        G8|             null|             99|
# |     GB|        GB|             null|             99|
# |     GC|        GC|             null|             99|
# |     GD|        GD|             null|             99|
# |     GE|        GE|             null|             99|
# |     GF|        GF|             null|             99|
# |     GG|        GG|             null|             99|
# |     GH|        GH|             null|             99|
# |     GI|        GI|             null|             99|
# |     GJ|        GJ|             null|             99|
# |     GK|        GK|             null|             99|
# |     GL|        GL|             null|             99|
# |     GM|        GM|             null|             99|
# |     GN|        GN|             null|             99|
# |     GO|        GO|             null|             99|
# |     GP|        GP|             null|             99|
# |     GQ|        GQ|             null|             99|
# |     GR|        GR|             null|             99|
# |     GS|        GS|             null|             99|
# |     GT|        GT|             null|             99|
# |     GV|        GV|             null|             99|
# |     GW|        GW|             null|             99|
# |     GY|        GY|             null|             99|
# |     GZ|        GZ|             null|             99|
# |      H|         H|             null|             99|
# |     H8|        H8|             null|             99|
# |     HA|        HA|             null|             99|
# |     HB|        HB|             null|             99|
# |     HC|        HC|             null|             99|
# |     HE|        HE|             null|             99|
# |     HF|        HF|             null|             99|
# |     HG|        HG|             null|             99|
# |     HH|        HH|             null|             99|
# |     HJ|        HJ|             null|             99|
# |     HK|        HK|             null|             99|
# |     HL|        HL|             null|             99|
# |     HM|        HM|             null|             99|
# |     HN|        HN|             null|             99|
# |     HO|        HO|             null|             99|
# |     HP|        HP|             null|             99|
# |     HQ|        HQ|             null|             99|
# |     HR|        HR|             null|             99|
# |     HS|        HS|             null|             99|
# |     HT|        HT|             null|             99|
# |     HU|        HU|             null|             99|
# |     HV|        HV|             null|             99|
# |     HW|        HW|             null|             99|
# |     HX|        HX|             null|             99|
# |     HY|        HY|             null|             99|
# |     HZ|        HZ|             null|             99|
# |      I|         I|             null|             99|
# |     I0|        I0|             null|             99|
# |     I6|        I6|             null|             99|
# |     IB|        IB|             null|             99|
# |     IC|        IC|             null|             99|
# |     IF|        IF|             null|             99|
# |     IG|        IG|             null|             99|
# |     IH|        IH|             null|             99|
# |     II|        II|             null|             99|
# |     IJ|        IJ|             null|             99|
# |     IK|        IK|             null|             99|
# |     IM|        IM|             null|             99|
# |     IO|        IO|             null|             99|
# |     IP|        IP|             null|             99|
# |     IQ|        IQ|             null|             99|
# |     IR|        IR|             null|             99|
# |     IS|        IS|             null|             99|
# |     IT|        IT|             null|             99|
# |     IU|        IU|             null|             99|
# |     IV|        IV|             null|             99|
# |     IW|        IW|             null|             99|
# |     IY|        IY|             null|             99|
# |     IZ|        IZ|             null|             99|
# |      J|         J|             null|             99|
# |     JA|        JA|             null|             99|
# |     JC|        JC|             null|             99|
# |     JD|        JD|             null|             99|
# |     JE|        JE|             null|             99|
# |     JF|        JF|             null|             99|
# |     JG|        JG|             null|             99|
# |     JH|        JH|             null|             99|
# |     JI|        JI|             null|             99|
# |     JJ|        JJ|             null|             99|
# |     JK|        JK|             null|             99|
# |     JL|        JL|             null|             99|
# |     JM|        JM|             null|             99|
# |     JN|        JN|             null|             99|
# |     JO|        JO|             null|             99|
# |     JP|        JP|             null|             99|
# |     JQ|        JQ|             null|             99|
# |     JR|        JR|             null|             99|
# |     JS|        JS|             null|             99|
# |     JT|        JT|             null|             99|
# |     JU|        JU|             null|             99|
# |     JW|        JW|             null|             99|
# |     JX|        JX|             null|             99|
# |     JY|        JY|             null|             99|
# |      K|         K|             null|             99|
# |     KA|        KA|             null|             99|
# |     KC|        KC|             null|             99|
# |     KD|        KD|             null|             99|
# |     KE|        KE|             null|             99|
# |     KF|        KF|             null|             99|
# |     KH|        KH|             null|             99|
# |     KI|        KI|             null|             99|
# |     KJ|        KJ|             null|             99|
# |     KK|        KK|             null|             99|
# |     KL|        KL|             null|             99|
# |     KM|        KM|             null|             99|
# |     KN|        KN|             null|             99|
# |     KO|        KO|             null|             99|
# |     KR|        KR|             null|             99|
# |     KT|        KT|             null|             99|
# |     KU|        KU|             null|             99|
# |     KV|        KV|             null|             99|
# |     KW|        KW|             null|             99|
# |     KZ|        KZ|             null|             99|
# |      L|         L|             null|             99|
# |     L1|        L1|             null|             99|
# |     L2|        L2|             null|             99|
# |     L3|        L3|             null|             99|
# |     L4|        L4|             null|             99|
# |     LB|        LB|             null|             99|
# |     LC|        LC|             null|             99|
# |     LD|        LD|             null|             99|
# |     LE|        LE|             null|             99|
# |     LF|        LF|             null|             99|
# |     LG|        LG|             null|             99|
# |     LH|        LH|             null|             99|
# |     LI|        LI|             null|             99|
# |     LJ|        LJ|             null|             99|
# |     LK|        LK|             null|             99|
# |     LL|        LL|             null|             99|
# |     LN|        LN|             null|             99|
# |     LO|        LO|             null|             99|
# |     LP|        LP|             null|             99|
# |     LQ|        LQ|             null|             99|
# |     LR|        LR|             null|             99|
# |     LS|        LS|             null|             99|
# |     LT|        LT|             null|             99|
# |     LU|        LU|             null|             99|
# |     LV|        LV|             null|             99|
# |     LW|        LW|             null|             99|
# |     LX|        LX|             null|             99|
# |     LY|        LY|             null|             99|
# |     LZ|        LZ|             null|             99|
# |      M|         M|             null|             99|
# |     M1|        M1|             null|             99|
# |     M2|        M2|             null|             99|
# |     M3|        M3|             null|             99|
# |     M8|        M8|             null|             99|
# |     MB|        MB|             null|             99|
# |     MC|        MC|             null|             99|
# |     MF|        MF|             null|             99|
# |     MG|        MG|             null|             99|
# |     MH|        MH|             null|             99|
# |     MJ|        MJ|             null|             99|
# |     MK|        MK|             null|             99|
# |     ML|        ML|             null|             99|
# |     MM|        MM|             null|             99|
# |     MP|        MP|             null|             99|
# |     MQ|        MQ|             null|             99|
# |     MR|        MR|             null|             99|
# |     MU|        MU|             null|             99|
# |     MV|        MV|             null|             99|
# |     MW|        MW|             null|             99|
# |     MX|        MX|             null|             99|
# |     MY|        MY|             null|             99|
# |     MZ|        MZ|             null|             99|
# |      N|         N|             null|             99|
# |     N.|        N.|             null|             99|
# |     N0|        N0|             null|             99|
# |     N1|        N1|             null|             99|
# |     N6|        N6|             null|             99|
# |     N7|        N7|             null|             99|
# |     NA|        NA|             null|             99|
# |     NB|        NB|             null|             99|
# |     NF|        NF|             null|             99|
# |     NG|        NG|             null|             99|
# |     NI|        NI|             null|             99|
# |     NK|        NK|             null|             99|
# |     NL|        NL|             null|             99|
# |     NN|        NN|             null|             99|
# |     NO|        NO|             null|             99|
# |     NP|        NP|             null|             99|
# |     NR|        NR|             null|             99|
# |     NS|        NS|             null|             99|
# |     NT|        NT|             null|             99|
# |     NU|        NU|             null|             99|
# |     NW|        NW|             null|             99|
# |     NX|        NX|             null|             99|
# |     NZ|        NZ|             null|             99|
# |      O|         O|             null|             99|
# |     OA|        OA|             null|             99|
# |     OB|        OB|             null|             99|
# |     OC|        OC|             null|             99|
# |     OD|        OD|             null|             99|
# |     OE|        OE|             null|             99|
# |     OF|        OF|             null|             99|
# |     OG|        OG|             null|             99|
# |     OI|        OI|             null|             99|
# |     OJ|        OJ|             null|             99|
# |     OL|        OL|             null|             99|
# |     OM|        OM|             null|             99|
# |     ON|        ON|             null|             99|
# |     OO|        OO|             null|             99|
# |     OP|        OP|             null|             99|
# |     OS|        OS|             null|             99|
# |     OT|        OT|             null|             99|
# |     OU|        OU|             null|             99|
# |     OV|        OV|             null|             99|
# |     OW|        OW|             null|             99|
# |     OX|        OX|             null|             99|
# |     OY|        OY|             null|             99|
# |     OZ|        OZ|             null|             99|
# |      P|         P|             null|             99|
# |     PB|        PB|             null|             99|
# |     PC|        PC|             null|             99|
# |     PD|        PD|             null|             99|
# |     PE|        PE|             null|             99|
# |     PF|        PF|             null|             99|
# |     PG|        PG|             null|             99|
# |     PH|        PH|             null|             99|
# |     PI|        PI|             null|             99|
# |     PJ|        PJ|             null|             99|
# |     PK|        PK|             null|             99|
# |     PL|        PL|             null|             99|
# |     PN|        PN|             null|             99|
# |     PO|        PO|             null|             99|
# |     PP|        PP|             null|             99|
# |     PQ|        PQ|             null|             99|
# |     PS|        PS|             null|             99|
# |     PT|        PT|             null|             99|
# |     PU|        PU|             null|             99|
# |     PV|        PV|             null|             99|
# |     PW|        PW|             null|             99|
# |     PX|        PX|             null|             99|
# |     PY|        PY|             null|             99|
# |      Q|         Q|             null|             99|
# |     QA|        QA|             null|             99|
# |     QB|        QB|             null|             99|
# |     QC|        QC|             null|             99|
# |     QE|        QE|             null|             99|
# |     QF|        QF|             null|             99|
# |     QI|        QI|             null|             99|
# |     QK|        QK|             null|             99|
# |     QL|        QL|             null|             99|
# |     QM|        QM|             null|             99|
# |     QO|        QO|             null|             99|
# |     QQ|        QQ|             null|             99|
# |     QR|        QR|             null|             99|
# |     QS|        QS|             null|             99|
# |     QT|        QT|             null|             99|
# |     QU|        QU|             null|             99|
# |     QW|        QW|             null|             99|
# |     QY|        QY|             null|             99|
# |     QZ|        QZ|             null|             99|
# |      R|         R|             null|             99|
# |     RA|        RA|             null|             99|
# |     RC|        RC|             null|             99|
# |     RD|        RD|             null|             99|
# |     RE|        RE|             null|             99|
# |     RF|        RF|             null|             99|
# |     RG|        RG|             null|             99|
# |     RH|        RH|             null|             99|
# |     RJ|        RJ|             null|             99|
# |     RL|        RL|             null|             99|
# |     RM|        RM|             null|             99|
# |     RN|        RN|             null|             99|
# |     RO|        RO|             null|             99|
# |     RP|        RP|             null|             99|
# |     RQ|        RQ|             null|             99|
# |     RR|        RR|             null|             99|
# |     RS|        RS|             null|             99|
# |     RT|        RT|             null|             99|
# |     RU|        RU|             null|             99|
# |     RV|        RV|             null|             99|
# |     RX|        RX|             null|             99|
# |     RY|        RY|             null|             99|
# |      S|         S|             null|             99|
# |     S.|        S.|             null|             99|
# |     S2|        S2|             null|             99|
# |     S3|        S3|             null|             99|
# |     S6|        S6|             null|             99|
# |     S7|        S7|             null|             99|
# |     S8|        S8|             null|             99|
# |     SA|        SA|             null|             99|
# |     SB|        SB|             null|             99|
# |     SE|        SE|             null|             99|
# |     SF|        SF|             null|             99|
# |     SG|        SG|             null|             99|
# |     SH|        SH|             null|             99|
# |     SI|        SI|             null|             99|
# |     SJ|        SJ|             null|             99|
# |     SK|        SK|             null|             99|
# |     SL|        SL|             null|             99|
# |     SM|        SM|             null|             99|
# |     SN|        SN|             null|             99|
# |     SO|        SO|             null|             99|
# |     SP|        SP|             null|             99|
# |     SQ|        SQ|             null|             99|
# |     SR|        SR|             null|             99|
# |     SS|        SS|             null|             99|
# |     ST|        ST|             null|             99|
# |     SU|        SU|             null|             99|
# |     SV|        SV|             null|             99|
# |     SW|        SW|             null|             99|
# |     SX|        SX|             null|             99|
# |     SY|        SY|             null|             99|
# |     SZ|        SZ|             null|             99|
# |      T|         T|             null|             99|
# |     TA|        TA|             null|             99|
# |     TB|        TB|             null|             99|
# |     TC|        TC|             null|             99|
# |     TD|        TD|             null|             99|
# |     TE|        TE|             null|             99|
# |     TF|        TF|             null|             99|
# |     TG|        TG|             null|             99|
# |     TH|        TH|             null|             99|
# |     TI|        TI|             null|             99|
# |     TJ|        TJ|             null|             99|
# |     TK|        TK|             null|             99|
# |     TL|        TL|             null|             99|
# |     TM|        TM|             null|             99|
# |     TO|        TO|             null|             99|
# |     TP|        TP|             null|             99|
# |     TQ|        TQ|             null|             99|
# |     TR|        TR|             null|             99|
# |     TS|        TS|             null|             99|
# |     TT|        TT|             null|             99|
# |     TU|        TU|             null|             99|
# |     TV|        TV|             null|             99|
# |     TW|        TW|             null|             99|
# |     TY|        TY|             null|             99|
# |     TZ|        TZ|             null|             99|
# |      U|         U|             null|             99|
# |     UA|        UA|             null|             99|
# |     UB|        UB|             null|             99|
# |     UC|        UC|             null|             99|
# |     UD|        UD|             null|             99|
# |     UE|        UE|             null|             99|
# |     UF|        UF|             null|             99|
# |     UG|        UG|             null|             99|
# |     UH|        UH|             null|             99|
# |     UI|        UI|             null|             99|
# |     UJ|        UJ|             null|             99|
# |     UK|        UK|             null|             99|
# |     UL|        UL|             null|             99|
# |     UM|        UM|             null|             99|
# |     UN|        UN|             null|             99|
# |     UP|        UP|             null|             99|
# |     UR|        UR|             null|             99|
# |     US|        US|             null|             99|
# |     UU|        UU|             null|             99|
# |     UV|        UV|             null|             99|
# |     UY|        UY|             null|             99|
# |      V|         V|             null|             99|
# |     VC|        VC|             null|             99|
# |     VD|        VD|             null|             99|
# |     VE|        VE|             null|             99|
# |     VF|        VF|             null|             99|
# |     VG|        VG|             null|             99|
# |     VH|        VH|             null|             99|
# |     VK|        VK|             null|             99|
# |     VL|        VL|             null|             99|
# |     VM|        VM|             null|             99|
# |     VN|        VN|             null|             99|
# |     VO|        VO|             null|             99|
# |     VP|        VP|             null|             99|
# |     VQ|        VQ|             null|             99|
# |     VR|        VR|             null|             99|
# |     VS|        VS|             null|             99|
# |     VU|        VU|             null|             99|
# |     VV|        VV|             null|             99|
# |     VW|        VW|             null|             99|
# |     VX|        VX|             null|             99|
# |     VY|        VY|             null|             99|
# |     VZ|        VZ|             null|             99|
# |      W|         W|             null|             99|
# |     W1|        W1|             null|             99|
# |     W3|        W3|             null|             99|
# |     W4|        W4|             null|             99|
# |     W5|        W5|             null|             99|
# |     WB|        WB|             null|             99|
# |     WC|        WC|             null|             99|
# |     WD|        WD|             null|             99|
# |     WE|        WE|             null|             99|
# |     WF|        WF|             null|             99|
# |     WG|        WG|             null|             99|
# |     WH|        WH|             null|             99|
# |     WJ|        WJ|             null|             99|
# |     WK|        WK|             null|             99|
# |     WL|        WL|             null|             99|
# |     WM|        WM|             null|             99|
# |     WN|        WN|             null|             99|
# |     WO|        WO|             null|             99|
# |     WP|        WP|             null|             99|
# |     WQ|        WQ|             null|             99|
# |     WR|        WR|             null|             99|
# |     WS|        WS|             null|             99|
# |     WT|        WT|             null|             99|
# |     WU|        WU|             null|             99|
# |     WW|        WW|             null|             99|
# |     WZ|        WZ|             null|             99|
# |      X|         X|             null|             99|
# |     XA|        XA|             null|             99|
# |     XC|        XC|             null|             99|
# |     XD|        XD|             null|             99|
# |     XF|        XF|             null|             99|
# |     XI|        XI|             null|             99|
# |     XN|        XN|             null|             99|
# |     XQ|        XQ|             null|             99|
# |     XT|        XT|             null|             99|
# |     XX|        XX|             null|             99|
# |     XZ|        XZ|             null|             99|
# |      Y|         Y|             null|             99|
# |     YA|        YA|             null|             99|
# |     YB|        YB|             null|             99|
# |     YC|        YC|             null|             99|
# |     YD|        YD|             null|             99|
# |     YE|        YE|             null|             99|
# |     YH|        YH|             null|             99|
# |     YI|        YI|             null|             99|
# |     YK|        YK|             null|             99|
# |     YL|        YL|             null|             99|
# |     YM|        YM|             null|             99|
# |     YN|        YN|             null|             99|
# |     YO|        YO|             null|             99|
# |     YQ|        YQ|             null|             99|
# |     YS|        YS|             null|             99|
# |     YT|        YT|             null|             99|
# |     YU|        YU|             null|             99|
# |     YV|        YV|             null|             99|
# |     YW|        YW|             null|             99|
# |     YX|        YX|             null|             99|
# |     YY|        YY|             null|             99|
# |      Z|         Z|             null|             99|
# |     ZA|        ZA|             null|             99|
# |     ZC|        ZC|             null|             99|
# |     ZE|        ZE|             null|             99|
# |     ZG|        ZG|             null|             99|
# |     ZH|        ZH|             null|             99|
# |     ZI|        ZI|             null|             99|
# |     ZJ|        ZJ|             null|             99|
# |     ZL|        ZL|             null|             99|
# |     ZN|        ZN|             null|             99|
# |     ZO|        ZO|             null|             99|
# |     ZR|        ZR|             null|             99|
# |     ZT|        ZT|             null|             99|
# |     ZU|        ZU|             null|             99|
# |     ZW|        ZW|             null|             99|
# |     ZX|        ZX|             null|             99|
# +-------+----------+-----------------+---------------+

# %%
# clean column "f_i94_immigrations.d_sd_id" by column "d_sd_id_cleaned (d_sd_id_reference)"
df_f_i94_immigrations = df_f_i94_immigrations \
    .join(df_f_i94_immigrations_2_join, df_f_i94_immigrations_2_join.d_sd_id_reference == df_f_i94_immigrations.d_sd_id, 'left') \
    .withColumn("d_sd_id", when(col("d_sd_id_reference").isNull(), "99")\
                .otherwise(col("d_sd_id_reference"))) \
    .drop("d_sd_id_reference") \

# %%
# check corrected column "d_sd_id"
df_f_i94_immigrations \
    .select("d_sd_id", "f_i94_addr") \
    .distinct() \
    .orderBy("d_sd_id", "f_i94_addr") \
    .show(5000)
# Out:
# +-------+----------+
# |d_sd_id|f_i94_addr|
# +-------+----------+
# |     99|        **|
# |     99|        ..|
# |     99|        .7|
# |     99|        .9|
# |     99|        .A|
# |     99|        .C|
# |     99|        .D|
# |     99|        .F|
# |     99|        .H|
# |     99|        .I|
# |     99|        .K|
# |     99|        .L|
# |     99|        .M|
# |     99|        .N|
# |     99|        .O|
# |     99|        .S|
# |     99|        .T|
# |     99|        .V|
# |     99|        .W|
# |     99|         /|
# |     99|         0|
# |     99|        00|
# |     99|        01|
# |     99|        02|
# |     99|        03|
# |     99|        04|
# |     99|        06|
# |     99|        07|
# |     99|        08|
# |     99|         1|
# |     99|        10|
# |     99|        11|
# |     99|        12|
# |     99|        13|
# |     99|        14|
# |     99|        15|
# |     99|        16|
# |     99|        17|
# |     99|        18|
# |     99|        19|
# |     99|         2|
# |     99|        20|
# |     99|        21|
# |     99|        22|
# |     99|        23|
# |     99|        26|
# |     99|        27|
# |     99|        28|
# |     99|        29|
# |     99|         3|
# |     99|        30|
# |     99|        31|
# |     99|        32|
# |     99|        33|
# |     99|        34|
# |     99|        35|
# |     99|        36|
# |     99|        37|
# |     99|        38|
# |     99|        3F|
# |     99|        3H|
# |     99|        3M|
# |     99|        3R|
# |     99|        40|
# |     99|        41|
# |     99|        43|
# |     99|        44|
# |     99|        45|
# |     99|        46|
# |     99|        48|
# |     99|        49|
# |     99|        4B|
# |     99|         5|
# |     99|        50|
# |     99|        51|
# |     99|        52|
# |     99|        53|
# |     99|        54|
# |     99|        55|
# |     99|        57|
# |     99|        58|
# |     99|         6|
# |     99|        60|
# |     99|        61|
# |     99|        62|
# |     99|        63|
# |     99|        64|
# |     99|        65|
# |     99|        67|
# |     99|        68|
# |     99|         7|
# |     99|        70|
# |     99|        71|
# |     99|        72|
# |     99|        73|
# |     99|        74|
# |     99|        75|
# |     99|        76|
# |     99|        77|
# |     99|        78|
# |     99|        79|
# |     99|         8|
# |     99|        80|
# |     99|        81|
# |     99|        82|
# |     99|        83|
# |     99|        84|
# |     99|        85|
# |     99|        87|
# |     99|        89|
# |     99|        8T|
# |     99|         9|
# |     99|        90|
# |     99|        91|
# |     99|        92|
# |     99|        93|
# |     99|        94|
# |     99|        95|
# |     99|        96|
# |     99|        97|
# |     99|        98|
# |     99|        99|
# |     99|         A|
# |     99|        AA|
# |     99|        AB|
# |     99|        AC|
# |     99|        AD|
# |     99|        AE|
# |     99|        AF|
# |     99|        AG|
# |     99|        AH|
# |     99|        AI|
# |     99|        AJ|
# |     99|        AM|
# |     99|        AN|
# |     99|        AO|
# |     99|        AP|
# |     99|        AQ|
# |     99|        AS|
# |     99|        AT|
# |     99|        AU|
# |     99|        AV|
# |     99|        AW|
# |     99|        AX|
# |     99|        AY|
# |     99|         B|
# |     99|        B2|
# |     99|        B3|
# |     99|        B6|
# |     99|        B7|
# |     99|        B9|
# |     99|        BA|
# |     99|        BB|
# |     99|        BC|
# |     99|        BD|
# |     99|        BE|
# |     99|        BF|
# |     99|        BG|
# |     99|        BH|
# |     99|        BI|
# |     99|        BJ|
# |     99|        BK|
# |     99|        BL|
# |     99|        BM|
# |     99|        BN|
# |     99|        BO|
# |     99|        BQ|
# |     99|        BR|
# |     99|        BS|
# |     99|        BT|
# |     99|        BU|
# |     99|        BV|
# |     99|        BW|
# |     99|        BX|
# |     99|        BY|
# |     99|        BZ|
# |     99|         C|
# |     99|        C0|
# |     99|        CB|
# |     99|        CC|
# |     99|        CD|
# |     99|        CE|
# |     99|        CF|
# |     99|        CG|
# |     99|        CH|
# |     99|        CI|
# |     99|        CK|
# |     99|        CL|
# |     99|        CM|
# |     99|        CN|
# |     99|        CP|
# |     99|        CQ|
# |     99|        CR|
# |     99|        CS|
# |     99|        CU|
# |     99|        CV|
# |     99|        CW|
# |     99|        CX|
# |     99|        CY|
# |     99|        CZ|
# |     99|         D|
# |     99|        D.|
# |     99|        DA|
# |     99|        DB|
# |     99|        DD|
# |     99|        DF|
# |     99|        DG|
# |     99|        DH|
# |     99|        DI|
# |     99|        DK|
# |     99|        DL|
# |     99|        DM|
# |     99|        DN|
# |     99|        DO|
# |     99|        DR|
# |     99|        DS|
# |     99|        DT|
# |     99|        DU|
# |     99|        DV|
# |     99|        DW|
# |     99|        DX|
# |     99|        DY|
# |     99|        DZ|
# |     99|         E|
# |     99|        E2|
# |     99|        E3|
# |     99|        E4|
# |     99|        EA|
# |     99|        EB|
# |     99|        EC|
# |     99|        ED|
# |     99|        EE|
# |     99|        EG|
# |     99|        EH|
# |     99|        EI|
# |     99|        EL|
# |     99|        EM|
# |     99|        EN|
# |     99|        EP|
# |     99|        EQ|
# |     99|        ER|
# |     99|        ES|
# |     99|        ET|
# |     99|        EU|
# |     99|        EV|
# |     99|        EW|
# |     99|        EX|
# |     99|        EY|
# |     99|        EZ|
# |     99|         F|
# |     99|        F1|
# |     99|        FA|
# |     99|        FC|
# |     99|        FD|
# |     99|        FE|
# |     99|        FF|
# |     99|        FG|
# |     99|        FH|
# |     99|        FI|
# |     99|        FJ|
# |     99|        FK|
# |     99|        FM|
# |     99|        FN|
# |     99|        FO|
# |     99|        FP|
# |     99|        FR|
# |     99|        FS|
# |     99|        FT|
# |     99|        FU|
# |     99|        FW|
# |     99|        FX|
# |     99|        FY|
# |     99|        FZ|
# |     99|         G|
# |     99|        G3|
# |     99|        G5|
# |     99|        G6|
# |     99|        G7|
# |     99|        G8|
# |     99|        GB|
# |     99|        GC|
# |     99|        GD|
# |     99|        GE|
# |     99|        GF|
# |     99|        GG|
# |     99|        GH|
# |     99|        GI|
# |     99|        GJ|
# |     99|        GK|
# |     99|        GL|
# |     99|        GM|
# |     99|        GN|
# |     99|        GO|
# |     99|        GP|
# |     99|        GQ|
# |     99|        GR|
# |     99|        GS|
# |     99|        GT|
# |     99|        GV|
# |     99|        GW|
# |     99|        GY|
# |     99|        GZ|
# |     99|         H|
# |     99|        H8|
# |     99|        HA|
# |     99|        HB|
# |     99|        HC|
# |     99|        HE|
# |     99|        HF|
# |     99|        HG|
# |     99|        HH|
# |     99|        HJ|
# |     99|        HK|
# |     99|        HL|
# |     99|        HM|
# |     99|        HN|
# |     99|        HO|
# |     99|        HP|
# |     99|        HQ|
# |     99|        HR|
# |     99|        HS|
# |     99|        HT|
# |     99|        HU|
# |     99|        HV|
# |     99|        HW|
# |     99|        HX|
# |     99|        HY|
# |     99|        HZ|
# |     99|         I|
# |     99|        I0|
# |     99|        I6|
# |     99|        IB|
# |     99|        IC|
# |     99|        IF|
# |     99|        IG|
# |     99|        IH|
# |     99|        II|
# |     99|        IJ|
# |     99|        IK|
# |     99|        IM|
# |     99|        IO|
# |     99|        IP|
# |     99|        IQ|
# |     99|        IR|
# |     99|        IS|
# |     99|        IT|
# |     99|        IU|
# |     99|        IV|
# |     99|        IW|
# |     99|        IY|
# |     99|        IZ|
# |     99|         J|
# |     99|        JA|
# |     99|        JC|
# |     99|        JD|
# |     99|        JE|
# |     99|        JF|
# |     99|        JG|
# |     99|        JH|
# |     99|        JI|
# |     99|        JJ|
# |     99|        JK|
# |     99|        JL|
# |     99|        JM|
# |     99|        JN|
# |     99|        JO|
# |     99|        JP|
# |     99|        JQ|
# |     99|        JR|
# |     99|        JS|
# |     99|        JT|
# |     99|        JU|
# |     99|        JW|
# |     99|        JX|
# |     99|        JY|
# |     99|         K|
# |     99|        KA|
# |     99|        KC|
# |     99|        KD|
# |     99|        KE|
# |     99|        KF|
# |     99|        KH|
# |     99|        KI|
# |     99|        KJ|
# |     99|        KK|
# |     99|        KL|
# |     99|        KM|
# |     99|        KN|
# |     99|        KO|
# |     99|        KR|
# |     99|        KT|
# |     99|        KU|
# |     99|        KV|
# |     99|        KW|
# |     99|        KZ|
# |     99|         L|
# |     99|        L1|
# |     99|        L2|
# |     99|        L3|
# |     99|        L4|
# |     99|        LB|
# |     99|        LC|
# |     99|        LD|
# |     99|        LE|
# |     99|        LF|
# |     99|        LG|
# |     99|        LH|
# |     99|        LI|
# |     99|        LJ|
# |     99|        LK|
# |     99|        LL|
# |     99|        LN|
# |     99|        LO|
# |     99|        LP|
# |     99|        LQ|
# |     99|        LR|
# |     99|        LS|
# |     99|        LT|
# |     99|        LU|
# |     99|        LV|
# |     99|        LW|
# |     99|        LX|
# |     99|        LY|
# |     99|        LZ|
# |     99|         M|
# |     99|        M1|
# |     99|        M2|
# |     99|        M3|
# |     99|        M8|
# |     99|        MB|
# |     99|        MC|
# |     99|        MF|
# |     99|        MG|
# |     99|        MH|
# |     99|        MJ|
# |     99|        MK|
# |     99|        ML|
# |     99|        MM|
# |     99|        MP|
# |     99|        MQ|
# |     99|        MR|
# |     99|        MU|
# |     99|        MV|
# |     99|        MW|
# |     99|        MX|
# |     99|        MY|
# |     99|        MZ|
# |     99|         N|
# |     99|        N.|
# |     99|        N0|
# |     99|        N1|
# |     99|        N6|
# |     99|        N7|
# |     99|        NA|
# |     99|        NB|
# |     99|        NF|
# |     99|        NG|
# |     99|        NI|
# |     99|        NK|
# |     99|        NL|
# |     99|        NN|
# |     99|        NO|
# |     99|        NP|
# |     99|        NR|
# |     99|        NS|
# |     99|        NT|
# |     99|        NU|
# |     99|        NW|
# |     99|        NX|
# |     99|        NZ|
# |     99|         O|
# |     99|        OA|
# |     99|        OB|
# |     99|        OC|
# |     99|        OD|
# |     99|        OE|
# |     99|        OF|
# |     99|        OG|
# |     99|        OI|
# |     99|        OJ|
# |     99|        OL|
# |     99|        OM|
# |     99|        ON|
# |     99|        OO|
# |     99|        OP|
# |     99|        OS|
# |     99|        OT|
# |     99|        OU|
# |     99|        OV|
# |     99|        OW|
# |     99|        OX|
# |     99|        OY|
# |     99|        OZ|
# |     99|         P|
# |     99|        PB|
# |     99|        PC|
# |     99|        PD|
# |     99|        PE|
# |     99|        PF|
# |     99|        PG|
# |     99|        PH|
# |     99|        PI|
# |     99|        PJ|
# |     99|        PK|
# |     99|        PL|
# |     99|        PN|
# |     99|        PO|
# |     99|        PP|
# |     99|        PQ|
# |     99|        PS|
# |     99|        PT|
# |     99|        PU|
# |     99|        PV|
# |     99|        PW|
# |     99|        PX|
# |     99|        PY|
# |     99|         Q|
# |     99|        QA|
# |     99|        QB|
# |     99|        QC|
# |     99|        QE|
# |     99|        QF|
# |     99|        QI|
# |     99|        QK|
# |     99|        QL|
# |     99|        QM|
# |     99|        QO|
# |     99|        QQ|
# |     99|        QR|
# |     99|        QS|
# |     99|        QT|
# |     99|        QU|
# |     99|        QW|
# |     99|        QY|
# |     99|        QZ|
# |     99|         R|
# |     99|        RA|
# |     99|        RC|
# |     99|        RD|
# |     99|        RE|
# |     99|        RF|
# |     99|        RG|
# |     99|        RH|
# |     99|        RJ|
# |     99|        RL|
# |     99|        RM|
# |     99|        RN|
# |     99|        RO|
# |     99|        RP|
# |     99|        RQ|
# |     99|        RR|
# |     99|        RS|
# |     99|        RT|
# |     99|        RU|
# |     99|        RV|
# |     99|        RX|
# |     99|        RY|
# |     99|         S|
# |     99|        S.|
# |     99|        S2|
# |     99|        S3|
# |     99|        S6|
# |     99|        S7|
# |     99|        S8|
# |     99|        SA|
# |     99|        SB|
# |     99|        SE|
# |     99|        SF|
# |     99|        SG|
# |     99|        SH|
# |     99|        SI|
# |     99|        SJ|
# |     99|        SK|
# |     99|        SL|
# |     99|        SM|
# |     99|        SN|
# |     99|        SO|
# |     99|        SP|
# |     99|        SQ|
# |     99|        SR|
# |     99|        SS|
# |     99|        ST|
# |     99|        SU|
# |     99|        SV|
# |     99|        SW|
# |     99|        SX|
# |     99|        SY|
# |     99|        SZ|
# |     99|         T|
# |     99|        TA|
# |     99|        TB|
# |     99|        TC|
# |     99|        TD|
# |     99|        TE|
# |     99|        TF|
# |     99|        TG|
# |     99|        TH|
# |     99|        TI|
# |     99|        TJ|
# |     99|        TK|
# |     99|        TL|
# |     99|        TM|
# |     99|        TO|
# |     99|        TP|
# |     99|        TQ|
# |     99|        TR|
# |     99|        TS|
# |     99|        TT|
# |     99|        TU|
# |     99|        TV|
# |     99|        TW|
# |     99|        TY|
# |     99|        TZ|
# |     99|         U|
# |     99|        UA|
# |     99|        UB|
# |     99|        UC|
# |     99|        UD|
# |     99|        UE|
# |     99|        UF|
# |     99|        UG|
# |     99|        UH|
# |     99|        UI|
# |     99|        UJ|
# |     99|        UK|
# |     99|        UL|
# |     99|        UM|
# |     99|        UN|
# |     99|        UP|
# |     99|        UR|
# |     99|        US|
# |     99|        UU|
# |     99|        UV|
# |     99|        UY|
# |     99|         V|
# |     99|        VC|
# |     99|        VD|
# |     99|        VE|
# |     99|        VF|
# |     99|        VG|
# |     99|        VH|
# |     99|        VK|
# |     99|        VL|
# |     99|        VM|
# |     99|        VN|
# |     99|        VO|
# |     99|        VP|
# |     99|        VQ|
# |     99|        VR|
# |     99|        VS|
# |     99|        VU|
# |     99|        VV|
# |     99|        VW|
# |     99|        VX|
# |     99|        VY|
# |     99|        VZ|
# |     99|         W|
# |     99|        W1|
# |     99|        W3|
# |     99|        W4|
# |     99|        W5|
# |     99|        WB|
# |     99|        WC|
# |     99|        WD|
# |     99|        WE|
# |     99|        WF|
# |     99|        WG|
# |     99|        WH|
# |     99|        WJ|
# |     99|        WK|
# |     99|        WL|
# |     99|        WM|
# |     99|        WN|
# |     99|        WO|
# |     99|        WP|
# |     99|        WQ|
# |     99|        WR|
# |     99|        WS|
# |     99|        WT|
# |     99|        WU|
# |     99|        WW|
# |     99|        WZ|
# |     99|         X|
# |     99|        XA|
# |     99|        XC|
# |     99|        XD|
# |     99|        XF|
# |     99|        XI|
# |     99|        XN|
# |     99|        XQ|
# |     99|        XT|
# |     99|        XX|
# |     99|        XZ|
# |     99|         Y|
# |     99|        YA|
# |     99|        YB|
# |     99|        YC|
# |     99|        YD|
# |     99|        YE|
# |     99|        YH|
# |     99|        YI|
# |     99|        YK|
# |     99|        YL|
# |     99|        YM|
# |     99|        YN|
# |     99|        YO|
# |     99|        YQ|
# |     99|        YS|
# |     99|        YT|
# |     99|        YU|
# |     99|        YV|
# |     99|        YW|
# |     99|        YX|
# |     99|        YY|
# |     99|         Z|
# |     99|        ZA|
# |     99|        ZC|
# |     99|        ZE|
# |     99|        ZG|
# |     99|        ZH|
# |     99|        ZI|
# |     99|        ZJ|
# |     99|        ZL|
# |     99|        ZN|
# |     99|        ZO|
# |     99|        ZR|
# |     99|        ZT|
# |     99|        ZU|
# |     99|        ZW|
# |     99|        ZX|
# |     AK|        AK|
# |     AL|        AL|
# |     AR|        AR|
# |     AZ|        AZ|
# |     CA|        CA|
# |     CO|        CO|
# |     CT|        CT|
# |     DC|        DC|
# |     DE|        DE|
# |     FL|        FL|
# |     GA|        GA|
# |     GU|        GU|
# |     HI|        HI|
# |     IA|        IA|
# |     ID|        ID|
# |     IL|        IL|
# |     IN|        IN|
# |     KS|        KS|
# |     KY|        KY|
# |     LA|        LA|
# |     MA|        MA|
# |     MD|        MD|
# |     ME|        ME|
# |     MI|        MI|
# |     MN|        MN|
# |     MO|        MO|
# |     MS|        MS|
# |     MT|        MT|
# |     NC|        NC|
# |     ND|        ND|
# |     NE|        NE|
# |     NH|        NH|
# |     NJ|        NJ|
# |     NM|        NM|
# |     NV|        NV|
# |     NY|        NY|
# |     OH|        OH|
# |     OK|        OK|
# |     OR|        OR|
# |     PA|        PA|
# |     PR|        PR|
# |     RI|        RI|
# |     SC|        SC|
# |     SD|        SD|
# |     TN|        TN|
# |     TX|        TX|
# |     UT|        UT|
# |     VA|        VA|
# |     VI|        VI|
# |     VT|        VT|
# |     WA|        WA|
# |     WI|        WI|
# |     WV|        WV|
# |     WY|        WY|
# +-------+----------+

# %%
print(df_f_i94_immigrations.count())
df_f_i94_immigrations.printSchema()
# Out:
# 12228839
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_port_state_code: string (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)

# %%
# write fact table f_i94_immigration (~ 137,7 MB)
location_to_write = "../P8_capstone_resource_files/parquet_star/PQ4/f_i94_immigrations"

# delete folder if already exists
if path.exists(location_to_write):
    shutil.rmtree(location_to_write)

df_f_i94_immigrations \
    .repartition(int(1)) \
    .write \
    .format("parquet")\
    .mode(saveMode='overwrite') \
    .partitionBy('f_i94_year', 'f_i94_month') \
    .parquet(location_to_write, compression="gzip")

# %% [markdown]
# 6. Answer Project Question 4: To which states in the U.S. do immigrants want to continue their travel after their initial
#    arrival and what demographics can immigrants expect when they arrive in the destination state, such as average
#    temperature, population numbers or population density?

# %%
#Get data for further processing
location_to_read = "../P8_capstone_resource_files/parquet_star/PQ4/f_i94_immigrations"
df_f_i94_immigrations = spark.read.parquet(location_to_read)

print(df_f_i94_immigrations.count())
df_f_i94_immigrations.printSchema()


location_to_read = "../P8_capstone_resource_files/parquet_star/PQ4/d_state_destinations"
df_d_state_destinations = spark.read.parquet(location_to_read)

print(df_d_state_destinations.count())
df_d_state_destinations.printSchema()
# Out:
# 12228839
# root
#  |-- f_i94_cit: integer (nullable = true)
#  |-- f_i94_port: string (nullable = true)
#  |-- f_i94_addr: string (nullable = true)
#  |-- f_i94_arrdate_iso: date (nullable = true)
#  |-- f_i94_depdate_iso: date (nullable = true)
#  |-- f_i94_dtadfile: date (nullable = true)
#  |-- f_i94_matflag: string (nullable = true)
#  |-- f_i94_count: integer (nullable = true)
#  |-- f_i94_id: integer (nullable = true)
#  |-- d_ic_id: integer (nullable = true)
#  |-- d_ia_id: string (nullable = true)
#  |-- d_da_id: date (nullable = true)
#  |-- d_dd_id: date (nullable = true)
#  |-- f_i94_port_state_code: string (nullable = true)
#  |-- d_sd_id: string (nullable = true)
#  |-- f_i94_year: integer (nullable = true)
#  |-- f_i94_month: integer (nullable = true)
#
# 55
# root
#  |-- d_sd_state_code: string (nullable = true)
#  |-- d_sd_state_name: string (nullable = true)
#  |-- d_sd_age_median: double (nullable = true)
#  |-- d_sd_population_male: integer (nullable = true)
#  |-- d_sd_population_female: integer (nullable = true)
#  |-- d_sd_population_total: integer (nullable = true)
#  |-- d_sd_foreign_born: integer (nullable = true)
#  |-- d_sd_id: string (nullable = true)

# %%
# Register data frames as Views
df_f_i94_immigrations.createOrReplaceTempView("f_i94_immigrations")
df_d_state_destinations.createOrReplaceTempView("d_state_destinations")


# Answer Project question #6: The Answer is "California"
df_pq4 = spark.sql(" select "
                   "        RANK() OVER (ORDER BY count(f_i94.f_i94_count) desc) immigrants_continue_travel_rank"
                   "       ,d_sd.d_sd_state_code as state_code"
                   "       ,d_sd.d_sd_state_name as state_name"
                   "       ,count(f_i94.f_i94_count) as immigrants_continue_travel "
                   "       ,d_sd.d_sd_age_median as age_median"
                   "       ,d_sd.d_sd_population_male as population_male"
                   "       ,d_sd.d_sd_population_female as population_female"
                   "       ,d_sd.d_sd_population_total as population_total"
                   "       ,d_sd.d_sd_foreign_born as foreign_born"
                   " from f_i94_immigrations f_i94"
                   " join d_state_destinations d_sd on d_sd.d_sd_id == f_i94.d_sd_id"
                   " group by state_code"
                   "         ,state_name"
                   "         ,age_median"
                   "         ,population_male"
                   "         ,population_female"
                   "         ,population_total"
                   "         ,foreign_born"
                   " order by immigrants_continue_travel desc ")

df_pq4.show(500)
# Out:
# +-------------------------------+----------+-----------------+--------------------------+----------+---------------+-----------------+----------------+------------+
# |immigrants_continue_travel_rank|state_code|       state_name|immigrants_continue_travel|age_median|population_male|population_female|population_total|foreign_born|
# +-------------------------------+----------+-----------------+--------------------------+----------+---------------+-----------------+----------------+------------+
# |                              1|        CA|       California|                   1643595|      36.2|          90319|            92290|          182609|       54821|
# |                              2|        FL|          Florida|                   1574311|      39.5|          70602|            75919|          145523|       35340|
# |                              3|        NY|         New York|                   1387808|      35.6|         433755|           473689|          907445|      318275|
# |                              4|        99|  All Other Codes|                    982830|       0.0|              0|                0|               0|           0|
# |                              5|        TX|            Texas|                    714372|      33.4|         127700|           130738|          258439|       53106|
# |                              6|        MA|    Massachusetts|                    438998|      35.5|          70160|            74723|          144884|       37301|
# |                              7|        NJ|       New Jersey|                    433331|      35.3|          60053|            61543|          121596|       40837|
# |                              8|        IL|         Illinois|                    406719|      35.7|         120262|           127148|          247410|       50907|
# |                              9|        NV|           Nevada|                    386045|      36.1|         124293|           124677|          248971|       53481|
# |                             10|        WA|       Washington|                    360872|      35.3|          73270|            73794|          147065|       25938|
# |                             11|        GA|          Georgia|                    266045|      33.8|          74574|            80973|          155548|       13435|
# |                             12|        PA|     Pennsylvania|                    251428|      34.0|         167112|           181457|          348569|       43634|
# |                             13|        VA|         Virginia|                    230215|      34.4|          82891|            85939|          168830|       19232|
# |                             14|        MI|         Michigan|                    222573|      37.0|          66041|            71746|          137787|       15374|
# |                             15|        MD|         Maryland|                    193001|      36.4|          62795|            68417|          131212|       22979|
# |                             16|        NC|      N. Carolina|                    177568|      33.8|         104721|           113863|          218585|       27094|
# |                             17|        DC|Dist. Of Columbia|                    175928|      33.8|         319705|           352523|          672228|       95117|
# |                             18|        CO|         Colorado|                    166799|      35.8|          90913|            92565|          183479|       21101|
# |                             19|        HI|           Hawaii|                    161629|      41.4|         176807|           175959|          352766|      101312|
# |                             20|        OH|             Ohio|                    161616|      35.6|         119454|           127414|          246868|       17834|
# |                             21|        AZ|          Arizona|                    148546|      35.0|         139215|           142005|          281221|       42644|
# |                             22|        LA|        Louisiana|                    135393|      34.6|          78374|            84199|          162574|       10427|
# |                             23|        NE|         Nebraska|                    124276|      33.3|         178666|           181950|          360616|       35610|
# |                             24|        CT|      Connecticut|                    121880|      35.0|          54447|            57222|          111669|       28570|
# |                             25|        OR|           Oregon|                    115275|      36.1|          88430|            91133|          179563|       23219|
# |                             26|        MN|        Minnesota|                    105117|      35.6|          64422|            66025|          130447|       19812|
# |                             27|        TN|        Tennessee|                     96373|      34.3|         116458|           126499|          242958|       20457|
# |                             28|        IN|          Indiana|                     93715|      33.8|          86272|            92115|          178388|       13992|
# |                             29|        UT|             Utah|                     76321|      30.9|          53890|            52769|          106659|       13579|
# |                             30|        WI|        Wisconsin|                     73780|      33.5|          76533|            80482|          157016|       13854|
# |                             31|        SC|      S. Carolina|                     70509|      33.8|          52720|            55070|          107790|        5584|
# |                             32|        MO|         Missouri|                     69008|      34.9|          81473|            87325|          168799|       11010|
# |                             33|        AL|          Alabama|                     66922|      36.2|          72005|            79856|          151861|        7427|
# |                             34|        PR|      Puerto Rico|                     63772|      40.7|          71542|            84676|          156219|           0|
# |                             35|        KY|         Kentucky|                     47022|      36.0|         226241|           238697|          464938|       33244|
# |                             36|        GU|             Guam|                     43338|       0.0|              0|                0|               0|           0|
# |                             37|        IA|             Iowa|                     35705|      32.5|          52119|            53880|          106000|        9112|
# |                             38|        RI|     Rhode Island|                     35632|      37.7|          51304|            53227|          104532|       22710|
# |                             39|        AK|           Alaska|                     34844|      32.2|         152945|           145750|          298695|       33258|
# |                             40|        OK|         Oklahoma|                     34553|      33.4|         119095|           122403|          241499|       25195|
# |                             41|        NH|    New Hampshire|                     33252|      37.8|          48885|            50213|           99099|       13599|
# |                             42|        KS|           Kansas|                     32751|      34.8|          80592|            83447|          164039|       16949|
# |                             43|        ME|            Maine|                     32481|      40.3|          31480|            35392|           66872|        9229|
# |                             44|        AR|         Arkansas|                     29456|      32.7|          48300|            51109|           99409|       10612|
# |                             45|        DE|         Delaware|                     27163|      36.4|          32680|            39277|           71957|        3336|
# |                             46|        NM|       New Mexico|                     22722|      37.8|         102252|           107508|          209760|       22278|
# |                             47|        ID|            Idaho|                     21915|      34.8|          66367|            66593|          132961|        9375|
# |                             48|        VT|          Vermont|                     20809|       0.0|              0|                0|               0|           0|
# |                             49|        MT|          Montana|                     20384|      35.5|          43853|            46793|           90647|        2988|
# |                             50|        MS|      Mississippi|                     18807|      33.2|          58625|            68212|          126838|        2359|
# |                             51|        WV|      W. Virginia|                     10644|       0.0|              0|                0|               0|           0|
# |                             52|        WY|          Wyoming|                     10433|       0.0|              0|                0|               0|           0|
# |                             53|        ND|        N. Dakota|                     10405|      34.3|          47617|            47127|           94745|        5746|
# |                             54|        SD|        S. Dakota|                      7348|      37.1|          61359|            61190|          122549|        7654|
# |                             55|        VI|   Virgin Islands|                      2605|       0.0|              0|                0|               0|           0|
# +-------------------------------+----------+-----------------+--------------------------+----------+---------------+-----------------+----------------+------------+
